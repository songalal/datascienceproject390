# %%
import pandas as pd
from statsmodels.tsa.arima.model import ARIMA

#85 percent train 15 percent test

# %%
df = pd.read_csv('variable_selected_county_dataset.csv')

# %%
df.entity.unique()
# Out:
# array(['California-Los Angeles', 'California-Orange',
#        'California-San Diego', 'Florida-Miami-Dade', 'Illinois-Cook',
#        'Nevada-Clark', 'New York-Nassau', 'New York-New York City',
#        'New York-Suffolk', 'Pennsylvania-Philadelphia', 'Texas-Harris',
#        'Texas-Tarrant'], dtype=object)

# %%
df.isna().sum()
# Out:
# Unnamed: 0                      0
# date                            0
# cases                           0
# stay_at_home_announced          0
# stay_at_home_effective          0
#                                ..
# dewpoint_3d_avg                57
# date_stay_at_home_announced     0
# date_stay_at_home_effective     0
# entity                          0
# incremental_cases               0
# Length: 135, dtype: int64

# %%
# get selected counties
toWorkOn = df.loc[(df.county =='Maricopa') | (df.county == 'Los Angeles') | (df.county == 'Santa Clara')]

# %%
maricopa = toWorkOn[toWorkOn.county == 'Maricopa']
maricopa = maricopa[['date', 'cases']]
maricopa.set_index('date',inplace=True)

# %%
#maricopa.plot(x='date', y='cases')
maricopa['Change'] = maricopa['cases'].diff()
maricopa.drop(columns=['cases'], inplace=True)
maricopa = maricopa.iloc[1: , :]
# Out:
# C:\Users\yshik\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\yshik\Anaconda3\lib\site-packages\pandas\core\frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
maricopa
# Out:
#             Change
# date
# 2020-01-28     0.0
# 2020-01-29     0.0
# 2020-01-30     0.0
# 2020-01-31     0.0
# 2020-02-01     0.0
# ...            ...
# 2020-11-30   326.0
# 2020-12-01  8330.0
# 2020-12-02  3123.0
# 2020-12-03  3288.0
# 2020-12-04  4525.0
#
# [312 rows x 1 columns]

# %%
from matplotlib import pyplot as plt

train = maricopa.head(int(0.85*len(maricopa)))
test = maricopa.tail(int(0.15*len(maricopa)))
model = ARIMA(train, order=(5,1,0))
model_fit = model.fit()
# summary of fit model
print(model_fit.summary())
# line plot of residuals
residuals = pd.DataFrame(model_fit.resid)
residuals.plot()
plt.show()
# density plot of residuals
residuals.plot(kind='kde')
plt.show()
# summary stats of residuals
print(residuals.describe())
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:                 Change   No. Observations:                  265
# Model:                 ARIMA(5, 1, 0)   Log Likelihood               -1913.009
# Date:                Thu, 25 Jan 2024   AIC                           3838.017
# Time:                        16:50:54   BIC                           3859.473
# Sample:                    01-28-2020   HQIC                          3846.639
#                          - 10-18-2020
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.6066      0.029    -20.980      0.000      -0.663      -0.550
# ar.L2         -0.5243      0.040    -13.129      0.000      -0.603      -0.446
# ar.L3         -0.3544      0.049     -7.175      0.000      -0.451      -0.258
# ...

# %%
foo = pd.DataFrame(model_fit.resid)
foo.columns=['Change']
predictedTrain = train + foo
predictedTrain
# Out:
#                 Change
# date
# 2020-01-28    0.000000
# 2020-01-29    0.000000
# 2020-01-30    0.000000
# 2020-01-31    0.000000
# 2020-02-01    0.000000
# ...                ...
# 2020-10-14  651.721477
# 2020-10-15  718.406941
# 2020-10-16  407.189816
# 2020-10-17  741.251131
# 2020-10-18  516.438998
#
# [265 rows x 1 columns]

# %%
predictedTrain.plot(y='Change')
# Out:
# <AxesSubplot:xlabel='date'>

# %%
train.plot(y='Change')
# Out:
# <AxesSubplot:xlabel='date'>

# %%
forecast = model_fit.forecast(steps=47)

predictTest = pd.DataFrame(forecast)
predictTest.columns=['Change']
predictTest
# Out:
#                 Change
# 2020-10-19  516.565740
# 2020-10-20  552.431225
# 2020-10-21  522.576073
# 2020-10-22  538.050366
# 2020-10-23  536.766081
# 2020-10-24  528.095740
# 2020-10-25  536.210818
# 2020-10-26  533.048043
# 2020-10-27  533.208802
# 2020-10-28  534.880374
# 2020-10-29  532.749089
# 2020-10-30  533.640202
# 2020-10-31  533.776453
# 2020-11-01  533.411716
# 2020-11-02  533.850750
# 2020-11-03  533.567498
# 2020-11-04  533.534850
# 2020-11-05  533.660858
# 2020-11-06  533.578615
# 2020-11-07  533.640321
# 2020-11-08  533.630694
# 2020-11-09  533.593254
# 2020-11-10  533.618495
# 2020-11-11  533.610909
# 2020-11-12  533.614758
# 2020-11-13  533.620618
# 2020-11-14  533.611715
# 2020-11-15  533.613579
# 2020-11-16  533.614244
# 2020-11-17  533.613806
# 2020-11-18  533.615663
# 2020-11-19  533.614485
# 2020-11-20  533.614037
# 2020-11-21  533.614371
# 2020-11-22  533.614227
# 2020-11-23  533.614572
# 2020-11-24  533.614546
# 2020-11-25  533.614349
# 2020-11-26  533.614387
# ...

# %%
predictTest.plot(y='Change')
# Out:
# <AxesSubplot:>

# %%
test.plot(y='Change')
# Out:
# <AxesSubplot:xlabel='date'>
