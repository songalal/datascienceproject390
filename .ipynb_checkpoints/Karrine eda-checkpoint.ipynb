# %%
import pandas as pd
import datetime as dt

# %%
data = pd.read_csv('data.csv')

# %%
for x in data.columns[171:]:
    print(x, data[x].isna().sum())
# Out:
# percentile_rank_age_65_and_older 17835
# percentile_rank_age_17_and_younger 17835
# percentile_rank_disabled 17835
# percentile_rank_single_parent_households 17835
# percentile_rank_household_comp_disability_theme 17835
# percentile_rank_minorities 17835
# percentile_rank_limited_english_abilities 17835
# percentile_rank_minority_status_and_language_theme 17835
# percentile_rank_multi_unit_housing 17835
# percentile_rank_mobile_homes 17835
# percentile_rank_overcrowding 17835
# percentile_rank_no_vehicle 17835
# percentile_rank_institutionalized_in_group_quarters 17835
# percentile_rank_housing_and_transportation 17835
# percentile_rank_social_vulnerability 17835
# km_to_closest_station 17835
# CALL 84360
# ELEV_M 17835
# station_id 34239
# station_name 34239
# mean_temp 34244
# min_temp 34399
# max_temp 35222
# dewpoint 87536
# sea_level_pressure 387426
# station_pressure 134979
# visibility 98906
# wind_speed 69244
# max_wind_speed 72664
# wind_gust 333692
# precipitation 106830
# precip_flag 106830
# fog 34239
# rain 34239
# snow 34239
# hail 34239
# thunder 34239
# tornado 34239
# mean_temp_3d_avg 37386
# mean_temp_5d_avg 40528
# mean_temp_10d_avg 49950
# mean_temp_15d_avg 56238
# max_temp_3d_avg 39981
# max_temp_5d_avg 44651
# max_temp_10d_avg 57517
# max_temp_15d_avg 67038
# min_temp_3d_avg 37729
# min_temp_5d_avg 41042
# min_temp_10d_avg 50849
# min_temp_15d_avg 57491
# dewpoint_3d_avg 91249
# dewpoint_5d_avg 94835
# dewpoint_10d_avg 104846
# dewpoint_15d_avg 111689
# date_stay_at_home_announced 151112
# date_stay_at_home_effective 151112

# %%
sub_data = data.iloc[:, 171:]
sub_data['entity'] = data['state'] + '-' + data['county']

# %%
all_entities = sub_data['entity'].unique()

# %%
# number of NAs for each column
num_na_df = sub_data.isna().sum().reset_index().rename(
    columns = {'index':'col', 0:'num_na'}).sort_values(by = 'num_na', ascending = False)

# columns with NAs
num_na_df = num_na_df[num_na_df['num_na'] != 0]
num_na_df
# Out:
#                                                   col  num_na
# 24                                 sea_level_pressure  387426
# 29                                          wind_gust  333692
# 55                        date_stay_at_home_effective  151112
# 54                        date_stay_at_home_announced  151112
# 25                                   station_pressure  134979
# 53                                   dewpoint_15d_avg  111689
# 30                                      precipitation  106830
# 31                                        precip_flag  106830
# 52                                   dewpoint_10d_avg  104846
# 26                                         visibility   98906
# 51                                    dewpoint_5d_avg   94835
# 50                                    dewpoint_3d_avg   91249
# 23                                           dewpoint   87536
# 16                                               CALL   84360
# 28                                     max_wind_speed   72664
# 27                                         wind_speed   69244
# 45                                   max_temp_15d_avg   67038
# 44                                   max_temp_10d_avg   57517
# 49                                   min_temp_15d_avg   57491
# 41                                  mean_temp_15d_avg   56238
# 48                                   min_temp_10d_avg   50849
# 40                                  mean_temp_10d_avg   49950
# 43                                    max_temp_5d_avg   44651
# 47                                    min_temp_5d_avg   41042
# 39                                   mean_temp_5d_avg   40528
# 42                                    max_temp_3d_avg   39981
# 46                                    min_temp_3d_avg   37729
# 38                                   mean_temp_3d_avg   37386
# 22                                           max_temp   35222
# 21                                           min_temp   34399
# 20                                          mean_temp   34244
# 18                                         station_id   34239
# 32                                                fog   34239
# 33                                               rain   34239
# 34                                               snow   34239
# 35                                               hail   34239
# 36                                            thunder   34239
# 37                                            tornado   34239
# 19                                       station_name   34239
# 0                    percentile_rank_age_65_and_older   17835
# 1                  percentile_rank_age_17_and_younger   17835
# 8                  percentile_rank_multi_unit_housing   17835
# 2                            percentile_rank_disabled   17835
# 3            percentile_rank_single_parent_households   17835
# 4     percentile_rank_household_comp_disability_theme   17835
# 5                          percentile_rank_minorities   17835
# 6           percentile_rank_limited_english_abilities   17835
# 7   percentile_rank_minority_status_and_language_t...   17835
# 9                        percentile_rank_mobile_homes   17835
# 17                                             ELEV_M   17835
# 10                       percentile_rank_overcrowding   17835
# 11                         percentile_rank_no_vehicle   17835
# 12  percentile_rank_institutionalized_in_group_qua...   17835
# 13         percentile_rank_housing_and_transportation   17835
# 14               percentile_rank_social_vulnerability   17835
# 15                              km_to_closest_station   17835

# %%
columns_to_check = sub_data.columns[sub_data.columns != 'entity']

# Dictionary to store entities for each column
entities_all_na_by_column = {}

# Iterate over each column
for column in columns_to_check:
    # Find entities where all values for the current column are NaN
    entities_all_na = sub_data[sub_data[column].isna()]['entity'].unique()
    entities_all_na_by_column[column] = entities_all_na

# Print the result
for column, entities in entities_all_na_by_column.items():
    print(f"Entities where all values for '{column}' are NaN: {entities}")
# Out:
# Entities where all values for 'percentile_rank_age_65_and_older' are NaN: ['Virgin Islands-St. Croix' 'Virgin Islands-St. John'
#  'Virgin Islands-St. Thomas' 'Puerto Rico-Adjuntas' 'Puerto Rico-Aguada'
#  'Puerto Rico-Aguadilla' 'Puerto Rico-Aguas Buenas' 'Puerto Rico-Aibonito'
#  'Puerto Rico-Anasco' 'Puerto Rico-Arecibo' 'Puerto Rico-Arroyo'
#  'Puerto Rico-Barceloneta' 'Puerto Rico-Barranquitas'
#  'Puerto Rico-Bayamon' 'Puerto Rico-Cabo Rojo' 'Puerto Rico-Caguas'
#  'Puerto Rico-Camuy' 'Puerto Rico-Canovanas' 'Puerto Rico-Carolina'
#  'Puerto Rico-Catano' 'Puerto Rico-Cayey' 'Puerto Rico-Ceiba'
#  'Puerto Rico-Ciales' 'Puerto Rico-Cidra' 'Puerto Rico-Coamo'
#  'Puerto Rico-Comerio' 'Puerto Rico-Corozal' 'Puerto Rico-Dorado'
#  'Puerto Rico-Fajardo' 'Puerto Rico-Florida' 'Puerto Rico-Guanica'
#  'Puerto Rico-Guayama' 'Puerto Rico-Guayanilla' 'Puerto Rico-Guaynabo'
#  'Puerto Rico-Gurabo' 'Puerto Rico-Hatillo' 'Puerto Rico-Hormigueros'
#  'Puerto Rico-Humacao' 'Puerto Rico-Isabela' 'Puerto Rico-Jayuya'
#  'Puerto Rico-Juana Diaz' 'Puerto Rico-Juncos' 'Puerto Rico-Lajas'
#  'Puerto Rico-Lares' 'Puerto Rico-Las Marias' 'Puerto Rico-Las Piedras'
#  'Puerto Rico-Loiza' 'Puerto Rico-Luquillo' 'Puerto Rico-Manati'
#  'Puerto Rico-Maunabo' 'Puerto Rico-Mayaguez' 'Puerto Rico-Moca'
#  'Puerto Rico-Morovis' 'Puerto Rico-Naguabo' 'Puerto Rico-Naranjito'
#  'Puerto Rico-Orocovis' 'Puerto Rico-Patillas' 'Puerto Rico-Penuelas'
#  'Puerto Rico-Ponce' 'Puerto Rico-Quebradillas' 'Puerto Rico-Rincon'
#  'Puerto Rico-Rio Grande' 'Puerto Rico-Sabana Grande'
#  'Puerto Rico-Salinas' 'Puerto Rico-San German' 'Puerto Rico-San Juan'
#  'Puerto Rico-San Lorenzo' 'Puerto Rico-San Sebastian'
#  'Puerto Rico-Santa Isabel' 'Puerto Rico-Toa Alta' 'Puerto Rico-Toa Baja'
#  'Puerto Rico-Trujillo Alto' 'Puerto Rico-Utuado' 'Puerto Rico-Vega Alta'
#  'Puerto Rico-Vega Baja' 'Puerto Rico-Villalba' 'Puerto Rico-Yabucoa'
#  'Puerto Rico-Yauco' 'Puerto Rico-Vieques' 'Puerto Rico-Maricao'
#  'Puerto Rico-Culebra' 'Missouri-Joplin' 'Northern Mariana Islands-Saipan'
#  'Northern Mariana Islands-Tinian']
# Entities where all values for 'percentile_rank_age_17_and_younger' are NaN: ['Virgin Islands-St. Croix' 'Virgin Islands-St. John'
#  'Virgin Islands-St. Thomas' 'Puerto Rico-Adjuntas' 'Puerto Rico-Aguada'
#  'Puerto Rico-Aguadilla' 'Puerto Rico-Aguas Buenas' 'Puerto Rico-Aibonito'
#  'Puerto Rico-Anasco' 'Puerto Rico-Arecibo' 'Puerto Rico-Arroyo'
#  'Puerto Rico-Barceloneta' 'Puerto Rico-Barranquitas'
#  'Puerto Rico-Bayamon' 'Puerto Rico-Cabo Rojo' 'Puerto Rico-Caguas'
#  'Puerto Rico-Camuy' 'Puerto Rico-Canovanas' 'Puerto Rico-Carolina'
#  'Puerto Rico-Catano' 'Puerto Rico-Cayey' 'Puerto Rico-Ceiba'
#  'Puerto Rico-Ciales' 'Puerto Rico-Cidra' 'Puerto Rico-Coamo'
#  'Puerto Rico-Comerio' 'Puerto Rico-Corozal' 'Puerto Rico-Dorado'
#  'Puerto Rico-Fajardo' 'Puerto Rico-Florida' 'Puerto Rico-Guanica'
#  'Puerto Rico-Guayama' 'Puerto Rico-Guayanilla' 'Puerto Rico-Guaynabo'
#  'Puerto Rico-Gurabo' 'Puerto Rico-Hatillo' 'Puerto Rico-Hormigueros'
#  'Puerto Rico-Humacao' 'Puerto Rico-Isabela' 'Puerto Rico-Jayuya'
#  'Puerto Rico-Juana Diaz' 'Puerto Rico-Juncos' 'Puerto Rico-Lajas'
#  'Puerto Rico-Lares' 'Puerto Rico-Las Marias' 'Puerto Rico-Las Piedras'
#  'Puerto Rico-Loiza' 'Puerto Rico-Luquillo' 'Puerto Rico-Manati'
#  'Puerto Rico-Maunabo' 'Puerto Rico-Mayaguez' 'Puerto Rico-Moca'
#  'Puerto Rico-Morovis' 'Puerto Rico-Naguabo' 'Puerto Rico-Naranjito'
#  'Puerto Rico-Orocovis' 'Puerto Rico-Patillas' 'Puerto Rico-Penuelas'
#  'Puerto Rico-Ponce' 'Puerto Rico-Quebradillas' 'Puerto Rico-Rincon'
#  'Puerto Rico-Rio Grande' 'Puerto Rico-Sabana Grande'
#  'Puerto Rico-Salinas' 'Puerto Rico-San German' 'Puerto Rico-San Juan'
#  'Puerto Rico-San Lorenzo' 'Puerto Rico-San Sebastian'
#  'Puerto Rico-Santa Isabel' 'Puerto Rico-Toa Alta' 'Puerto Rico-Toa Baja'
#  'Puerto Rico-Trujillo Alto' 'Puerto Rico-Utuado' 'Puerto Rico-Vega Alta'
#  'Puerto Rico-Vega Baja' 'Puerto Rico-Villalba' 'Puerto Rico-Yabucoa'
#  'Puerto Rico-Yauco' 'Puerto Rico-Vieques' 'Puerto Rico-Maricao'
#  'Puerto Rico-Culebra' 'Missouri-Joplin' 'Northern Mariana Islands-Saipan'
#  'Northern Mariana Islands-Tinian']
# Entities where all values for 'percentile_rank_disabled' are NaN: ['Virgin Islands-St. Croix' 'Virgin Islands-St. John'
#  'Virgin Islands-St. Thomas' 'Puerto Rico-Adjuntas' 'Puerto Rico-Aguada'
#  'Puerto Rico-Aguadilla' 'Puerto Rico-Aguas Buenas' 'Puerto Rico-Aibonito'
#  'Puerto Rico-Anasco' 'Puerto Rico-Arecibo' 'Puerto Rico-Arroyo'
#  'Puerto Rico-Barceloneta' 'Puerto Rico-Barranquitas'
#  'Puerto Rico-Bayamon' 'Puerto Rico-Cabo Rojo' 'Puerto Rico-Caguas'
#  'Puerto Rico-Camuy' 'Puerto Rico-Canovanas' 'Puerto Rico-Carolina'
#  'Puerto Rico-Catano' 'Puerto Rico-Cayey' 'Puerto Rico-Ceiba'
#  'Puerto Rico-Ciales' 'Puerto Rico-Cidra' 'Puerto Rico-Coamo'
#  'Puerto Rico-Comerio' 'Puerto Rico-Corozal' 'Puerto Rico-Dorado'
#  'Puerto Rico-Fajardo' 'Puerto Rico-Florida' 'Puerto Rico-Guanica'
#  'Puerto Rico-Guayama' 'Puerto Rico-Guayanilla' 'Puerto Rico-Guaynabo'
#  'Puerto Rico-Gurabo' 'Puerto Rico-Hatillo' 'Puerto Rico-Hormigueros'
#  'Puerto Rico-Humacao' 'Puerto Rico-Isabela' 'Puerto Rico-Jayuya'
#  'Puerto Rico-Juana Diaz' 'Puerto Rico-Juncos' 'Puerto Rico-Lajas'
#  'Puerto Rico-Lares' 'Puerto Rico-Las Marias' 'Puerto Rico-Las Piedras'
#  'Puerto Rico-Loiza' 'Puerto Rico-Luquillo' 'Puerto Rico-Manati'
#  'Puerto Rico-Maunabo' 'Puerto Rico-Mayaguez' 'Puerto Rico-Moca'
#  'Puerto Rico-Morovis' 'Puerto Rico-Naguabo' 'Puerto Rico-Naranjito'
#  'Puerto Rico-Orocovis' 'Puerto Rico-Patillas' 'Puerto Rico-Penuelas'
#  'Puerto Rico-Ponce' 'Puerto Rico-Quebradillas' 'Puerto Rico-Rincon'
#  'Puerto Rico-Rio Grande' 'Puerto Rico-Sabana Grande'
#  'Puerto Rico-Salinas' 'Puerto Rico-San German' 'Puerto Rico-San Juan'
#  'Puerto Rico-San Lorenzo' 'Puerto Rico-San Sebastian'
#  'Puerto Rico-Santa Isabel' 'Puerto Rico-Toa Alta' 'Puerto Rico-Toa Baja'
#  'Puerto Rico-Trujillo Alto' 'Puerto Rico-Utuado' 'Puerto Rico-Vega Alta'
#  'Puerto Rico-Vega Baja' 'Puerto Rico-Villalba' 'Puerto Rico-Yabucoa'
#  'Puerto Rico-Yauco' 'Puerto Rico-Vieques' 'Puerto Rico-Maricao'
#  'Puerto Rico-Culebra' 'Missouri-Joplin' 'Northern Mariana Islands-Saipan'
#  'Northern Mariana Islands-Tinian']
# Entities where all values for 'percentile_rank_single_parent_households' are NaN: ['Virgin Islands-St. Croix' 'Virgin Islands-St. John'
#  'Virgin Islands-St. Thomas' 'Puerto Rico-Adjuntas' 'Puerto Rico-Aguada'
#  'Puerto Rico-Aguadilla' 'Puerto Rico-Aguas Buenas' 'Puerto Rico-Aibonito'
#  'Puerto Rico-Anasco' 'Puerto Rico-Arecibo' 'Puerto Rico-Arroyo'
#  'Puerto Rico-Barceloneta' 'Puerto Rico-Barranquitas'
#  'Puerto Rico-Bayamon' 'Puerto Rico-Cabo Rojo' 'Puerto Rico-Caguas'
#  'Puerto Rico-Camuy' 'Puerto Rico-Canovanas' 'Puerto Rico-Carolina'
#  'Puerto Rico-Catano' 'Puerto Rico-Cayey' 'Puerto Rico-Ceiba'
#  'Puerto Rico-Ciales' 'Puerto Rico-Cidra' 'Puerto Rico-Coamo'
#  'Puerto Rico-Comerio' 'Puerto Rico-Corozal' 'Puerto Rico-Dorado'
#  'Puerto Rico-Fajardo' 'Puerto Rico-Florida' 'Puerto Rico-Guanica'
#  'Puerto Rico-Guayama' 'Puerto Rico-Guayanilla' 'Puerto Rico-Guaynabo'
#  'Puerto Rico-Gurabo' 'Puerto Rico-Hatillo' 'Puerto Rico-Hormigueros'
#  'Puerto Rico-Humacao' 'Puerto Rico-Isabela' 'Puerto Rico-Jayuya'
#  'Puerto Rico-Juana Diaz' 'Puerto Rico-Juncos' 'Puerto Rico-Lajas'
#  'Puerto Rico-Lares' 'Puerto Rico-Las Marias' 'Puerto Rico-Las Piedras'
#  'Puerto Rico-Loiza' 'Puerto Rico-Luquillo' 'Puerto Rico-Manati'
#  'Puerto Rico-Maunabo' 'Puerto Rico-Mayaguez' 'Puerto Rico-Moca'
#  'Puerto Rico-Morovis' 'Puerto Rico-Naguabo' 'Puerto Rico-Naranjito'
#  'Puerto Rico-Orocovis' 'Puerto Rico-Patillas' 'Puerto Rico-Penuelas'
#  'Puerto Rico-Ponce' 'Puerto Rico-Quebradillas' 'Puerto Rico-Rincon'
#  'Puerto Rico-Rio Grande' 'Puerto Rico-Sabana Grande'
#  'Puerto Rico-Salinas' 'Puerto Rico-San German' 'Puerto Rico-San Juan'
#  'Puerto Rico-San Lorenzo' 'Puerto Rico-San Sebastian'
#  'Puerto Rico-Santa Isabel' 'Puerto Rico-Toa Alta' 'Puerto Rico-Toa Baja'
#  'Puerto Rico-Trujillo Alto' 'Puerto Rico-Utuado' 'Puerto Rico-Vega Alta'
#  'Puerto Rico-Vega Baja' 'Puerto Rico-Villalba' 'Puerto Rico-Yabucoa'
#  'Puerto Rico-Yauco' 'Puerto Rico-Vieques' 'Puerto Rico-Maricao'
#  'Puerto Rico-Culebra' 'Missouri-Joplin' 'Northern Mariana Islands-Saipan'
#  'Northern Mariana Islands-Tinian']
# Entities where all values for 'percentile_rank_household_comp_disability_theme' are NaN: ['Virgin Islands-St. Croix' 'Virgin Islands-St. John'
#  'Virgin Islands-St. Thomas' 'Puerto Rico-Adjuntas' 'Puerto Rico-Aguada'
#  'Puerto Rico-Aguadilla' 'Puerto Rico-Aguas Buenas' 'Puerto Rico-Aibonito'
#  'Puerto Rico-Anasco' 'Puerto Rico-Arecibo' 'Puerto Rico-Arroyo'
#  'Puerto Rico-Barceloneta' 'Puerto Rico-Barranquitas'
#  'Puerto Rico-Bayamon' 'Puerto Rico-Cabo Rojo' 'Puerto Rico-Caguas'
#  'Puerto Rico-Camuy' 'Puerto Rico-Canovanas' 'Puerto Rico-Carolina'
#  'Puerto Rico-Catano' 'Puerto Rico-Cayey' 'Puerto Rico-Ceiba'
#  'Puerto Rico-Ciales' 'Puerto Rico-Cidra' 'Puerto Rico-Coamo'
#  'Puerto Rico-Comerio' 'Puerto Rico-Corozal' 'Puerto Rico-Dorado'
#  'Puerto Rico-Fajardo' 'Puerto Rico-Florida' 'Puerto Rico-Guanica'
#  'Puerto Rico-Guayama' 'Puerto Rico-Guayanilla' 'Puerto Rico-Guaynabo'
#  'Puerto Rico-Gurabo' 'Puerto Rico-Hatillo' 'Puerto Rico-Hormigueros'
#  'Puerto Rico-Humacao' 'Puerto Rico-Isabela' 'Puerto Rico-Jayuya'
#  'Puerto Rico-Juana Diaz' 'Puerto Rico-Juncos' 'Puerto Rico-Lajas'
#  'Puerto Rico-Lares' 'Puerto Rico-Las Marias' 'Puerto Rico-Las Piedras'
#  'Puerto Rico-Loiza' 'Puerto Rico-Luquillo' 'Puerto Rico-Manati'
#  'Puerto Rico-Maunabo' 'Puerto Rico-Mayaguez' 'Puerto Rico-Moca'
#  'Puerto Rico-Morovis' 'Puerto Rico-Naguabo' 'Puerto Rico-Naranjito'
#  'Puerto Rico-Orocovis' 'Puerto Rico-Patillas' 'Puerto Rico-Penuelas'
#  'Puerto Rico-Ponce' 'Puerto Rico-Quebradillas' 'Puerto Rico-Rincon'
#  'Puerto Rico-Rio Grande' 'Puerto Rico-Sabana Grande'
#  'Puerto Rico-Salinas' 'Puerto Rico-San German' 'Puerto Rico-San Juan'
#  'Puerto Rico-San Lorenzo' 'Puerto Rico-San Sebastian'
#  'Puerto Rico-Santa Isabel' 'Puerto Rico-Toa Alta' 'Puerto Rico-Toa Baja'
#  'Puerto Rico-Trujillo Alto' 'Puerto Rico-Utuado' 'Puerto Rico-Vega Alta'
#  'Puerto Rico-Vega Baja' 'Puerto Rico-Villalba' 'Puerto Rico-Yabucoa'
#  'Puerto Rico-Yauco' 'Puerto Rico-Vieques' 'Puerto Rico-Maricao'
#  'Puerto Rico-Culebra' 'Missouri-Joplin' 'Northern Mariana Islands-Saipan'
#  'Northern Mariana Islands-Tinian']
# Entities where all values for 'percentile_rank_minorities' are NaN: ['Virgin Islands-St. Croix' 'Virgin Islands-St. John'
#  'Virgin Islands-St. Thomas' 'Puerto Rico-Adjuntas' 'Puerto Rico-Aguada'
#  'Puerto Rico-Aguadilla' 'Puerto Rico-Aguas Buenas' 'Puerto Rico-Aibonito'
#  'Puerto Rico-Anasco' 'Puerto Rico-Arecibo' 'Puerto Rico-Arroyo'
#  'Puerto Rico-Barceloneta' 'Puerto Rico-Barranquitas'
#  'Puerto Rico-Bayamon' 'Puerto Rico-Cabo Rojo' 'Puerto Rico-Caguas'
#  'Puerto Rico-Camuy' 'Puerto Rico-Canovanas' 'Puerto Rico-Carolina'
#  'Puerto Rico-Catano' 'Puerto Rico-Cayey' 'Puerto Rico-Ceiba'
#  'Puerto Rico-Ciales' 'Puerto Rico-Cidra' 'Puerto Rico-Coamo'
#  'Puerto Rico-Comerio' 'Puerto Rico-Corozal' 'Puerto Rico-Dorado'
#  'Puerto Rico-Fajardo' 'Puerto Rico-Florida' 'Puerto Rico-Guanica'
#  'Puerto Rico-Guayama' 'Puerto Rico-Guayanilla' 'Puerto Rico-Guaynabo'
#  'Puerto Rico-Gurabo' 'Puerto Rico-Hatillo' 'Puerto Rico-Hormigueros'
#  'Puerto Rico-Humacao' 'Puerto Rico-Isabela' 'Puerto Rico-Jayuya'
#  'Puerto Rico-Juana Diaz' 'Puerto Rico-Juncos' 'Puerto Rico-Lajas'
#  'Puerto Rico-Lares' 'Puerto Rico-Las Marias' 'Puerto Rico-Las Piedras'
#  'Puerto Rico-Loiza' 'Puerto Rico-Luquillo' 'Puerto Rico-Manati'
#  'Puerto Rico-Maunabo' 'Puerto Rico-Mayaguez' 'Puerto Rico-Moca'
#  'Puerto Rico-Morovis' 'Puerto Rico-Naguabo' 'Puerto Rico-Naranjito'
#  'Puerto Rico-Orocovis' 'Puerto Rico-Patillas' 'Puerto Rico-Penuelas'
#  'Puerto Rico-Ponce' 'Puerto Rico-Quebradillas' 'Puerto Rico-Rincon'
#  'Puerto Rico-Rio Grande' 'Puerto Rico-Sabana Grande'
#  'Puerto Rico-Salinas' 'Puerto Rico-San German' 'Puerto Rico-San Juan'
#  'Puerto Rico-San Lorenzo' 'Puerto Rico-San Sebastian'
#  'Puerto Rico-Santa Isabel' 'Puerto Rico-Toa Alta' 'Puerto Rico-Toa Baja'
#  'Puerto Rico-Trujillo Alto' 'Puerto Rico-Utuado' 'Puerto Rico-Vega Alta'
#  'Puerto Rico-Vega Baja' 'Puerto Rico-Villalba' 'Puerto Rico-Yabucoa'
#  'Puerto Rico-Yauco' 'Puerto Rico-Vieques' 'Puerto Rico-Maricao'
#  'Puerto Rico-Culebra' 'Missouri-Joplin' 'Northern Mariana Islands-Saipan'
#  'Northern Mariana Islands-Tinian']
# Entities where all values for 'percentile_rank_limited_english_abilities' are NaN: ['Virgin Islands-St. Croix' 'Virgin Islands-St. John'
#  'Virgin Islands-St. Thomas' 'Puerto Rico-Adjuntas' 'Puerto Rico-Aguada'
#  'Puerto Rico-Aguadilla' 'Puerto Rico-Aguas Buenas' 'Puerto Rico-Aibonito'
#  'Puerto Rico-Anasco' 'Puerto Rico-Arecibo' 'Puerto Rico-Arroyo'
#  'Puerto Rico-Barceloneta' 'Puerto Rico-Barranquitas'
#  'Puerto Rico-Bayamon' 'Puerto Rico-Cabo Rojo' 'Puerto Rico-Caguas'
#  'Puerto Rico-Camuy' 'Puerto Rico-Canovanas' 'Puerto Rico-Carolina'
#  'Puerto Rico-Catano' 'Puerto Rico-Cayey' 'Puerto Rico-Ceiba'
#  'Puerto Rico-Ciales' 'Puerto Rico-Cidra' 'Puerto Rico-Coamo'
#  'Puerto Rico-Comerio' 'Puerto Rico-Corozal' 'Puerto Rico-Dorado'
#  'Puerto Rico-Fajardo' 'Puerto Rico-Florida' 'Puerto Rico-Guanica'
#  'Puerto Rico-Guayama' 'Puerto Rico-Guayanilla' 'Puerto Rico-Guaynabo'
#  'Puerto Rico-Gurabo' 'Puerto Rico-Hatillo' 'Puerto Rico-Hormigueros'
#  'Puerto Rico-Humacao' 'Puerto Rico-Isabela' 'Puerto Rico-Jayuya'
#  'Puerto Rico-Juana Diaz' 'Puerto Rico-Juncos' 'Puerto Rico-Lajas'
#  'Puerto Rico-Lares' 'Puerto Rico-Las Marias' 'Puerto Rico-Las Piedras'
#  'Puerto Rico-Loiza' 'Puerto Rico-Luquillo' 'Puerto Rico-Manati'
#  'Puerto Rico-Maunabo' 'Puerto Rico-Mayaguez' 'Puerto Rico-Moca'
#  'Puerto Rico-Morovis' 'Puerto Rico-Naguabo' 'Puerto Rico-Naranjito'
#  'Puerto Rico-Orocovis' 'Puerto Rico-Patillas' 'Puerto Rico-Penuelas'
#  'Puerto Rico-Ponce' 'Puerto Rico-Quebradillas' 'Puerto Rico-Rincon'
#  'Puerto Rico-Rio Grande' 'Puerto Rico-Sabana Grande'
#  'Puerto Rico-Salinas' 'Puerto Rico-San German' 'Puerto Rico-San Juan'
#  'Puerto Rico-San Lorenzo' 'Puerto Rico-San Sebastian'
#  'Puerto Rico-Santa Isabel' 'Puerto Rico-Toa Alta' 'Puerto Rico-Toa Baja'
#  'Puerto Rico-Trujillo Alto' 'Puerto Rico-Utuado' 'Puerto Rico-Vega Alta'
#  'Puerto Rico-Vega Baja' 'Puerto Rico-Villalba' 'Puerto Rico-Yabucoa'
#  'Puerto Rico-Yauco' 'Puerto Rico-Vieques' 'Puerto Rico-Maricao'
#  'Puerto Rico-Culebra' 'Missouri-Joplin' 'Northern Mariana Islands-Saipan'
#  'Northern Mariana Islands-Tinian']
# Entities where all values for 'percentile_rank_minority_status_and_language_theme' are NaN: ['Virgin Islands-St. Croix' 'Virgin Islands-St. John'
#  'Virgin Islands-St. Thomas' 'Puerto Rico-Adjuntas' 'Puerto Rico-Aguada'
#  'Puerto Rico-Aguadilla' 'Puerto Rico-Aguas Buenas' 'Puerto Rico-Aibonito'
#  'Puerto Rico-Anasco' 'Puerto Rico-Arecibo' 'Puerto Rico-Arroyo'
#  'Puerto Rico-Barceloneta' 'Puerto Rico-Barranquitas'
#  'Puerto Rico-Bayamon' 'Puerto Rico-Cabo Rojo' 'Puerto Rico-Caguas'
#  'Puerto Rico-Camuy' 'Puerto Rico-Canovanas' 'Puerto Rico-Carolina'
#  'Puerto Rico-Catano' 'Puerto Rico-Cayey' 'Puerto Rico-Ceiba'
#  'Puerto Rico-Ciales' 'Puerto Rico-Cidra' 'Puerto Rico-Coamo'
#  'Puerto Rico-Comerio' 'Puerto Rico-Corozal' 'Puerto Rico-Dorado'
#  'Puerto Rico-Fajardo' 'Puerto Rico-Florida' 'Puerto Rico-Guanica'
#  'Puerto Rico-Guayama' 'Puerto Rico-Guayanilla' 'Puerto Rico-Guaynabo'
#  'Puerto Rico-Gurabo' 'Puerto Rico-Hatillo' 'Puerto Rico-Hormigueros'
#  'Puerto Rico-Humacao' 'Puerto Rico-Isabela' 'Puerto Rico-Jayuya'
#  'Puerto Rico-Juana Diaz' 'Puerto Rico-Juncos' 'Puerto Rico-Lajas'
#  'Puerto Rico-Lares' 'Puerto Rico-Las Marias' 'Puerto Rico-Las Piedras'
#  'Puerto Rico-Loiza' 'Puerto Rico-Luquillo' 'Puerto Rico-Manati'
#  'Puerto Rico-Maunabo' 'Puerto Rico-Mayaguez' 'Puerto Rico-Moca'
#  'Puerto Rico-Morovis' 'Puerto Rico-Naguabo' 'Puerto Rico-Naranjito'
#  'Puerto Rico-Orocovis' 'Puerto Rico-Patillas' 'Puerto Rico-Penuelas'
#  'Puerto Rico-Ponce' 'Puerto Rico-Quebradillas' 'Puerto Rico-Rincon'
#  'Puerto Rico-Rio Grande' 'Puerto Rico-Sabana Grande'
#  'Puerto Rico-Salinas' 'Puerto Rico-San German' 'Puerto Rico-San Juan'
#  'Puerto Rico-San Lorenzo' 'Puerto Rico-San Sebastian'
#  'Puerto Rico-Santa Isabel' 'Puerto Rico-Toa Alta' 'Puerto Rico-Toa Baja'
#  'Puerto Rico-Trujillo Alto' 'Puerto Rico-Utuado' 'Puerto Rico-Vega Alta'
#  'Puerto Rico-Vega Baja' 'Puerto Rico-Villalba' 'Puerto Rico-Yabucoa'
#  'Puerto Rico-Yauco' 'Puerto Rico-Vieques' 'Puerto Rico-Maricao'
#  'Puerto Rico-Culebra' 'Missouri-Joplin' 'Northern Mariana Islands-Saipan'
#  'Northern Mariana Islands-Tinian']
# Entities where all values for 'percentile_rank_multi_unit_housing' are NaN: ['Virgin Islands-St. Croix' 'Virgin Islands-St. John'
#  'Virgin Islands-St. Thomas' 'Puerto Rico-Adjuntas' 'Puerto Rico-Aguada'
#  'Puerto Rico-Aguadilla' 'Puerto Rico-Aguas Buenas' 'Puerto Rico-Aibonito'
#  'Puerto Rico-Anasco' 'Puerto Rico-Arecibo' 'Puerto Rico-Arroyo'
#  'Puerto Rico-Barceloneta' 'Puerto Rico-Barranquitas'
#  'Puerto Rico-Bayamon' 'Puerto Rico-Cabo Rojo' 'Puerto Rico-Caguas'
#  'Puerto Rico-Camuy' 'Puerto Rico-Canovanas' 'Puerto Rico-Carolina'
#  'Puerto Rico-Catano' 'Puerto Rico-Cayey' 'Puerto Rico-Ceiba'
#  'Puerto Rico-Ciales' 'Puerto Rico-Cidra' 'Puerto Rico-Coamo'
#  'Puerto Rico-Comerio' 'Puerto Rico-Corozal' 'Puerto Rico-Dorado'
#  'Puerto Rico-Fajardo' 'Puerto Rico-Florida' 'Puerto Rico-Guanica'
#  'Puerto Rico-Guayama' 'Puerto Rico-Guayanilla' 'Puerto Rico-Guaynabo'
#  'Puerto Rico-Gurabo' 'Puerto Rico-Hatillo' 'Puerto Rico-Hormigueros'
#  'Puerto Rico-Humacao' 'Puerto Rico-Isabela' 'Puerto Rico-Jayuya'
#  'Puerto Rico-Juana Diaz' 'Puerto Rico-Juncos' 'Puerto Rico-Lajas'
#  'Puerto Rico-Lares' 'Puerto Rico-Las Marias' 'Puerto Rico-Las Piedras'
#  'Puerto Rico-Loiza' 'Puerto Rico-Luquillo' 'Puerto Rico-Manati'
#  'Puerto Rico-Maunabo' 'Puerto Rico-Mayaguez' 'Puerto Rico-Moca'
#  'Puerto Rico-Morovis' 'Puerto Rico-Naguabo' 'Puerto Rico-Naranjito'
#  'Puerto Rico-Orocovis' 'Puerto Rico-Patillas' 'Puerto Rico-Penuelas'
#  'Puerto Rico-Ponce' 'Puerto Rico-Quebradillas' 'Puerto Rico-Rincon'
#  'Puerto Rico-Rio Grande' 'Puerto Rico-Sabana Grande'
#  'Puerto Rico-Salinas' 'Puerto Rico-San German' 'Puerto Rico-San Juan'
#  'Puerto Rico-San Lorenzo' 'Puerto Rico-San Sebastian'
#  'Puerto Rico-Santa Isabel' 'Puerto Rico-Toa Alta' 'Puerto Rico-Toa Baja'
#  'Puerto Rico-Trujillo Alto' 'Puerto Rico-Utuado' 'Puerto Rico-Vega Alta'
#  'Puerto Rico-Vega Baja' 'Puerto Rico-Villalba' 'Puerto Rico-Yabucoa'
#  'Puerto Rico-Yauco' 'Puerto Rico-Vieques' 'Puerto Rico-Maricao'
#  'Puerto Rico-Culebra' 'Missouri-Joplin' 'Northern Mariana Islands-Saipan'
#  'Northern Mariana Islands-Tinian']
# Entities where all values for 'percentile_rank_mobile_homes' are NaN: ['Virgin Islands-St. Croix' 'Virgin Islands-St. John'
#  'Virgin Islands-St. Thomas' 'Puerto Rico-Adjuntas' 'Puerto Rico-Aguada'
#  'Puerto Rico-Aguadilla' 'Puerto Rico-Aguas Buenas' 'Puerto Rico-Aibonito'
#  'Puerto Rico-Anasco' 'Puerto Rico-Arecibo' 'Puerto Rico-Arroyo'
#  'Puerto Rico-Barceloneta' 'Puerto Rico-Barranquitas'
#  'Puerto Rico-Bayamon' 'Puerto Rico-Cabo Rojo' 'Puerto Rico-Caguas'
#  'Puerto Rico-Camuy' 'Puerto Rico-Canovanas' 'Puerto Rico-Carolina'
#  'Puerto Rico-Catano' 'Puerto Rico-Cayey' 'Puerto Rico-Ceiba'
#  'Puerto Rico-Ciales' 'Puerto Rico-Cidra' 'Puerto Rico-Coamo'
#  'Puerto Rico-Comerio' 'Puerto Rico-Corozal' 'Puerto Rico-Dorado'
#  'Puerto Rico-Fajardo' 'Puerto Rico-Florida' 'Puerto Rico-Guanica'
#  'Puerto Rico-Guayama' 'Puerto Rico-Guayanilla' 'Puerto Rico-Guaynabo'
#  'Puerto Rico-Gurabo' 'Puerto Rico-Hatillo' 'Puerto Rico-Hormigueros'
#  'Puerto Rico-Humacao' 'Puerto Rico-Isabela' 'Puerto Rico-Jayuya'
#  'Puerto Rico-Juana Diaz' 'Puerto Rico-Juncos' 'Puerto Rico-Lajas'
#  'Puerto Rico-Lares' 'Puerto Rico-Las Marias' 'Puerto Rico-Las Piedras'
#  'Puerto Rico-Loiza' 'Puerto Rico-Luquillo' 'Puerto Rico-Manati'
#  'Puerto Rico-Maunabo' 'Puerto Rico-Mayaguez' 'Puerto Rico-Moca'
#  'Puerto Rico-Morovis' 'Puerto Rico-Naguabo' 'Puerto Rico-Naranjito'
#  'Puerto Rico-Orocovis' 'Puerto Rico-Patillas' 'Puerto Rico-Penuelas'
#  'Puerto Rico-Ponce' 'Puerto Rico-Quebradillas' 'Puerto Rico-Rincon'
#  'Puerto Rico-Rio Grande' 'Puerto Rico-Sabana Grande'
#  'Puerto Rico-Salinas' 'Puerto Rico-San German' 'Puerto Rico-San Juan'
#  'Puerto Rico-San Lorenzo' 'Puerto Rico-San Sebastian'
#  'Puerto Rico-Santa Isabel' 'Puerto Rico-Toa Alta' 'Puerto Rico-Toa Baja'
#  'Puerto Rico-Trujillo Alto' 'Puerto Rico-Utuado' 'Puerto Rico-Vega Alta'
#  'Puerto Rico-Vega Baja' 'Puerto Rico-Villalba' 'Puerto Rico-Yabucoa'
#  'Puerto Rico-Yauco' 'Puerto Rico-Vieques' 'Puerto Rico-Maricao'
#  'Puerto Rico-Culebra' 'Missouri-Joplin' 'Northern Mariana Islands-Saipan'
#  'Northern Mariana Islands-Tinian']
# Entities where all values for 'percentile_rank_overcrowding' are NaN: ['Virgin Islands-St. Croix' 'Virgin Islands-St. John'
#  'Virgin Islands-St. Thomas' 'Puerto Rico-Adjuntas' 'Puerto Rico-Aguada'
#  'Puerto Rico-Aguadilla' 'Puerto Rico-Aguas Buenas' 'Puerto Rico-Aibonito'
#  'Puerto Rico-Anasco' 'Puerto Rico-Arecibo' 'Puerto Rico-Arroyo'
#  'Puerto Rico-Barceloneta' 'Puerto Rico-Barranquitas'
#  'Puerto Rico-Bayamon' 'Puerto Rico-Cabo Rojo' 'Puerto Rico-Caguas'
#  'Puerto Rico-Camuy' 'Puerto Rico-Canovanas' 'Puerto Rico-Carolina'
#  'Puerto Rico-Catano' 'Puerto Rico-Cayey' 'Puerto Rico-Ceiba'
#  'Puerto Rico-Ciales' 'Puerto Rico-Cidra' 'Puerto Rico-Coamo'
#  'Puerto Rico-Comerio' 'Puerto Rico-Corozal' 'Puerto Rico-Dorado'
#  'Puerto Rico-Fajardo' 'Puerto Rico-Florida' 'Puerto Rico-Guanica'
#  'Puerto Rico-Guayama' 'Puerto Rico-Guayanilla' 'Puerto Rico-Guaynabo'
#  'Puerto Rico-Gurabo' 'Puerto Rico-Hatillo' 'Puerto Rico-Hormigueros'
#  'Puerto Rico-Humacao' 'Puerto Rico-Isabela' 'Puerto Rico-Jayuya'
#  'Puerto Rico-Juana Diaz' 'Puerto Rico-Juncos' 'Puerto Rico-Lajas'
#  'Puerto Rico-Lares' 'Puerto Rico-Las Marias' 'Puerto Rico-Las Piedras'
#  'Puerto Rico-Loiza' 'Puerto Rico-Luquillo' 'Puerto Rico-Manati'
#  'Puerto Rico-Maunabo' 'Puerto Rico-Mayaguez' 'Puerto Rico-Moca'
#  'Puerto Rico-Morovis' 'Puerto Rico-Naguabo' 'Puerto Rico-Naranjito'
#  'Puerto Rico-Orocovis' 'Puerto Rico-Patillas' 'Puerto Rico-Penuelas'
#  'Puerto Rico-Ponce' 'Puerto Rico-Quebradillas' 'Puerto Rico-Rincon'
#  'Puerto Rico-Rio Grande' 'Puerto Rico-Sabana Grande'
#  'Puerto Rico-Salinas' 'Puerto Rico-San German' 'Puerto Rico-San Juan'
#  'Puerto Rico-San Lorenzo' 'Puerto Rico-San Sebastian'
#  'Puerto Rico-Santa Isabel' 'Puerto Rico-Toa Alta' 'Puerto Rico-Toa Baja'
#  'Puerto Rico-Trujillo Alto' 'Puerto Rico-Utuado' 'Puerto Rico-Vega Alta'
#  'Puerto Rico-Vega Baja' 'Puerto Rico-Villalba' 'Puerto Rico-Yabucoa'
#  'Puerto Rico-Yauco' 'Puerto Rico-Vieques' 'Puerto Rico-Maricao'
#  'Puerto Rico-Culebra' 'Missouri-Joplin' 'Northern Mariana Islands-Saipan'
#  'Northern Mariana Islands-Tinian']
# Entities where all values for 'percentile_rank_no_vehicle' are NaN: ['Virgin Islands-St. Croix' 'Virgin Islands-St. John'
#  'Virgin Islands-St. Thomas' 'Puerto Rico-Adjuntas' 'Puerto Rico-Aguada'
#  'Puerto Rico-Aguadilla' 'Puerto Rico-Aguas Buenas' 'Puerto Rico-Aibonito'
#  'Puerto Rico-Anasco' 'Puerto Rico-Arecibo' 'Puerto Rico-Arroyo'
#  'Puerto Rico-Barceloneta' 'Puerto Rico-Barranquitas'
#  'Puerto Rico-Bayamon' 'Puerto Rico-Cabo Rojo' 'Puerto Rico-Caguas'
#  'Puerto Rico-Camuy' 'Puerto Rico-Canovanas' 'Puerto Rico-Carolina'
#  'Puerto Rico-Catano' 'Puerto Rico-Cayey' 'Puerto Rico-Ceiba'
#  'Puerto Rico-Ciales' 'Puerto Rico-Cidra' 'Puerto Rico-Coamo'
#  'Puerto Rico-Comerio' 'Puerto Rico-Corozal' 'Puerto Rico-Dorado'
#  'Puerto Rico-Fajardo' 'Puerto Rico-Florida' 'Puerto Rico-Guanica'
#  'Puerto Rico-Guayama' 'Puerto Rico-Guayanilla' 'Puerto Rico-Guaynabo'
#  'Puerto Rico-Gurabo' 'Puerto Rico-Hatillo' 'Puerto Rico-Hormigueros'
#  'Puerto Rico-Humacao' 'Puerto Rico-Isabela' 'Puerto Rico-Jayuya'
#  'Puerto Rico-Juana Diaz' 'Puerto Rico-Juncos' 'Puerto Rico-Lajas'
#  'Puerto Rico-Lares' 'Puerto Rico-Las Marias' 'Puerto Rico-Las Piedras'
#  'Puerto Rico-Loiza' 'Puerto Rico-Luquillo' 'Puerto Rico-Manati'
#  'Puerto Rico-Maunabo' 'Puerto Rico-Mayaguez' 'Puerto Rico-Moca'
#  'Puerto Rico-Morovis' 'Puerto Rico-Naguabo' 'Puerto Rico-Naranjito'
#  'Puerto Rico-Orocovis' 'Puerto Rico-Patillas' 'Puerto Rico-Penuelas'
#  'Puerto Rico-Ponce' 'Puerto Rico-Quebradillas' 'Puerto Rico-Rincon'
#  'Puerto Rico-Rio Grande' 'Puerto Rico-Sabana Grande'
#  'Puerto Rico-Salinas' 'Puerto Rico-San German' 'Puerto Rico-San Juan'
#  'Puerto Rico-San Lorenzo' 'Puerto Rico-San Sebastian'
#  'Puerto Rico-Santa Isabel' 'Puerto Rico-Toa Alta' 'Puerto Rico-Toa Baja'
#  'Puerto Rico-Trujillo Alto' 'Puerto Rico-Utuado' 'Puerto Rico-Vega Alta'
#  'Puerto Rico-Vega Baja' 'Puerto Rico-Villalba' 'Puerto Rico-Yabucoa'
#  'Puerto Rico-Yauco' 'Puerto Rico-Vieques' 'Puerto Rico-Maricao'
#  'Puerto Rico-Culebra' 'Missouri-Joplin' 'Northern Mariana Islands-Saipan'
#  'Northern Mariana Islands-Tinian']
# Entities where all values for 'percentile_rank_institutionalized_in_group_quarters' are NaN: ['Virgin Islands-St. Croix' 'Virgin Islands-St. John'
#  'Virgin Islands-St. Thomas' 'Puerto Rico-Adjuntas' 'Puerto Rico-Aguada'
#  'Puerto Rico-Aguadilla' 'Puerto Rico-Aguas Buenas' 'Puerto Rico-Aibonito'
#  'Puerto Rico-Anasco' 'Puerto Rico-Arecibo' 'Puerto Rico-Arroyo'
#  'Puerto Rico-Barceloneta' 'Puerto Rico-Barranquitas'
#  'Puerto Rico-Bayamon' 'Puerto Rico-Cabo Rojo' 'Puerto Rico-Caguas'
#  'Puerto Rico-Camuy' 'Puerto Rico-Canovanas' 'Puerto Rico-Carolina'
#  'Puerto Rico-Catano' 'Puerto Rico-Cayey' 'Puerto Rico-Ceiba'
#  'Puerto Rico-Ciales' 'Puerto Rico-Cidra' 'Puerto Rico-Coamo'
#  'Puerto Rico-Comerio' 'Puerto Rico-Corozal' 'Puerto Rico-Dorado'
#  'Puerto Rico-Fajardo' 'Puerto Rico-Florida' 'Puerto Rico-Guanica'
#  'Puerto Rico-Guayama' 'Puerto Rico-Guayanilla' 'Puerto Rico-Guaynabo'
#  'Puerto Rico-Gurabo' 'Puerto Rico-Hatillo' 'Puerto Rico-Hormigueros'
#  'Puerto Rico-Humacao' 'Puerto Rico-Isabela' 'Puerto Rico-Jayuya'
#  'Puerto Rico-Juana Diaz' 'Puerto Rico-Juncos' 'Puerto Rico-Lajas'
#  'Puerto Rico-Lares' 'Puerto Rico-Las Marias' 'Puerto Rico-Las Piedras'
#  'Puerto Rico-Loiza' 'Puerto Rico-Luquillo' 'Puerto Rico-Manati'
#  'Puerto Rico-Maunabo' 'Puerto Rico-Mayaguez' 'Puerto Rico-Moca'
#  'Puerto Rico-Morovis' 'Puerto Rico-Naguabo' 'Puerto Rico-Naranjito'
#  'Puerto Rico-Orocovis' 'Puerto Rico-Patillas' 'Puerto Rico-Penuelas'
#  'Puerto Rico-Ponce' 'Puerto Rico-Quebradillas' 'Puerto Rico-Rincon'
#  'Puerto Rico-Rio Grande' 'Puerto Rico-Sabana Grande'
#  'Puerto Rico-Salinas' 'Puerto Rico-San German' 'Puerto Rico-San Juan'
#  'Puerto Rico-San Lorenzo' 'Puerto Rico-San Sebastian'
#  'Puerto Rico-Santa Isabel' 'Puerto Rico-Toa Alta' 'Puerto Rico-Toa Baja'
#  'Puerto Rico-Trujillo Alto' 'Puerto Rico-Utuado' 'Puerto Rico-Vega Alta'
#  'Puerto Rico-Vega Baja' 'Puerto Rico-Villalba' 'Puerto Rico-Yabucoa'
#  'Puerto Rico-Yauco' 'Puerto Rico-Vieques' 'Puerto Rico-Maricao'
#  'Puerto Rico-Culebra' 'Missouri-Joplin' 'Northern Mariana Islands-Saipan'
#  'Northern Mariana Islands-Tinian']
# Entities where all values for 'percentile_rank_housing_and_transportation' are NaN: ['Virgin Islands-St. Croix' 'Virgin Islands-St. John'
#  'Virgin Islands-St. Thomas' 'Puerto Rico-Adjuntas' 'Puerto Rico-Aguada'
#  'Puerto Rico-Aguadilla' 'Puerto Rico-Aguas Buenas' 'Puerto Rico-Aibonito'
#  'Puerto Rico-Anasco' 'Puerto Rico-Arecibo' 'Puerto Rico-Arroyo'
#  'Puerto Rico-Barceloneta' 'Puerto Rico-Barranquitas'
#  'Puerto Rico-Bayamon' 'Puerto Rico-Cabo Rojo' 'Puerto Rico-Caguas'
#  'Puerto Rico-Camuy' 'Puerto Rico-Canovanas' 'Puerto Rico-Carolina'
#  'Puerto Rico-Catano' 'Puerto Rico-Cayey' 'Puerto Rico-Ceiba'
#  'Puerto Rico-Ciales' 'Puerto Rico-Cidra' 'Puerto Rico-Coamo'
#  'Puerto Rico-Comerio' 'Puerto Rico-Corozal' 'Puerto Rico-Dorado'
#  'Puerto Rico-Fajardo' 'Puerto Rico-Florida' 'Puerto Rico-Guanica'
#  'Puerto Rico-Guayama' 'Puerto Rico-Guayanilla' 'Puerto Rico-Guaynabo'
#  'Puerto Rico-Gurabo' 'Puerto Rico-Hatillo' 'Puerto Rico-Hormigueros'
#  'Puerto Rico-Humacao' 'Puerto Rico-Isabela' 'Puerto Rico-Jayuya'
#  'Puerto Rico-Juana Diaz' 'Puerto Rico-Juncos' 'Puerto Rico-Lajas'
#  'Puerto Rico-Lares' 'Puerto Rico-Las Marias' 'Puerto Rico-Las Piedras'
#  'Puerto Rico-Loiza' 'Puerto Rico-Luquillo' 'Puerto Rico-Manati'
#  'Puerto Rico-Maunabo' 'Puerto Rico-Mayaguez' 'Puerto Rico-Moca'
#  'Puerto Rico-Morovis' 'Puerto Rico-Naguabo' 'Puerto Rico-Naranjito'
#  'Puerto Rico-Orocovis' 'Puerto Rico-Patillas' 'Puerto Rico-Penuelas'
#  'Puerto Rico-Ponce' 'Puerto Rico-Quebradillas' 'Puerto Rico-Rincon'
#  'Puerto Rico-Rio Grande' 'Puerto Rico-Sabana Grande'
#  'Puerto Rico-Salinas' 'Puerto Rico-San German' 'Puerto Rico-San Juan'
#  'Puerto Rico-San Lorenzo' 'Puerto Rico-San Sebastian'
#  'Puerto Rico-Santa Isabel' 'Puerto Rico-Toa Alta' 'Puerto Rico-Toa Baja'
#  'Puerto Rico-Trujillo Alto' 'Puerto Rico-Utuado' 'Puerto Rico-Vega Alta'
#  'Puerto Rico-Vega Baja' 'Puerto Rico-Villalba' 'Puerto Rico-Yabucoa'
#  'Puerto Rico-Yauco' 'Puerto Rico-Vieques' 'Puerto Rico-Maricao'
#  'Puerto Rico-Culebra' 'Missouri-Joplin' 'Northern Mariana Islands-Saipan'
#  'Northern Mariana Islands-Tinian']
# Entities where all values for 'percentile_rank_social_vulnerability' are NaN: ['Virgin Islands-St. Croix' 'Virgin Islands-St. John'
#  'Virgin Islands-St. Thomas' 'Puerto Rico-Adjuntas' 'Puerto Rico-Aguada'
#  'Puerto Rico-Aguadilla' 'Puerto Rico-Aguas Buenas' 'Puerto Rico-Aibonito'
#  'Puerto Rico-Anasco' 'Puerto Rico-Arecibo' 'Puerto Rico-Arroyo'
#  'Puerto Rico-Barceloneta' 'Puerto Rico-Barranquitas'
#  'Puerto Rico-Bayamon' 'Puerto Rico-Cabo Rojo' 'Puerto Rico-Caguas'
#  'Puerto Rico-Camuy' 'Puerto Rico-Canovanas' 'Puerto Rico-Carolina'
#  'Puerto Rico-Catano' 'Puerto Rico-Cayey' 'Puerto Rico-Ceiba'
#  'Puerto Rico-Ciales' 'Puerto Rico-Cidra' 'Puerto Rico-Coamo'
#  'Puerto Rico-Comerio' 'Puerto Rico-Corozal' 'Puerto Rico-Dorado'
#  'Puerto Rico-Fajardo' 'Puerto Rico-Florida' 'Puerto Rico-Guanica'
#  'Puerto Rico-Guayama' 'Puerto Rico-Guayanilla' 'Puerto Rico-Guaynabo'
#  'Puerto Rico-Gurabo' 'Puerto Rico-Hatillo' 'Puerto Rico-Hormigueros'
#  'Puerto Rico-Humacao' 'Puerto Rico-Isabela' 'Puerto Rico-Jayuya'
#  'Puerto Rico-Juana Diaz' 'Puerto Rico-Juncos' 'Puerto Rico-Lajas'
#  'Puerto Rico-Lares' 'Puerto Rico-Las Marias' 'Puerto Rico-Las Piedras'
#  'Puerto Rico-Loiza' 'Puerto Rico-Luquillo' 'Puerto Rico-Manati'
#  'Puerto Rico-Maunabo' 'Puerto Rico-Mayaguez' 'Puerto Rico-Moca'
#  'Puerto Rico-Morovis' 'Puerto Rico-Naguabo' 'Puerto Rico-Naranjito'
#  'Puerto Rico-Orocovis' 'Puerto Rico-Patillas' 'Puerto Rico-Penuelas'
#  'Puerto Rico-Ponce' 'Puerto Rico-Quebradillas' 'Puerto Rico-Rincon'
#  'Puerto Rico-Rio Grande' 'Puerto Rico-Sabana Grande'
#  'Puerto Rico-Salinas' 'Puerto Rico-San German' 'Puerto Rico-San Juan'
#  'Puerto Rico-San Lorenzo' 'Puerto Rico-San Sebastian'
#  'Puerto Rico-Santa Isabel' 'Puerto Rico-Toa Alta' 'Puerto Rico-Toa Baja'
#  'Puerto Rico-Trujillo Alto' 'Puerto Rico-Utuado' 'Puerto Rico-Vega Alta'
#  'Puerto Rico-Vega Baja' 'Puerto Rico-Villalba' 'Puerto Rico-Yabucoa'
#  'Puerto Rico-Yauco' 'Puerto Rico-Vieques' 'Puerto Rico-Maricao'
#  'Puerto Rico-Culebra' 'Missouri-Joplin' 'Northern Mariana Islands-Saipan'
#  'Northern Mariana Islands-Tinian']
# Entities where all values for 'km_to_closest_station' are NaN: ['Virgin Islands-St. Croix' 'Virgin Islands-St. John'
#  'Virgin Islands-St. Thomas' 'Puerto Rico-Adjuntas' 'Puerto Rico-Aguada'
#  'Puerto Rico-Aguadilla' 'Puerto Rico-Aguas Buenas' 'Puerto Rico-Aibonito'
#  'Puerto Rico-Anasco' 'Puerto Rico-Arecibo' 'Puerto Rico-Arroyo'
#  'Puerto Rico-Barceloneta' 'Puerto Rico-Barranquitas'
#  'Puerto Rico-Bayamon' 'Puerto Rico-Cabo Rojo' 'Puerto Rico-Caguas'
#  'Puerto Rico-Camuy' 'Puerto Rico-Canovanas' 'Puerto Rico-Carolina'
#  'Puerto Rico-Catano' 'Puerto Rico-Cayey' 'Puerto Rico-Ceiba'
#  'Puerto Rico-Ciales' 'Puerto Rico-Cidra' 'Puerto Rico-Coamo'
#  'Puerto Rico-Comerio' 'Puerto Rico-Corozal' 'Puerto Rico-Dorado'
#  'Puerto Rico-Fajardo' 'Puerto Rico-Florida' 'Puerto Rico-Guanica'
#  'Puerto Rico-Guayama' 'Puerto Rico-Guayanilla' 'Puerto Rico-Guaynabo'
#  'Puerto Rico-Gurabo' 'Puerto Rico-Hatillo' 'Puerto Rico-Hormigueros'
#  'Puerto Rico-Humacao' 'Puerto Rico-Isabela' 'Puerto Rico-Jayuya'
#  'Puerto Rico-Juana Diaz' 'Puerto Rico-Juncos' 'Puerto Rico-Lajas'
#  'Puerto Rico-Lares' 'Puerto Rico-Las Marias' 'Puerto Rico-Las Piedras'
#  'Puerto Rico-Loiza' 'Puerto Rico-Luquillo' 'Puerto Rico-Manati'
#  'Puerto Rico-Maunabo' 'Puerto Rico-Mayaguez' 'Puerto Rico-Moca'
#  'Puerto Rico-Morovis' 'Puerto Rico-Naguabo' 'Puerto Rico-Naranjito'
#  'Puerto Rico-Orocovis' 'Puerto Rico-Patillas' 'Puerto Rico-Penuelas'
#  'Puerto Rico-Ponce' 'Puerto Rico-Quebradillas' 'Puerto Rico-Rincon'
#  'Puerto Rico-Rio Grande' 'Puerto Rico-Sabana Grande'
#  'Puerto Rico-Salinas' 'Puerto Rico-San German' 'Puerto Rico-San Juan'
#  'Puerto Rico-San Lorenzo' 'Puerto Rico-San Sebastian'
#  'Puerto Rico-Santa Isabel' 'Puerto Rico-Toa Alta' 'Puerto Rico-Toa Baja'
#  'Puerto Rico-Trujillo Alto' 'Puerto Rico-Utuado' 'Puerto Rico-Vega Alta'
#  'Puerto Rico-Vega Baja' 'Puerto Rico-Villalba' 'Puerto Rico-Yabucoa'
#  'Puerto Rico-Yauco' 'Puerto Rico-Vieques' 'Puerto Rico-Maricao'
#  'Puerto Rico-Culebra' 'Missouri-Joplin' 'Northern Mariana Islands-Saipan'
#  'Northern Mariana Islands-Tinian']
# Entities where all values for 'CALL' are NaN: ['Massachusetts-Suffolk' 'California-San Francisco' 'New Jersey-Camden'
#  'Pennsylvania-Delaware' 'South Carolina-Charleston'
#  'Washington-Jefferson' 'District of Columbia-District of Columbia'
#  'New Hampshire-Rockingham' 'New York-Ulster' 'New Jersey-Hudson'
#  'Florida-Collier' 'Washington-Skagit' 'Washington-Whatcom'
#  'Delaware-New Castle' 'Minnesota-Olmsted' 'Washington-Island'
#  'Florida-Sarasota' 'New York-Dutchess' 'Virginia-James City'
#  'Alabama-Tuscaloosa' 'Colorado-Clear Creek' 'Maryland-Anne Arundel'
#  'Texas-Galveston' 'Alabama-Baldwin' 'New Mexico-Sandoval'
#  'Louisiana-St. Bernard' 'New York-Erie' 'New York-Greene'
#  'Oklahoma-Payne' 'Arkansas-Cleburne' 'Florida-Escambia' 'Oregon-Benton'
#  'Utah-Tooele' 'Virginia-York' 'Alabama-St. Clair'
#  'Alaska-Ketchikan Gateway Borough' 'Hawaii-Hawaii' 'New Jersey-Warren'
#  'Ohio-Lake' 'Virginia-Charlottesville city' 'Alabama-Talladega'
#  'Georgia-Columbia' 'Ohio-Huron' 'Texas-Lavaca' 'Utah-Box Elder'
#  'Wyoming-Teton' 'Kentucky-Scott' 'Louisiana-Assumption'
#  'Maryland-Calvert' 'Mississippi-Scott' 'Montana-Roosevelt'
#  'New York-Wayne' 'Texas-Crane' 'West Virginia-Tucker' 'Wisconsin-Ozaukee'
#  'Alabama-Cullman' 'Alabama-Jackson' 'Alabama-Lauderdale'
#  'Alabama-Washington' 'Arizona-Yuma' 'Connecticut-New London'
#  'Florida-Monroe' 'Georgia-Lincoln' 'Georgia-Oconee'
#  'Mississippi-Marshall' 'New York-Niagara' 'North Carolina-Orange'
#  'Vermont-Addison' 'Virginia-Gloucester' 'Virginia-Portsmouth city'
#  'Indiana-Washington' 'Maryland-Somerset' 'Massachusetts-Nantucket'
#  'Michigan-Berrien' 'Minnesota-Wabasha' 'Mississippi-Leake'
#  'North Carolina-Buncombe' 'Ohio-Clermont' 'Ohio-Erie'
#  'South Carolina-Edgefield' 'Tennessee-Cocke' 'Virginia-Albemarle'
#  'Maryland-Cecil' "Maryland-St. Mary's" 'New Jersey-Salem'
#  'New York-Cortland' 'North Carolina-Henderson' 'Virginia-Fluvanna'
#  'Alabama-Franklin' 'Alaska-Juneau City and Borough' 'Georgia-Morgan'
#  'Louisiana-St. Martin' 'Maryland-Garrett' "Maryland-Queen Anne's"
#  'Michigan-Chippewa' 'Ohio-Sandusky' 'South Dakota-Lyman' 'Arkansas-Stone'
#  'California-Merced' 'Georgia-Baker' 'Georgia-Camden' 'Georgia-Mitchell'
#  'Indiana-Lawrence' 'Kansas-Pottawatomie' 'Kentucky-Muhlenberg'
#  'Mississippi-Newton' 'New York-Orleans' 'North Carolina-Transylvania'
#  'Texas-Chambers' 'Alabama-Blount' 'Alabama-Cherokee' 'Alabama-Chilton'
#  'Alabama-Colbert' 'Alabama-Lawrence' 'Alabama-Pike' 'Alabama-Wilcox'
#  'California-Inyo' 'Colorado-Otero' 'Kentucky-Grayson' 'Louisiana-Union'
#  'Maryland-Kent' 'Michigan-Iosco' 'New Mexico-Rio Arriba' 'Oregon-Lincoln'
#  'Rhode Island-Bristol' 'Rhode Island-Washington' 'Texas-Liberty'
#  'Texas-San Patricio' 'Virginia-Mathews' 'Virginia-Nelson'
#  'Alabama-Choctaw' 'Alabama-Crenshaw' 'Alabama-DeKalb' 'Alabama-Marengo'
#  'Florida-Washington' 'Georgia-Calhoun' 'Indiana-Orange'
#  'Kentucky-Hopkins' 'Kentucky-Webster' 'Louisiana-Vermilion'
#  'Mississippi-Benton' 'Montana-Meagher' 'North Dakota-McHenry'
#  'North Dakota-McIntosh' 'Texas-Calhoun' 'Virginia-Northampton'
#  'Alabama-Escambia' 'Alabama-Greene' 'Florida-Levy' 'Kentucky-Woodford'
#  'Mississippi-Neshoba' 'Missouri-Chariton' 'Ohio-Ottawa' 'Texas-Lamb'
#  'Utah-Garfield' 'Virginia-Lancaster' 'Virginia-Northumberland'
#  'Arkansas-Ashley' 'California-Tuolumne' 'Florida-Glades'
#  'Florida-Wakulla' 'Alabama-Hale' 'Alabama-Sumter' 'Florida-Holmes'
#  'Georgia-Dade' 'Georgia-McIntosh' 'New Mexico-Torrance' 'Ohio-Brown'
#  'Ohio-Holmes' 'Tennessee-Fentress' 'Tennessee-Wayne' 'Texas-Leon'
#  'Kentucky-Edmonson' 'Michigan-Arenac' 'Montana-Liberty'
#  'South Carolina-Bamberg' 'West Virginia-Hardy' 'Alabama-Clarke'
#  'Michigan-Mackinac' 'Mississippi-Jasper' 'North Dakota-Burke'
#  'Texas-Gonzales' 'Arkansas-Sharp' 'California-Del Norte' 'Illinois-Piatt'
#  'Kentucky-Pendleton' 'South Carolina-McCormick' 'West Virginia-Pendleton'
#  'Wisconsin-Adams' 'Alabama-Barbour' 'Florida-Franklin'
#  'Illinois-Effingham' 'Maine-Washington' 'Missouri-Linn' 'Montana-Glacier'
#  'North Carolina-Haywood' 'North Dakota-Slope' 'Utah-Juab' 'Utah-Millard'
#  'Indiana-Martin' 'Kentucky-Caldwell' 'Montana-Beaverhead'
#  'Washington-Wahkiakum' 'Wyoming-Crook' 'Kansas-Wabaunsee'
#  'Kentucky-McLean' 'Nebraska-Seward' 'Texas-Aransas'
#  'Alaska-Petersburg Borough' 'Arkansas-Izard' 'Missouri-Phelps'
#  'Nebraska-Cheyenne' 'Oregon-Curry' 'Virgin Islands-St. Croix'
#  'Virgin Islands-St. John' 'Virgin Islands-St. Thomas'
#  'Wisconsin-Kewaunee' 'Florida-Taylor' 'Illinois-Shelby'
#  'Louisiana-Cameron' 'Texas-Hansford' 'Minnesota-Pine' 'Alabama-Perry'
#  'Colorado-Gilpin' 'Missouri-Vernon' 'Washington-Pacific' 'Oregon-Coos'
#  'West Virginia-Grant' 'North Carolina-Jackson' 'Nebraska-Saline'
#  'Utah-Sevier' 'Michigan-Baraga' 'Texas-Sherman' 'Texas-Cochran'
#  'North Carolina-Madison' 'South Dakota-McPherson'
#  'Alaska-Sitka City and Borough' 'California-Mariposa' 'Texas-Runnels'
#  'North Carolina-Hyde' 'North Dakota-Renville' 'Texas-Brewster'
#  'Missouri-Sullivan' 'North Carolina-Yancey' 'Puerto Rico-Adjuntas'
#  'Puerto Rico-Aguada' 'Puerto Rico-Aguadilla' 'Puerto Rico-Aguas Buenas'
#  'Puerto Rico-Aibonito' 'Puerto Rico-Anasco' 'Puerto Rico-Arecibo'
#  'Puerto Rico-Arroyo' 'Puerto Rico-Barceloneta' 'Puerto Rico-Barranquitas'
#  'Puerto Rico-Bayamon' 'Puerto Rico-Cabo Rojo' 'Puerto Rico-Caguas'
#  'Puerto Rico-Camuy' 'Puerto Rico-Canovanas' 'Puerto Rico-Carolina'
#  'Puerto Rico-Catano' 'Puerto Rico-Cayey' 'Puerto Rico-Ceiba'
#  'Puerto Rico-Ciales' 'Puerto Rico-Cidra' 'Puerto Rico-Coamo'
#  'Puerto Rico-Comerio' 'Puerto Rico-Corozal' 'Puerto Rico-Dorado'
#  'Puerto Rico-Fajardo' 'Puerto Rico-Florida' 'Puerto Rico-Guanica'
#  'Puerto Rico-Guayama' 'Puerto Rico-Guayanilla' 'Puerto Rico-Guaynabo'
#  'Puerto Rico-Gurabo' 'Puerto Rico-Hatillo' 'Puerto Rico-Hormigueros'
#  'Puerto Rico-Humacao' 'Puerto Rico-Isabela' 'Puerto Rico-Jayuya'
#  'Puerto Rico-Juana Diaz' 'Puerto Rico-Juncos' 'Puerto Rico-Lajas'
#  'Puerto Rico-Lares' 'Puerto Rico-Las Marias' 'Puerto Rico-Las Piedras'
#  'Puerto Rico-Loiza' 'Puerto Rico-Luquillo' 'Puerto Rico-Manati'
#  'Puerto Rico-Maunabo' 'Puerto Rico-Mayaguez' 'Puerto Rico-Moca'
#  'Puerto Rico-Morovis' 'Puerto Rico-Naguabo' 'Puerto Rico-Naranjito'
#  'Puerto Rico-Orocovis' 'Puerto Rico-Patillas' 'Puerto Rico-Penuelas'
#  'Puerto Rico-Ponce' 'Puerto Rico-Quebradillas' 'Puerto Rico-Rincon'
#  'Puerto Rico-Rio Grande' 'Puerto Rico-Sabana Grande'
#  'Puerto Rico-Salinas' 'Puerto Rico-San German' 'Puerto Rico-San Juan'
#  'Puerto Rico-San Lorenzo' 'Puerto Rico-San Sebastian'
#  'Puerto Rico-Santa Isabel' 'Puerto Rico-Toa Alta' 'Puerto Rico-Toa Baja'
#  'Puerto Rico-Trujillo Alto' 'Puerto Rico-Utuado' 'Puerto Rico-Vega Alta'
#  'Puerto Rico-Vega Baja' 'Puerto Rico-Villalba' 'Puerto Rico-Yabucoa'
#  'Puerto Rico-Yauco' 'Texas-Bailey' 'Texas-Coke' 'Puerto Rico-Vieques'
#  'Missouri-Dent' 'Puerto Rico-Maricao' 'North Dakota-Bottineau'
#  'Texas-Ward' 'Wyoming-Weston' 'Alaska-North Slope Borough'
#  'Missouri-Texas' 'Puerto Rico-Culebra' 'South Dakota-Edmunds'
#  'Nebraska-Garden' 'North Dakota-Dickey'
#  'Alaska-Aleutians West Census Area' 'North Dakota-Sheridan'
#  'Nebraska-Banner' 'North Dakota-Kidder' 'Missouri-Barton'
#  'Nebraska-Sioux' 'South Dakota-Mellette' 'North Dakota-Billings'
#  'Kansas-Logan' 'Alaska-Denali Borough' 'Missouri-Joplin' 'Idaho-Oneida'
#  'Nebraska-Hooker' 'Montana-Sheridan' 'Texas-Kenedy' 'North Dakota-Logan'
#  'South Dakota-Jones' 'Nebraska-Deuel' 'Northern Mariana Islands-Saipan'
#  'Northern Mariana Islands-Tinian' 'Utah-Wayne' 'Idaho-Butte'
#  'Nebraska-Grant' 'Oregon-Wheeler']
# Entities where all values for 'ELEV_M' are NaN: ['Virgin Islands-St. Croix' 'Virgin Islands-St. John'
#  'Virgin Islands-St. Thomas' 'Puerto Rico-Adjuntas' 'Puerto Rico-Aguada'
#  'Puerto Rico-Aguadilla' 'Puerto Rico-Aguas Buenas' 'Puerto Rico-Aibonito'
#  'Puerto Rico-Anasco' 'Puerto Rico-Arecibo' 'Puerto Rico-Arroyo'
#  'Puerto Rico-Barceloneta' 'Puerto Rico-Barranquitas'
#  'Puerto Rico-Bayamon' 'Puerto Rico-Cabo Rojo' 'Puerto Rico-Caguas'
#  'Puerto Rico-Camuy' 'Puerto Rico-Canovanas' 'Puerto Rico-Carolina'
#  'Puerto Rico-Catano' 'Puerto Rico-Cayey' 'Puerto Rico-Ceiba'
#  'Puerto Rico-Ciales' 'Puerto Rico-Cidra' 'Puerto Rico-Coamo'
#  'Puerto Rico-Comerio' 'Puerto Rico-Corozal' 'Puerto Rico-Dorado'
#  'Puerto Rico-Fajardo' 'Puerto Rico-Florida' 'Puerto Rico-Guanica'
#  'Puerto Rico-Guayama' 'Puerto Rico-Guayanilla' 'Puerto Rico-Guaynabo'
#  'Puerto Rico-Gurabo' 'Puerto Rico-Hatillo' 'Puerto Rico-Hormigueros'
#  'Puerto Rico-Humacao' 'Puerto Rico-Isabela' 'Puerto Rico-Jayuya'
#  'Puerto Rico-Juana Diaz' 'Puerto Rico-Juncos' 'Puerto Rico-Lajas'
#  'Puerto Rico-Lares' 'Puerto Rico-Las Marias' 'Puerto Rico-Las Piedras'
#  'Puerto Rico-Loiza' 'Puerto Rico-Luquillo' 'Puerto Rico-Manati'
#  'Puerto Rico-Maunabo' 'Puerto Rico-Mayaguez' 'Puerto Rico-Moca'
#  'Puerto Rico-Morovis' 'Puerto Rico-Naguabo' 'Puerto Rico-Naranjito'
#  'Puerto Rico-Orocovis' 'Puerto Rico-Patillas' 'Puerto Rico-Penuelas'
#  'Puerto Rico-Ponce' 'Puerto Rico-Quebradillas' 'Puerto Rico-Rincon'
#  'Puerto Rico-Rio Grande' 'Puerto Rico-Sabana Grande'
#  'Puerto Rico-Salinas' 'Puerto Rico-San German' 'Puerto Rico-San Juan'
#  'Puerto Rico-San Lorenzo' 'Puerto Rico-San Sebastian'
#  'Puerto Rico-Santa Isabel' 'Puerto Rico-Toa Alta' 'Puerto Rico-Toa Baja'
#  'Puerto Rico-Trujillo Alto' 'Puerto Rico-Utuado' 'Puerto Rico-Vega Alta'
#  'Puerto Rico-Vega Baja' 'Puerto Rico-Villalba' 'Puerto Rico-Yabucoa'
#  'Puerto Rico-Yauco' 'Puerto Rico-Vieques' 'Puerto Rico-Maricao'
#  'Puerto Rico-Culebra' 'Missouri-Joplin' 'Northern Mariana Islands-Saipan'
#  'Northern Mariana Islands-Tinian']
# Entities where all values for 'station_id' are NaN: ['California-Santa Clara' 'California-Humboldt' 'Arizona-Pima' ...
#  'Washington-Benton' 'West Virginia-Mingo' 'Wisconsin-Ozaukee']
# Entities where all values for 'station_name' are NaN: ['California-Santa Clara' 'California-Humboldt' 'Arizona-Pima' ...
#  'Washington-Benton' 'West Virginia-Mingo' 'Wisconsin-Ozaukee']
# Entities where all values for 'mean_temp' are NaN: ['California-Santa Clara' 'California-Humboldt' 'Arizona-Pima' ...
#  'Washington-Benton' 'West Virginia-Mingo' 'Wisconsin-Ozaukee']
# Entities where all values for 'min_temp' are NaN: ['California-Santa Clara' 'California-Humboldt' 'Arizona-Pima' ...
#  'Washington-Benton' 'West Virginia-Mingo' 'Wisconsin-Ozaukee']
# Entities where all values for 'max_temp' are NaN: ['California-Santa Clara' 'California-Humboldt' 'Arizona-Pima' ...
#  'Washington-Benton' 'West Virginia-Mingo' 'Wisconsin-Ozaukee']
# Entities where all values for 'dewpoint' are NaN: ['Massachusetts-Suffolk' 'California-San Francisco'
#  'California-Santa Clara' ... 'Utah-Wasatch' 'Washington-Benton'
#  'West Virginia-Mingo']
# Entities where all values for 'sea_level_pressure' are NaN: ['Arizona-Maricopa' 'California-Los Angeles' 'California-Santa Clara' ...
#  'Tennessee-Stewart' 'Washington-Franklin' 'Wisconsin-Ozaukee']
# Entities where all values for 'station_pressure' are NaN: ['Massachusetts-Suffolk' 'California-San Francisco'
#  'California-Santa Clara' ... 'Montana-Daniels' 'Montana-Phillips'
#  'Oregon-Baker']
# Entities where all values for 'visibility' are NaN: ['Massachusetts-Suffolk' 'California-San Francisco'
#  'California-Santa Clara' ... 'Utah-Wasatch' 'Washington-Benton'
#  'West Virginia-Mingo']
# Entities where all values for 'wind_speed' are NaN: ['California-Santa Clara' 'California-Humboldt' 'Washington-Jefferson' ...
#  'Washington-Benton' 'West Virginia-Mingo' 'Wisconsin-Ozaukee']
# Entities where all values for 'max_wind_speed' are NaN: ['Massachusetts-Suffolk' 'California-Santa Clara' 'California-Humboldt'
#  ... 'Washington-Kitsap' 'West Virginia-Mingo' 'Wisconsin-Ozaukee']
# Entities where all values for 'wind_gust' are NaN: ['Illinois-Cook' 'California-Orange' 'Washington-Snohomish' ...
#  'Colorado-El Paso' 'Nevada-Esmeralda' 'Texas-Loving']
# Entities where all values for 'precipitation' are NaN: ['California-Santa Clara' 'Arizona-Maricopa' 'Nebraska-Douglas' ...
#  'Texas-Hansford' 'Texas-Sherman' 'Wisconsin-Ozaukee']
# Entities where all values for 'precip_flag' are NaN: ['California-Santa Clara' 'Arizona-Maricopa' 'Nebraska-Douglas' ...
#  'Texas-Hansford' 'Texas-Sherman' 'Wisconsin-Ozaukee']
# Entities where all values for 'fog' are NaN: ['California-Santa Clara' 'California-Humboldt' 'Arizona-Pima' ...
#  'Washington-Benton' 'West Virginia-Mingo' 'Wisconsin-Ozaukee']
# Entities where all values for 'rain' are NaN: ['California-Santa Clara' 'California-Humboldt' 'Arizona-Pima' ...
#  'Washington-Benton' 'West Virginia-Mingo' 'Wisconsin-Ozaukee']
# Entities where all values for 'snow' are NaN: ['California-Santa Clara' 'California-Humboldt' 'Arizona-Pima' ...
#  'Washington-Benton' 'West Virginia-Mingo' 'Wisconsin-Ozaukee']
# Entities where all values for 'hail' are NaN: ['California-Santa Clara' 'California-Humboldt' 'Arizona-Pima' ...
#  'Washington-Benton' 'West Virginia-Mingo' 'Wisconsin-Ozaukee']
# Entities where all values for 'thunder' are NaN: ['California-Santa Clara' 'California-Humboldt' 'Arizona-Pima' ...
#  'Washington-Benton' 'West Virginia-Mingo' 'Wisconsin-Ozaukee']
# Entities where all values for 'tornado' are NaN: ['California-Santa Clara' 'California-Humboldt' 'Arizona-Pima' ...
#  'Washington-Benton' 'West Virginia-Mingo' 'Wisconsin-Ozaukee']
# Entities where all values for 'mean_temp_3d_avg' are NaN: ['California-Santa Clara' 'California-Humboldt' 'Arizona-Pima' ...
#  'Wyoming-Uinta' 'Wyoming-Washakie' 'Wyoming-Weston']
# Entities where all values for 'mean_temp_5d_avg' are NaN: ['California-Santa Clara' 'California-Humboldt' 'Arizona-Pima' ...
#  'Wyoming-Uinta' 'Wyoming-Washakie' 'Wyoming-Weston']
# Entities where all values for 'mean_temp_10d_avg' are NaN: ['California-Santa Clara' 'California-Humboldt' 'Arizona-Pima' ...
#  'Wyoming-Uinta' 'Wyoming-Washakie' 'Wyoming-Weston']
# Entities where all values for 'mean_temp_15d_avg' are NaN: ['California-Santa Clara' 'California-Humboldt' 'Arizona-Pima' ...
#  'Wyoming-Uinta' 'Wyoming-Washakie' 'Wyoming-Weston']
# Entities where all values for 'max_temp_3d_avg' are NaN: ['California-Santa Clara' 'California-Humboldt' 'South Dakota-Minnehaha'
#  ... 'Wyoming-Sublette' 'Wyoming-Teton' 'Wyoming-Weston']
# Entities where all values for 'max_temp_5d_avg' are NaN: ['California-Santa Clara' 'California-Humboldt' 'South Dakota-Minnehaha'
#  ... 'Wyoming-Sublette' 'Wyoming-Teton' 'Wyoming-Weston']
# Entities where all values for 'max_temp_10d_avg' are NaN: ['California-Santa Clara' 'California-Humboldt' 'South Dakota-Minnehaha'
#  ... 'Wyoming-Sublette' 'Wyoming-Teton' 'Wyoming-Weston']
# Entities where all values for 'max_temp_15d_avg' are NaN: ['California-Santa Clara' 'California-Humboldt' 'South Dakota-Minnehaha'
#  ... 'Wyoming-Sublette' 'Wyoming-Teton' 'Wyoming-Weston']
# Entities where all values for 'min_temp_3d_avg' are NaN: ['California-Santa Clara' 'California-Humboldt' 'Arizona-Pima' ...
#  'Wyoming-Uinta' 'Wyoming-Washakie' 'Wyoming-Weston']
# Entities where all values for 'min_temp_5d_avg' are NaN: ['California-Santa Clara' 'California-Humboldt' 'Arizona-Pima' ...
#  'Wyoming-Uinta' 'Wyoming-Washakie' 'Wyoming-Weston']
# Entities where all values for 'min_temp_10d_avg' are NaN: ['California-Santa Clara' 'California-Humboldt' 'Arizona-Pima' ...
#  'Wyoming-Uinta' 'Wyoming-Washakie' 'Wyoming-Weston']
# ...
#  'Puerto Rico-Fajardo' 'Puerto Rico-Florida' 'Puerto Rico-Guanica'
#  'Puerto Rico-Guayama' 'Puerto Rico-Guayanilla' 'Puerto Rico-Guaynabo'
#  'Puerto Rico-Gurabo' 'Puerto Rico-Hatillo' 'Puerto Rico-Hormigueros'
#  'Puerto Rico-Humacao' 'Puerto Rico-Isabela' 'Puerto Rico-Jayuya'
#  'Puerto Rico-Juana Diaz' 'Puerto Rico-Juncos' 'Puerto Rico-Lajas'
#  'Puerto Rico-Lares' 'Puerto Rico-Las Marias' 'Puerto Rico-Las Piedras'
#  'Puerto Rico-Loiza' 'Puerto Rico-Luquillo' 'Puerto Rico-Manati'
#  'Puerto Rico-Maunabo' 'Puerto Rico-Mayaguez' 'Puerto Rico-Moca'
#  'Puerto Rico-Morovis' 'Puerto Rico-Naguabo' 'Puerto Rico-Naranjito'
#  'Puerto Rico-Orocovis' 'Puerto Rico-Patillas' 'Puerto Rico-Penuelas'
#  'Puerto Rico-Ponce' 'Puerto Rico-Quebradillas' 'Puerto Rico-Rincon'
#  'Puerto Rico-Rio Grande' 'Puerto Rico-Sabana Grande'
#  'Puerto Rico-Salinas' 'Puerto Rico-San German' 'Puerto Rico-San Juan'
#  'Puerto Rico-San Lorenzo' 'Puerto Rico-San Sebastian'
#  'Puerto Rico-Santa Isabel' 'Puerto Rico-Toa Alta' 'Puerto Rico-Toa Baja'
#  'Puerto Rico-Trujillo Alto' 'Puerto Rico-Utuado' 'Puerto Rico-Vega Alta'
#  'Puerto Rico-Vega Baja' 'Puerto Rico-Villalba' 'Puerto Rico-Yabucoa'
#  'Puerto Rico-Yauco' 'Nebraska-Thomas' 'South Dakota-Grant'
#  'South Dakota-Ziebach' 'North Dakota-Benson' 'North Dakota-Traill'
#  'Puerto Rico-Vieques' 'Utah-Piute' 'Iowa-Fremont' 'Iowa-Palo Alto'
#  'Nebraska-Dawes' 'Iowa-Ida' 'Iowa-Emmet' 'Nebraska-Richardson'
#  'Oklahoma-Washita' 'South Dakota-Tripp' 'Arkansas-Little River'
#  'Nebraska-Nuckolls' 'Puerto Rico-Maricao' 'Iowa-Adams' 'Iowa-Lucas'
#  'North Dakota-Steele' 'Iowa-Ringgold' 'North Dakota-Bottineau'
#  'Oklahoma-Coal' 'Wyoming-Platte' 'North Dakota-Griggs' 'Nebraska-Chase'
#  'South Dakota-Jackson' 'Iowa-Decatur' 'Wyoming-Weston' 'Nebraska-Thayer'
#  'Oklahoma-Hughes' 'Puerto Rico-Culebra' 'South Dakota-Edmunds'
#  'South Dakota-Kingsbury' 'South Dakota-Gregory' 'Nebraska-Boyd'
#  'Nebraska-Garden' 'North Dakota-Dickey' 'South Dakota-Brule'
#  'South Dakota-Hanson' 'South Dakota-Custer' 'Nebraska-Garfield'
#  'North Dakota-LaMoure' 'North Dakota-Sheridan' 'South Dakota-Dewey'
#  'Nebraska-Banner' 'North Dakota-Kidder' 'Nebraska-Sioux' 'Utah-Rich'
#  'South Dakota-Mellette' 'South Dakota-Bennett' 'Utah-Beaver'
#  'North Dakota-Billings' 'North Dakota-Cavalier' 'Oklahoma-Ellis'
#  'Nebraska-Harlan' 'Nebraska-Rock' 'Nebraska-Sheridan'
#  'North Dakota-Hettinger' 'Nebraska-Hooker' 'Oklahoma-Harmon'
#  'Arkansas-Calhoun' 'South Dakota-Campbell' 'South Dakota-Haakon'
#  'North Dakota-Towner' 'North Dakota-Logan' 'South Dakota-Butte'
#  'South Dakota-Jones' 'Nebraska-McPherson' 'Oklahoma-Roger Mills'
#  'Nebraska-Pawnee' 'South Dakota-Perkins' 'Nebraska-Deuel'
#  'North Dakota-Golden Valley' 'Northern Mariana Islands-Saipan'
#  'Northern Mariana Islands-Tinian' 'Nebraska-Dundy' 'Nebraska-Perkins'
#  'South Dakota-Potter' 'Nebraska-Wheeler' 'Utah-Wayne'
#  'North Dakota-Adams' 'Nebraska-Arthur' 'Nebraska-Brown'
#  'South Dakota-Harding' 'Nebraska-Keya Paha' 'Nebraska-Logan'
#  'Nebraska-Loup' 'Utah-Daggett' 'Nebraska-Grant' 'Nebraska-Blaine'
#  'Nebraska-Hayes']
# Entities where all values for 'date_stay_at_home_effective' are NaN: ['Nebraska-Douglas' 'Utah-Salt Lake' 'Oklahoma-Tulsa'
#  'South Carolina-Charleston' 'South Carolina-Kershaw' 'Utah-Davis'
#  'Utah-Washington' 'Iowa-Johnson' 'South Carolina-Spartanburg'
#  'Iowa-Pottawattamie' 'South Dakota-Beadle' 'South Dakota-Charles Mix'
#  'South Dakota-Davison' 'South Dakota-Minnehaha' 'Utah-Weber'
#  'Arkansas-Jefferson' 'North Dakota-Ward' 'South Carolina-Lancaster'
#  'South Dakota-Bon Homme' 'Wyoming-Sheridan' 'Arkansas-Pulaski'
#  'Iowa-Carroll' 'Nebraska-Cass' 'Iowa-Harrison' 'Oklahoma-Oklahoma'
#  'South Dakota-McCook' 'Wyoming-Fremont' 'Iowa-Dallas' 'Oklahoma-Jackson'
#  'South Carolina-Beaufort' 'South Carolina-Lexington' 'Utah-Summit'
#  'Arkansas-Garland' 'Arkansas-Saline' 'Iowa-Allamakee' 'Iowa-Polk'
#  'Oklahoma-Cleveland' 'Oklahoma-Kay' 'Oklahoma-Payne'
#  'South Carolina-Anderson' 'South Carolina-Greenville'
#  'South Carolina-Horry' 'Utah-Utah' 'Arkansas-Cleburne'
#  'Arkansas-Cleveland' 'Arkansas-Desha' 'Arkansas-Lincoln'
#  'Oklahoma-Canadian' 'South Carolina-Fairfield' 'Utah-Tooele'
#  'Utah-Wasatch' 'Iowa-Adair' 'Iowa-Black Hawk' 'Nebraska-Knox'
#  'Nebraska-Sarpy' 'North Dakota-Burleigh' 'North Dakota-Cass'
#  'Oklahoma-Pawnee' 'South Carolina-Calhoun' 'South Carolina-Richland'
#  'South Carolina-York' 'Wyoming-Laramie' 'Wyoming-Park' 'Arkansas-Bradley'
#  'Arkansas-Faulkner' 'Arkansas-Washington' 'Iowa-Washington'
#  'Iowa-Winneshiek' 'Nebraska-Adams' 'Nebraska-Lincoln'
#  'North Dakota-Morton' 'South Carolina-Lee' 'Utah-Box Elder' 'Utah-Cache'
#  'Wyoming-Teton' 'Arkansas-Benton' 'Arkansas-Boone' 'Arkansas-Clark'
#  'Arkansas-Craighead' 'Arkansas-Crittenden' 'Arkansas-Grant'
#  'Arkansas-Greene' 'Arkansas-Independence' 'Arkansas-Poinsett'
#  'Arkansas-Polk' 'Arkansas-Pope' 'Arkansas-Searcy' 'Arkansas-Sebastian'
#  'Arkansas-Sevier' 'Arkansas-Van Buren' 'Iowa-Dubuque' 'Iowa-Muscatine'
#  'Nebraska-Nemaha' 'Oklahoma-Custer' 'Oklahoma-Grady' 'Oklahoma-Logan'
#  'Oklahoma-McClain' 'Oklahoma-Washington' 'South Carolina-Abbeville'
#  'South Carolina-Dorchester' 'South Carolina-Saluda' 'Nebraska-Buffalo'
#  'Nebraska-Lancaster' 'North Dakota-Pierce' 'North Dakota-Ramsey'
#  'Oklahoma-Garvin' 'South Carolina-Aiken' 'South Carolina-Berkeley'
#  'South Carolina-Clarendon' 'South Carolina-Darlington'
#  'South Carolina-Florence' 'South Carolina-Orangeburg'
#  'South Carolina-Pickens' 'South Carolina-Sumter' 'Wyoming-Campbell'
#  'Wyoming-Natrona' 'Iowa-Fayette' 'Iowa-Henry' 'Iowa-Linn' 'Iowa-Story'
#  'South Carolina-Dillon' 'South Carolina-Edgefield'
#  'South Carolina-Greenwood' 'South Carolina-Jasper'
#  'South Carolina-Marlboro' 'South Carolina-Newberry' 'Wyoming-Carbon'
#  'Iowa-Cerro Gordo' 'Iowa-Kossuth' 'Iowa-Poweshiek' 'Iowa-Scott'
#  'Iowa-Sioux' 'Iowa-Tama' 'Iowa-Woodbury' 'Nebraska-Dawson'
#  'Oklahoma-Muskogee' 'Oklahoma-Noble' 'South Carolina-Colleton'
#  'South Dakota-Brown' 'Iowa-Hancock' 'Iowa-Wapello' 'Nebraska-Madison'
#  'Nebraska-Washington' 'North Dakota-Walsh' 'Oklahoma-Pontotoc'
#  'South Carolina-Chester' 'South Carolina-Georgetown'
#  'South Carolina-Oconee' 'South Dakota-Codington' 'South Dakota-Hughes'
#  'South Dakota-Lyman' 'South Dakota-Pennington' 'Utah-Iron'
#  'Arkansas-Columbia' 'Arkansas-Conway' 'Arkansas-Crawford'
#  'Arkansas-Cross' 'Arkansas-Hot Spring' 'Arkansas-Lawrence'
#  'Arkansas-Pike' 'Arkansas-Stone' 'Arkansas-Union' 'Arkansas-White'
#  'Arkansas-Woodruff' 'Iowa-Buchanan' 'Iowa-Cedar' 'Iowa-Jasper'
#  'Iowa-Warren' 'Nebraska-Saunders' 'North Dakota-Dunn' 'Oklahoma-Mayes'
#  'Oklahoma-Wagoner' 'South Carolina-Chesterfield' 'South Dakota-Brookings'
#  'Wyoming-Sweetwater' 'Arkansas-Drew' 'Iowa-Benton' 'Nebraska-Dodge'
#  'North Dakota-Foster' 'North Dakota-Stark' 'Oklahoma-Adair'
#  'Oklahoma-Bryan' 'Oklahoma-Carter' 'Oklahoma-Creek' 'Oklahoma-Delaware'
#  'Oklahoma-Osage' 'Oklahoma-Pottawatomie' 'Oklahoma-Stephens'
#  'South Carolina-Marion' 'South Carolina-Union'
#  'South Carolina-Williamsburg' 'South Dakota-Lincoln' 'South Dakota-Meade'
#  'Wyoming-Albany' 'Arkansas-Chicot' 'Arkansas-Howard' 'Arkansas-Lonoke'
#  'Arkansas-Randolph' 'Iowa-Appanoose' 'Iowa-Clayton' 'Iowa-Des Moines'
#  'Iowa-Mahaska' 'Iowa-Monona' 'Iowa-Page' 'Nebraska-Hall'
#  'Nebraska-Kearney' 'North Dakota-McHenry' 'North Dakota-McIntosh'
#  'Oklahoma-Comanche' 'Oklahoma-Craig' 'Oklahoma-Lincoln'
#  'Oklahoma-Okmulgee' 'Oklahoma-Ottawa' 'Oklahoma-Sequoyah' 'Utah-Morgan'
#  'Wyoming-Hot Springs' 'Wyoming-Johnson' 'Arkansas-Baxter' 'Iowa-Butler'
#  'Iowa-Clinton' 'Iowa-Dickinson' 'Iowa-Hardin' 'Iowa-Iowa' 'Iowa-Marshall'
#  'Iowa-Montgomery' 'Iowa-Webster' 'Iowa-Wright' 'Oklahoma-Caddo'
#  'Oklahoma-Cherokee' 'Oklahoma-Choctaw' 'Oklahoma-Latimer'
#  'Oklahoma-Pittsburg' 'South Dakota-Aurora' 'South Dakota-Faulk'
#  'South Dakota-Lawrence' 'South Dakota-Todd' 'South Dakota-Union'
#  'Utah-Uintah' 'Wyoming-Goshen' 'Wyoming-Washakie' 'Arkansas-Johnson'
#  'Iowa-Boone' 'Iowa-Keokuk' 'Iowa-Shelby' 'Iowa-Taylor' 'Nebraska-Gosper'
#  'Nebraska-Platte' 'North Dakota-Barnes' 'North Dakota-Divide'
#  'North Dakota-McLean' 'North Dakota-Mountrail' 'North Dakota-Sioux'
#  'Oklahoma-Le Flore' 'Oklahoma-Nowata' 'South Carolina-Laurens'
#  'South Dakota-Deuel' 'South Dakota-Hamlin' 'South Dakota-Hutchinson'
#  'South Dakota-Yankton' 'Utah-Garfield' 'Utah-San Juan' 'Wyoming-Converse'
#  'Wyoming-Sublette' 'Arkansas-Arkansas' 'Arkansas-Ashley'
#  'Arkansas-Hempstead' 'Arkansas-Nevada' 'Arkansas-Perry'
#  'Nebraska-Scotts Bluff' 'Oklahoma-Garfield' 'Oklahoma-Rogers'
#  'Oklahoma-Seminole' 'Oklahoma-Texas' 'South Dakota-Clark'
#  'South Dakota-Clay' 'South Dakota-Fall River' 'South Dakota-Roberts'
#  'South Dakota-Turner' 'Arkansas-Newton' 'Arkansas-St. Francis'
#  'Iowa-Audubon' 'Iowa-Crawford' 'Iowa-Guthrie' 'Iowa-Jackson' 'Iowa-Jones'
#  'Iowa-Van Buren' 'Nebraska-Antelope' 'Nebraska-York'
#  'North Dakota-Grand Forks' 'North Dakota-Oliver' 'Oklahoma-Beckham'
#  'Oklahoma-Cotton' 'Oklahoma-Love' 'South Carolina-Barnwell'
#  'South Dakota-Marshall' 'Arkansas-Miller' 'Arkansas-Scott' 'Iowa-Clay'
#  'Nebraska-Kimball' 'North Dakota-Grant' 'North Dakota-McKenzie'
#  'North Dakota-Williams' 'South Carolina-Bamberg' 'Arkansas-Carroll'
#  'Arkansas-Lee' 'Iowa-Madison' 'Iowa-Mitchell' 'Nebraska-Cuming'
#  'North Dakota-Burke' 'Oklahoma-Greer' 'South Carolina-Allendale'
#  'Arkansas-Mississippi' 'Arkansas-Monroe' 'Arkansas-Ouachita'
#  'Arkansas-Sharp' 'Iowa-Bremer' 'Iowa-Jefferson' "Iowa-O'Brien"
#  'Nebraska-Colfax' 'Nebraska-Gage' 'Nebraska-Hamilton' 'Nebraska-Otoe'
#  'Oklahoma-Atoka' 'Oklahoma-Kingfisher' 'Oklahoma-Kiowa'
#  'Oklahoma-Woodward' 'South Carolina-Cherokee' 'South Carolina-Hampton'
#  'South Carolina-McCormick' 'South Dakota-Lake' 'South Dakota-Spink'
#  'Utah-Kane' 'Wyoming-Uinta' 'Arkansas-Lafayette' 'Arkansas-Prairie'
#  'Iowa-Louisa' 'Iowa-Lyon' 'Iowa-Plymouth' 'Nebraska-Merrick'
#  'North Dakota-Eddy' 'North Dakota-Slope' 'Oklahoma-Grant'
#  'Oklahoma-Major' 'Oklahoma-McCurtain' 'Utah-Carbon' 'Utah-Duchesne'
#  'Utah-Emery' 'Utah-Grand' 'Utah-Juab' 'Utah-Millard' 'Wyoming-Lincoln'
#  'Arkansas-Dallas' 'Iowa-Grundy' 'Iowa-Howard' 'Iowa-Lee' 'Iowa-Mills'
#  'Nebraska-Cherry' 'Oklahoma-Tillman' 'Wyoming-Crook' 'Arkansas-Phillips'
#  'Arkansas-Yell' 'Iowa-Clarke' 'Iowa-Hamilton' 'Nebraska-Johnson'
#  'Nebraska-Phelps' 'Nebraska-Seward' 'North Dakota-Emmons' 'Arkansas-Clay'
#  'Arkansas-Franklin' 'Arkansas-Izard' 'Arkansas-Logan' 'Iowa-Chickasaw'
#  'Iowa-Franklin' 'Iowa-Marion' 'Iowa-Winnebago' 'Nebraska-Cheyenne'
#  'Nebraska-Custer' 'Nebraska-Stanton' 'Oklahoma-Jefferson'
#  'Virgin Islands-St. Croix' 'Virgin Islands-St. John'
#  'Virgin Islands-St. Thomas' 'Iowa-Buena Vista' 'Iowa-Delaware'
#  'Iowa-Greene' 'North Dakota-Bowman' 'Oklahoma-Beaver' 'Oklahoma-Dewey'
#  'Oklahoma-Marshall' 'Arkansas-Madison' 'Iowa-Worth'
#  'North Dakota-Stutsman' 'South Dakota-Oglala Lakota' 'Nebraska-Burt'
#  'Nebraska-Polk' 'North Dakota-Richland' 'South Dakota-Corson'
#  'South Dakota-Jerauld' 'Arkansas-Marion' 'Iowa-Osceola' 'Iowa-Union'
#  'Nebraska-Clay' 'Nebraska-Franklin' 'Nebraska-Webster'
#  'North Dakota-Sargent' 'Oklahoma-Murray' 'Oklahoma-Okfuskee'
#  'South Dakota-Miner' 'Wyoming-Niobrara' 'Nebraska-Box Butte'
#  'Nebraska-Pierce' 'Nebraska-Wayne' 'North Dakota-Rolette'
#  'South Dakota-Sanborn' 'Nebraska-Dakota' 'South Dakota-Sully'
#  'South Dakota-Walworth' 'Wyoming-Big Horn' 'Arkansas-Jackson' 'Iowa-Cass'
#  'Oklahoma-Alfalfa' 'South Dakota-Hyde' 'Nebraska-Saline'
#  'Oklahoma-Johnston' 'Nebraska-Morrill' 'Utah-Sevier' 'Nebraska-Howard'
#  'Nebraska-Nance' 'South Dakota-Moody' 'Nebraska-Butler'
#  'Nebraska-Red Willow' 'Oklahoma-Haskell' 'Oklahoma-McIntosh'
#  'Oklahoma-Woods' 'Nebraska-Furnas' 'Oklahoma-Harper' 'Utah-Sanpete'
#  'North Dakota-Nelson' 'Nebraska-Dixon' 'Iowa-Cherokee' 'Iowa-Humboldt'
#  'Oklahoma-Cimarron' 'Nebraska-Fillmore' 'North Dakota-Wells'
#  'Arkansas-Fulton' 'Nebraska-Greeley' 'Nebraska-Sherman'
#  'South Dakota-Stanley' 'Nebraska-Thurston' 'North Dakota-Pembina'
#  'South Dakota-McPherson' 'Nebraska-Jefferson' 'North Dakota-Ransom'
#  'South Dakota-Hand' 'Iowa-Pocahontas' 'Nebraska-Cedar' 'Nebraska-Valley'
#  'Oklahoma-Pushmataha' 'South Dakota-Douglas' 'Arkansas-Montgomery'
#  'South Dakota-Buffalo' 'Iowa-Davis' 'Nebraska-Frontier'
#  'South Dakota-Day' 'Nebraska-Hitchcock' 'Iowa-Calhoun' 'Iowa-Floyd'
#  'Iowa-Sac' 'Iowa-Wayne' 'North Dakota-Renville' 'Nebraska-Keith'
#  'Iowa-Monroe' 'Nebraska-Holt' 'Nebraska-Boone' 'Oklahoma-Blaine'
#  'North Dakota-Mercer' 'Puerto Rico-Adjuntas' 'Puerto Rico-Aguada'
#  'Puerto Rico-Aguadilla' 'Puerto Rico-Aguas Buenas' 'Puerto Rico-Aibonito'
#  'Puerto Rico-Anasco' 'Puerto Rico-Arecibo' 'Puerto Rico-Arroyo'
#  'Puerto Rico-Barceloneta' 'Puerto Rico-Barranquitas'
#  'Puerto Rico-Bayamon' 'Puerto Rico-Cabo Rojo' 'Puerto Rico-Caguas'
#  'Puerto Rico-Camuy' 'Puerto Rico-Canovanas' 'Puerto Rico-Carolina'
#  'Puerto Rico-Catano' 'Puerto Rico-Cayey' 'Puerto Rico-Ceiba'
#  'Puerto Rico-Ciales' 'Puerto Rico-Cidra' 'Puerto Rico-Coamo'
#  'Puerto Rico-Comerio' 'Puerto Rico-Corozal' 'Puerto Rico-Dorado'
#  'Puerto Rico-Fajardo' 'Puerto Rico-Florida' 'Puerto Rico-Guanica'
#  'Puerto Rico-Guayama' 'Puerto Rico-Guayanilla' 'Puerto Rico-Guaynabo'
#  'Puerto Rico-Gurabo' 'Puerto Rico-Hatillo' 'Puerto Rico-Hormigueros'
#  'Puerto Rico-Humacao' 'Puerto Rico-Isabela' 'Puerto Rico-Jayuya'
#  'Puerto Rico-Juana Diaz' 'Puerto Rico-Juncos' 'Puerto Rico-Lajas'
#  'Puerto Rico-Lares' 'Puerto Rico-Las Marias' 'Puerto Rico-Las Piedras'
#  'Puerto Rico-Loiza' 'Puerto Rico-Luquillo' 'Puerto Rico-Manati'
#  'Puerto Rico-Maunabo' 'Puerto Rico-Mayaguez' 'Puerto Rico-Moca'
#  'Puerto Rico-Morovis' 'Puerto Rico-Naguabo' 'Puerto Rico-Naranjito'
#  'Puerto Rico-Orocovis' 'Puerto Rico-Patillas' 'Puerto Rico-Penuelas'
#  'Puerto Rico-Ponce' 'Puerto Rico-Quebradillas' 'Puerto Rico-Rincon'
#  'Puerto Rico-Rio Grande' 'Puerto Rico-Sabana Grande'
#  'Puerto Rico-Salinas' 'Puerto Rico-San German' 'Puerto Rico-San Juan'
#  'Puerto Rico-San Lorenzo' 'Puerto Rico-San Sebastian'
#  'Puerto Rico-Santa Isabel' 'Puerto Rico-Toa Alta' 'Puerto Rico-Toa Baja'
#  'Puerto Rico-Trujillo Alto' 'Puerto Rico-Utuado' 'Puerto Rico-Vega Alta'
#  'Puerto Rico-Vega Baja' 'Puerto Rico-Villalba' 'Puerto Rico-Yabucoa'
#  'Puerto Rico-Yauco' 'Nebraska-Thomas' 'South Dakota-Grant'
#  'South Dakota-Ziebach' 'North Dakota-Benson' 'North Dakota-Traill'
#  'Puerto Rico-Vieques' 'Utah-Piute' 'Iowa-Fremont' 'Iowa-Palo Alto'
#  'Nebraska-Dawes' 'Iowa-Ida' 'Iowa-Emmet' 'Nebraska-Richardson'
#  'Oklahoma-Washita' 'South Dakota-Tripp' 'Arkansas-Little River'
#  'Nebraska-Nuckolls' 'Puerto Rico-Maricao' 'Iowa-Adams' 'Iowa-Lucas'
#  'North Dakota-Steele' 'Iowa-Ringgold' 'North Dakota-Bottineau'
#  'Oklahoma-Coal' 'Wyoming-Platte' 'North Dakota-Griggs' 'Nebraska-Chase'
#  'South Dakota-Jackson' 'Iowa-Decatur' 'Wyoming-Weston' 'Nebraska-Thayer'
#  'Oklahoma-Hughes' 'Puerto Rico-Culebra' 'South Dakota-Edmunds'
#  'South Dakota-Kingsbury' 'South Dakota-Gregory' 'Nebraska-Boyd'
#  'Nebraska-Garden' 'North Dakota-Dickey' 'South Dakota-Brule'
#  'South Dakota-Hanson' 'South Dakota-Custer' 'Nebraska-Garfield'
#  'North Dakota-LaMoure' 'North Dakota-Sheridan' 'South Dakota-Dewey'
#  'Nebraska-Banner' 'North Dakota-Kidder' 'Nebraska-Sioux' 'Utah-Rich'
#  'South Dakota-Mellette' 'South Dakota-Bennett' 'Utah-Beaver'
#  'North Dakota-Billings' 'North Dakota-Cavalier' 'Oklahoma-Ellis'
#  'Nebraska-Harlan' 'Nebraska-Rock' 'Nebraska-Sheridan'
#  'North Dakota-Hettinger' 'Nebraska-Hooker' 'Oklahoma-Harmon'
#  'Arkansas-Calhoun' 'South Dakota-Campbell' 'South Dakota-Haakon'
#  'North Dakota-Towner' 'North Dakota-Logan' 'South Dakota-Butte'
#  'South Dakota-Jones' 'Nebraska-McPherson' 'Oklahoma-Roger Mills'
#  'Nebraska-Pawnee' 'South Dakota-Perkins' 'Nebraska-Deuel'
#  'North Dakota-Golden Valley' 'Northern Mariana Islands-Saipan'
#  'Northern Mariana Islands-Tinian' 'Nebraska-Dundy' 'Nebraska-Perkins'
#  'South Dakota-Potter' 'Nebraska-Wheeler' 'Utah-Wayne'
#  'North Dakota-Adams' 'Nebraska-Arthur' 'Nebraska-Brown'
#  'South Dakota-Harding' 'Nebraska-Keya Paha' 'Nebraska-Logan'
#  'Nebraska-Loup' 'Utah-Daggett' 'Nebraska-Grant' 'Nebraska-Blaine'
#  'Nebraska-Hayes']

# %%
# Get a list of all column names excluding 'entity'
to_check = sub_data.columns[sub_data.columns != 'entity']

# Dictionary to store entities for each column
entities_all_na_by_col = {}

# Iterate over each column
for col in to_check:
    # Find entities where all values for the current column are NaN
    entities_all_na = sub_data[sub_data[col].isna()]['entity'].unique()
    entities_all_na_by_col[col] = set(entities_all_na)

# Find common entities across all columns
common_entities = set.intersection(*entities_all_na_by_col.values())

print(common_entities)
# Out:
# {'Puerto Rico-Guaynabo', 'Puerto Rico-Sabana Grande', 'Puerto Rico-Toa Baja', 'Puerto Rico-Ciales', 'Puerto Rico-Luquillo', 'Puerto Rico-Cayey', 'Puerto Rico-San German', 'Puerto Rico-Santa Isabel', 'Puerto Rico-Camuy', 'Puerto Rico-Ponce', 'Puerto Rico-Quebradillas', 'Puerto Rico-Vega Baja', 'Puerto Rico-Culebra', 'Puerto Rico-Ceiba', 'Virgin Islands-St. Thomas', 'Puerto Rico-San Lorenzo', 'Puerto Rico-Jayuya', 'Puerto Rico-Fajardo', 'Puerto Rico-Aguadilla', 'Puerto Rico-Morovis', 'Puerto Rico-Loiza', 'Puerto Rico-Barranquitas', 'Puerto Rico-Manati', 'Puerto Rico-San Juan', 'Puerto Rico-Coamo', 'Puerto Rico-Vega Alta', 'Puerto Rico-Lajas', 'Puerto Rico-Gurabo', 'Puerto Rico-Anasco', 'Puerto Rico-Corozal', 'Virgin Islands-St. John', 'Puerto Rico-Canovanas', 'Puerto Rico-Trujillo Alto', 'Puerto Rico-Moca', 'Puerto Rico-Salinas', 'Puerto Rico-Comerio', 'Puerto Rico-Rincon', 'Puerto Rico-Maunabo', 'Puerto Rico-Yauco', 'Puerto Rico-Cabo Rojo', 'Puerto Rico-Arroyo', 'Puerto Rico-Juana Diaz', 'Puerto Rico-Villalba', 'Puerto Rico-Isabela', 'Puerto Rico-Penuelas', 'Puerto Rico-Hatillo', 'Puerto Rico-Mayaguez', 'Puerto Rico-Toa Alta', 'Puerto Rico-Patillas', 'Puerto Rico-Catano', 'Puerto Rico-Orocovis', 'Puerto Rico-Vieques', 'Virgin Islands-St. Croix', 'Puerto Rico-Caguas', 'Puerto Rico-Hormigueros', 'Northern Mariana Islands-Tinian', 'Puerto Rico-Guanica', 'Puerto Rico-Juncos', 'Puerto Rico-Aguas Buenas', 'Puerto Rico-Utuado', 'Puerto Rico-Guayanilla', 'Puerto Rico-Adjuntas', 'Puerto Rico-Barceloneta', 'Puerto Rico-Florida', 'Puerto Rico-Guayama', 'Puerto Rico-Las Piedras', 'Puerto Rico-Naguabo', 'Puerto Rico-Dorado', 'Puerto Rico-Bayamon', 'Northern Mariana Islands-Saipan', 'Puerto Rico-Aibonito', 'Puerto Rico-Cidra', 'Puerto Rico-Arecibo', 'Puerto Rico-Maricao', 'Puerto Rico-Aguada', 'Puerto Rico-Las Marias', 'Puerto Rico-Humacao', 'Puerto Rico-Yabucoa', 'Puerto Rico-Rio Grande', 'Puerto Rico-Naranjito', 'Puerto Rico-Carolina', 'Puerto Rico-Lares', 'Puerto Rico-San Sebastian'}

# %%
len(common_entities)
# Out:
# 83

# %%
na_percentage = sub_data.isna().mean() * 100
print(na_percentage)
# Out:
# percentile_rank_age_65_and_older                        2.256649
# percentile_rank_age_17_and_younger                      2.256649
# percentile_rank_disabled                                2.256649
# percentile_rank_single_parent_households                2.256649
# percentile_rank_household_comp_disability_theme         2.256649
# percentile_rank_minorities                              2.256649
# percentile_rank_limited_english_abilities               2.256649
# percentile_rank_minority_status_and_language_theme      2.256649
# percentile_rank_multi_unit_housing                      2.256649
# percentile_rank_mobile_homes                            2.256649
# percentile_rank_overcrowding                            2.256649
# percentile_rank_no_vehicle                              2.256649
# percentile_rank_institutionalized_in_group_quarters     2.256649
# percentile_rank_housing_and_transportation              2.256649
# percentile_rank_social_vulnerability                    2.256649
# km_to_closest_station                                   2.256649
# CALL                                                   10.674009
# ELEV_M                                                  2.256649
# station_id                                              4.332235
# station_name                                            4.332235
# mean_temp                                               4.332868
# min_temp                                                4.352480
# max_temp                                                4.456614
# dewpoint                                               11.075866
# sea_level_pressure                                     49.020727
# station_pressure                                       17.078794
# visibility                                             12.514503
# wind_speed                                              8.761392
# max_wind_speed                                          9.194122
# wind_gust                                              42.221803
# precipitation                                          13.517121
# precip_flag                                            13.517121
# fog                                                     4.332235
# rain                                                    4.332235
# snow                                                    4.332235
# hail                                                    4.332235
# thunder                                                 4.332235
# tornado                                                 4.332235
# mean_temp_3d_avg                                        4.730423
# mean_temp_5d_avg                                        5.127978
# mean_temp_10d_avg                                       6.320137
# mean_temp_15d_avg                                       7.115753
# max_temp_3d_avg                                         5.058767
# max_temp_5d_avg                                         5.649658
# max_temp_10d_avg                                        7.277584
# max_temp_15d_avg                                        8.482269
# min_temp_3d_avg                                         4.773823
# min_temp_5d_avg                                         5.193014
# min_temp_10d_avg                                        6.433887
# min_temp_15d_avg                                        7.274294
# dewpoint_3d_avg                                        11.545669
# dewpoint_5d_avg                                        11.999403
# dewpoint_10d_avg                                       13.266087
# dewpoint_15d_avg                                       14.131927
# date_stay_at_home_announced                            19.120090
# date_stay_at_home_effective                            19.120090
# entity                                                  0.000000
# dtype: float64

# %%
features_to_drop = ['wind_gust', 'sea_level_pressure']

# Drop rows where entity is in common entities
sub_data_filtered = sub_data[~sub_data['entity'].isin(common_entities)]


# Calculate the percentage of NaN values for each column in the filtered DataFrame
na_percentage_filtered = sub_data_filtered.isna().mean() * 100

print(na_percentage_filtered)
# Out:
# percentile_rank_age_65_and_older                        0.021096
# percentile_rank_age_17_and_younger                      0.021096
# percentile_rank_disabled                                0.021096
# percentile_rank_single_parent_households                0.021096
# percentile_rank_household_comp_disability_theme         0.021096
# percentile_rank_minorities                              0.021096
# percentile_rank_limited_english_abilities               0.021096
# percentile_rank_minority_status_and_language_theme      0.021096
# percentile_rank_multi_unit_housing                      0.021096
# percentile_rank_mobile_homes                            0.021096
# percentile_rank_overcrowding                            0.021096
# percentile_rank_no_vehicle                              0.021096
# percentile_rank_institutionalized_in_group_quarters     0.021096
# percentile_rank_housing_and_transportation              0.021096
# percentile_rank_social_vulnerability                    0.021096
# km_to_closest_station                                   0.021096
# CALL                                                    8.630974
# ELEV_M                                                  0.021096
# station_id                                              2.144154
# station_name                                            2.144154
# mean_temp                                               2.144801
# min_temp                                                2.164862
# max_temp                                                2.271377
# dewpoint                                                9.042022
# sea_level_pressure                                     47.854746
# station_pressure                                       15.182247
# visibility                                             10.513564
# wind_speed                                              6.674613
# max_wind_speed                                          7.117241
# wind_gust                                              40.900320
# precipitation                                          11.539114
# precip_flag                                            11.539114
# fog                                                     2.144154
# rain                                                    2.144154
# snow                                                    2.144154
# hail                                                    2.144154
# thunder                                                 2.144154
# tornado                                                 2.144154
# mean_temp_3d_avg                                        2.551449
# mean_temp_5d_avg                                        2.958097
# mean_temp_10d_avg                                       4.177522
# mean_temp_15d_avg                                       4.991335
# max_temp_3d_avg                                         2.887302
# max_temp_5d_avg                                         3.491709
# max_temp_10d_avg                                        5.156867
# max_temp_15d_avg                                        6.389106
# min_temp_3d_avg                                         2.595841
# min_temp_5d_avg                                         3.024620
# min_temp_10d_avg                                        4.293873
# min_temp_15d_avg                                        5.153502
# dewpoint_3d_avg                                         9.522571
# dewpoint_5d_avg                                         9.986682
# dewpoint_10d_avg                                       11.282338
# dewpoint_15d_avg                                       12.167981
# date_stay_at_home_announced                            17.270232
# date_stay_at_home_effective                            17.270232
# entity                                                  0.000000
# dtype: float64

# %%
features_to_drop = ['wind_gust', 'sea_level_pressure']

# Drop rows where entity is in common entities
sub_data_filtered = sub_data[~sub_data['entity'].isin(common_entities)]

# Drop specific features
sub_data_filtered = sub_data_filtered.drop(features_to_drop, axis=1)

# Calculate the percentage of NaN values for each column in the filtered DataFrame
na_percentage_filtered = sub_data_filtered.isna().mean() * 100

print(na_percentage_filtered)
# Out:
# percentile_rank_age_65_and_older                        0.021096
# percentile_rank_age_17_and_younger                      0.021096
# percentile_rank_disabled                                0.021096
# percentile_rank_single_parent_households                0.021096
# percentile_rank_household_comp_disability_theme         0.021096
# percentile_rank_minorities                              0.021096
# percentile_rank_limited_english_abilities               0.021096
# percentile_rank_minority_status_and_language_theme      0.021096
# percentile_rank_multi_unit_housing                      0.021096
# percentile_rank_mobile_homes                            0.021096
# percentile_rank_overcrowding                            0.021096
# percentile_rank_no_vehicle                              0.021096
# percentile_rank_institutionalized_in_group_quarters     0.021096
# percentile_rank_housing_and_transportation              0.021096
# percentile_rank_social_vulnerability                    0.021096
# km_to_closest_station                                   0.021096
# CALL                                                    8.630974
# ELEV_M                                                  0.021096
# station_id                                              2.144154
# station_name                                            2.144154
# mean_temp                                               2.144801
# min_temp                                                2.164862
# max_temp                                                2.271377
# dewpoint                                                9.042022
# station_pressure                                       15.182247
# visibility                                             10.513564
# wind_speed                                              6.674613
# max_wind_speed                                          7.117241
# precipitation                                          11.539114
# precip_flag                                            11.539114
# fog                                                     2.144154
# rain                                                    2.144154
# snow                                                    2.144154
# hail                                                    2.144154
# thunder                                                 2.144154
# tornado                                                 2.144154
# mean_temp_3d_avg                                        2.551449
# mean_temp_5d_avg                                        2.958097
# mean_temp_10d_avg                                       4.177522
# mean_temp_15d_avg                                       4.991335
# max_temp_3d_avg                                         2.887302
# max_temp_5d_avg                                         3.491709
# max_temp_10d_avg                                        5.156867
# max_temp_15d_avg                                        6.389106
# min_temp_3d_avg                                         2.595841
# min_temp_5d_avg                                         3.024620
# min_temp_10d_avg                                        4.293873
# min_temp_15d_avg                                        5.153502
# dewpoint_3d_avg                                         9.522571
# dewpoint_5d_avg                                         9.986682
# dewpoint_10d_avg                                       11.282338
# dewpoint_15d_avg                                       12.167981
# date_stay_at_home_announced                            17.270232
# date_stay_at_home_effective                            17.270232
# entity                                                  0.000000
# dtype: float64

# %%
percentile_features = [col for col in sub_data_filtered.columns if 'percentile' in col.lower()]

# Find entities where all values for percentile features are NaN
entities_all_na_percentile = sub_data_filtered[sub_data_filtered[percentile_features].isna().all(axis=1)]['entity'].unique()

print(entities_all_na_percentile)
# Out:
# ['Missouri-Joplin']

# %%
sub_data_filtered_2 = sub_data_filtered[sub_data_filtered['entity']!='Missouri-Joplin']

# %%
na_percentage_filtered_2 = sub_data_filtered_2.isna().mean() * 100

print(na_percentage_filtered_2)
# Out:
# percentile_rank_age_65_and_older                        0.000000
# percentile_rank_age_17_and_younger                      0.000000
# percentile_rank_disabled                                0.000000
# percentile_rank_single_parent_households                0.000000
# percentile_rank_household_comp_disability_theme         0.000000
# percentile_rank_minorities                              0.000000
# percentile_rank_limited_english_abilities               0.000000
# percentile_rank_minority_status_and_language_theme      0.000000
# percentile_rank_multi_unit_housing                      0.000000
# percentile_rank_mobile_homes                            0.000000
# percentile_rank_overcrowding                            0.000000
# percentile_rank_no_vehicle                              0.000000
# percentile_rank_institutionalized_in_group_quarters     0.000000
# percentile_rank_housing_and_transportation              0.000000
# percentile_rank_social_vulnerability                    0.000000
# km_to_closest_station                                   0.000000
# CALL                                                    8.611695
# ELEV_M                                                  0.000000
# station_id                                              2.123506
# station_name                                            2.123506
# mean_temp                                               2.124153
# min_temp                                                2.144218
# max_temp                                                2.250756
# dewpoint                                                9.022830
# station_pressure                                       15.164350
# visibility                                             10.494682
# wind_speed                                              6.654921
# max_wind_speed                                          7.097642
# precipitation                                          11.520448
# precip_flag                                            11.520448
# fog                                                     2.123506
# rain                                                    2.123506
# snow                                                    2.123506
# hail                                                    2.123506
# thunder                                                 2.123506
# tornado                                                 2.123506
# mean_temp_3d_avg                                        2.530887
# mean_temp_5d_avg                                        2.937620
# mean_temp_10d_avg                                       4.157303
# mean_temp_15d_avg                                       4.971288
# max_temp_3d_avg                                         2.866811
# max_temp_5d_avg                                         3.471345
# max_temp_10d_avg                                        5.136855
# max_temp_15d_avg                                        6.369353
# min_temp_3d_avg                                         2.575288
# min_temp_5d_avg                                         3.004158
# min_temp_10d_avg                                        4.273679
# min_temp_15d_avg                                        5.133489
# dewpoint_3d_avg                                         9.503480
# dewpoint_5d_avg                                         9.967689
# dewpoint_10d_avg                                       11.263618
# dewpoint_15d_avg                                       12.149448
# date_stay_at_home_announced                            17.273876
# date_stay_at_home_effective                            17.273876
# entity                                                  0.000000
# dtype: float64

# %%
sub_data_filtered_2.shape
# Out:
# (772496, 55)

# %%
stay_features = [col for col in sub_data_filtered_2.columns if 'stay_at_home' in col.lower()]

# Find entities where all values for percentile features are NaN
entities_all_na_stay = sub_data_filtered_2[sub_data_filtered_2[stay_features].isna().all(axis=1)]['entity'].unique()

print(entities_all_na_stay)
# Out:
# ['Nebraska-Douglas' 'Utah-Salt Lake' 'Oklahoma-Tulsa'
#  'South Carolina-Charleston' 'South Carolina-Kershaw' 'Utah-Davis'
#  'Utah-Washington' 'Iowa-Johnson' 'South Carolina-Spartanburg'
#  'Iowa-Pottawattamie' 'South Dakota-Beadle' 'South Dakota-Charles Mix'
#  'South Dakota-Davison' 'South Dakota-Minnehaha' 'Utah-Weber'
#  'Arkansas-Jefferson' 'North Dakota-Ward' 'South Carolina-Lancaster'
#  'South Dakota-Bon Homme' 'Wyoming-Sheridan' 'Arkansas-Pulaski'
#  'Iowa-Carroll' 'Nebraska-Cass' 'Iowa-Harrison' 'Oklahoma-Oklahoma'
#  'South Dakota-McCook' 'Wyoming-Fremont' 'Iowa-Dallas' 'Oklahoma-Jackson'
#  'South Carolina-Beaufort' 'South Carolina-Lexington' 'Utah-Summit'
#  'Arkansas-Garland' 'Arkansas-Saline' 'Iowa-Allamakee' 'Iowa-Polk'
#  'Oklahoma-Cleveland' 'Oklahoma-Kay' 'Oklahoma-Payne'
#  'South Carolina-Anderson' 'South Carolina-Greenville'
#  'South Carolina-Horry' 'Utah-Utah' 'Arkansas-Cleburne'
#  'Arkansas-Cleveland' 'Arkansas-Desha' 'Arkansas-Lincoln'
#  'Oklahoma-Canadian' 'South Carolina-Fairfield' 'Utah-Tooele'
#  'Utah-Wasatch' 'Iowa-Adair' 'Iowa-Black Hawk' 'Nebraska-Knox'
#  'Nebraska-Sarpy' 'North Dakota-Burleigh' 'North Dakota-Cass'
#  'Oklahoma-Pawnee' 'South Carolina-Calhoun' 'South Carolina-Richland'
#  'South Carolina-York' 'Wyoming-Laramie' 'Wyoming-Park' 'Arkansas-Bradley'
#  'Arkansas-Faulkner' 'Arkansas-Washington' 'Iowa-Washington'
#  'Iowa-Winneshiek' 'Nebraska-Adams' 'Nebraska-Lincoln'
#  'North Dakota-Morton' 'South Carolina-Lee' 'Utah-Box Elder' 'Utah-Cache'
#  'Wyoming-Teton' 'Arkansas-Benton' 'Arkansas-Boone' 'Arkansas-Clark'
#  'Arkansas-Craighead' 'Arkansas-Crittenden' 'Arkansas-Grant'
#  'Arkansas-Greene' 'Arkansas-Independence' 'Arkansas-Poinsett'
#  'Arkansas-Polk' 'Arkansas-Pope' 'Arkansas-Searcy' 'Arkansas-Sebastian'
#  'Arkansas-Sevier' 'Arkansas-Van Buren' 'Iowa-Dubuque' 'Iowa-Muscatine'
#  'Nebraska-Nemaha' 'Oklahoma-Custer' 'Oklahoma-Grady' 'Oklahoma-Logan'
#  'Oklahoma-McClain' 'Oklahoma-Washington' 'South Carolina-Abbeville'
#  'South Carolina-Dorchester' 'South Carolina-Saluda' 'Nebraska-Buffalo'
#  'Nebraska-Lancaster' 'North Dakota-Pierce' 'North Dakota-Ramsey'
#  'Oklahoma-Garvin' 'South Carolina-Aiken' 'South Carolina-Berkeley'
#  'South Carolina-Clarendon' 'South Carolina-Darlington'
#  'South Carolina-Florence' 'South Carolina-Orangeburg'
#  'South Carolina-Pickens' 'South Carolina-Sumter' 'Wyoming-Campbell'
#  'Wyoming-Natrona' 'Iowa-Fayette' 'Iowa-Henry' 'Iowa-Linn' 'Iowa-Story'
#  'South Carolina-Dillon' 'South Carolina-Edgefield'
#  'South Carolina-Greenwood' 'South Carolina-Jasper'
#  'South Carolina-Marlboro' 'South Carolina-Newberry' 'Wyoming-Carbon'
#  'Iowa-Cerro Gordo' 'Iowa-Kossuth' 'Iowa-Poweshiek' 'Iowa-Scott'
#  'Iowa-Sioux' 'Iowa-Tama' 'Iowa-Woodbury' 'Nebraska-Dawson'
#  'Oklahoma-Muskogee' 'Oklahoma-Noble' 'South Carolina-Colleton'
#  'South Dakota-Brown' 'Iowa-Hancock' 'Iowa-Wapello' 'Nebraska-Madison'
#  'Nebraska-Washington' 'North Dakota-Walsh' 'Oklahoma-Pontotoc'
#  'South Carolina-Chester' 'South Carolina-Georgetown'
#  'South Carolina-Oconee' 'South Dakota-Codington' 'South Dakota-Hughes'
#  'South Dakota-Lyman' 'South Dakota-Pennington' 'Utah-Iron'
#  'Arkansas-Columbia' 'Arkansas-Conway' 'Arkansas-Crawford'
#  'Arkansas-Cross' 'Arkansas-Hot Spring' 'Arkansas-Lawrence'
#  'Arkansas-Pike' 'Arkansas-Stone' 'Arkansas-Union' 'Arkansas-White'
#  'Arkansas-Woodruff' 'Iowa-Buchanan' 'Iowa-Cedar' 'Iowa-Jasper'
#  'Iowa-Warren' 'Nebraska-Saunders' 'North Dakota-Dunn' 'Oklahoma-Mayes'
#  'Oklahoma-Wagoner' 'South Carolina-Chesterfield' 'South Dakota-Brookings'
#  'Wyoming-Sweetwater' 'Arkansas-Drew' 'Iowa-Benton' 'Nebraska-Dodge'
#  'North Dakota-Foster' 'North Dakota-Stark' 'Oklahoma-Adair'
#  'Oklahoma-Bryan' 'Oklahoma-Carter' 'Oklahoma-Creek' 'Oklahoma-Delaware'
#  'Oklahoma-Osage' 'Oklahoma-Pottawatomie' 'Oklahoma-Stephens'
#  'South Carolina-Marion' 'South Carolina-Union'
#  'South Carolina-Williamsburg' 'South Dakota-Lincoln' 'South Dakota-Meade'
#  'Wyoming-Albany' 'Arkansas-Chicot' 'Arkansas-Howard' 'Arkansas-Lonoke'
#  'Arkansas-Randolph' 'Iowa-Appanoose' 'Iowa-Clayton' 'Iowa-Des Moines'
#  'Iowa-Mahaska' 'Iowa-Monona' 'Iowa-Page' 'Nebraska-Hall'
#  'Nebraska-Kearney' 'North Dakota-McHenry' 'North Dakota-McIntosh'
#  'Oklahoma-Comanche' 'Oklahoma-Craig' 'Oklahoma-Lincoln'
#  'Oklahoma-Okmulgee' 'Oklahoma-Ottawa' 'Oklahoma-Sequoyah' 'Utah-Morgan'
#  'Wyoming-Hot Springs' 'Wyoming-Johnson' 'Arkansas-Baxter' 'Iowa-Butler'
#  'Iowa-Clinton' 'Iowa-Dickinson' 'Iowa-Hardin' 'Iowa-Iowa' 'Iowa-Marshall'
#  'Iowa-Montgomery' 'Iowa-Webster' 'Iowa-Wright' 'Oklahoma-Caddo'
#  'Oklahoma-Cherokee' 'Oklahoma-Choctaw' 'Oklahoma-Latimer'
#  'Oklahoma-Pittsburg' 'South Dakota-Aurora' 'South Dakota-Faulk'
#  'South Dakota-Lawrence' 'South Dakota-Todd' 'South Dakota-Union'
#  'Utah-Uintah' 'Wyoming-Goshen' 'Wyoming-Washakie' 'Arkansas-Johnson'
#  'Iowa-Boone' 'Iowa-Keokuk' 'Iowa-Shelby' 'Iowa-Taylor' 'Nebraska-Gosper'
#  'Nebraska-Platte' 'North Dakota-Barnes' 'North Dakota-Divide'
#  'North Dakota-McLean' 'North Dakota-Mountrail' 'North Dakota-Sioux'
#  'Oklahoma-Le Flore' 'Oklahoma-Nowata' 'South Carolina-Laurens'
#  'South Dakota-Deuel' 'South Dakota-Hamlin' 'South Dakota-Hutchinson'
#  'South Dakota-Yankton' 'Utah-Garfield' 'Utah-San Juan' 'Wyoming-Converse'
#  'Wyoming-Sublette' 'Arkansas-Arkansas' 'Arkansas-Ashley'
#  'Arkansas-Hempstead' 'Arkansas-Nevada' 'Arkansas-Perry'
#  'Nebraska-Scotts Bluff' 'Oklahoma-Garfield' 'Oklahoma-Rogers'
#  'Oklahoma-Seminole' 'Oklahoma-Texas' 'South Dakota-Clark'
#  'South Dakota-Clay' 'South Dakota-Fall River' 'South Dakota-Roberts'
#  'South Dakota-Turner' 'Arkansas-Newton' 'Arkansas-St. Francis'
#  'Iowa-Audubon' 'Iowa-Crawford' 'Iowa-Guthrie' 'Iowa-Jackson' 'Iowa-Jones'
#  'Iowa-Van Buren' 'Nebraska-Antelope' 'Nebraska-York'
#  'North Dakota-Grand Forks' 'North Dakota-Oliver' 'Oklahoma-Beckham'
#  'Oklahoma-Cotton' 'Oklahoma-Love' 'South Carolina-Barnwell'
#  'South Dakota-Marshall' 'Arkansas-Miller' 'Arkansas-Scott' 'Iowa-Clay'
#  'Nebraska-Kimball' 'North Dakota-Grant' 'North Dakota-McKenzie'
#  'North Dakota-Williams' 'South Carolina-Bamberg' 'Arkansas-Carroll'
#  'Arkansas-Lee' 'Iowa-Madison' 'Iowa-Mitchell' 'Nebraska-Cuming'
#  'North Dakota-Burke' 'Oklahoma-Greer' 'South Carolina-Allendale'
#  'Arkansas-Mississippi' 'Arkansas-Monroe' 'Arkansas-Ouachita'
#  'Arkansas-Sharp' 'Iowa-Bremer' 'Iowa-Jefferson' "Iowa-O'Brien"
#  'Nebraska-Colfax' 'Nebraska-Gage' 'Nebraska-Hamilton' 'Nebraska-Otoe'
#  'Oklahoma-Atoka' 'Oklahoma-Kingfisher' 'Oklahoma-Kiowa'
#  'Oklahoma-Woodward' 'South Carolina-Cherokee' 'South Carolina-Hampton'
#  'South Carolina-McCormick' 'South Dakota-Lake' 'South Dakota-Spink'
#  'Utah-Kane' 'Wyoming-Uinta' 'Arkansas-Lafayette' 'Arkansas-Prairie'
#  'Iowa-Louisa' 'Iowa-Lyon' 'Iowa-Plymouth' 'Nebraska-Merrick'
#  'North Dakota-Eddy' 'North Dakota-Slope' 'Oklahoma-Grant'
#  'Oklahoma-Major' 'Oklahoma-McCurtain' 'Utah-Carbon' 'Utah-Duchesne'
#  'Utah-Emery' 'Utah-Grand' 'Utah-Juab' 'Utah-Millard' 'Wyoming-Lincoln'
#  'Arkansas-Dallas' 'Iowa-Grundy' 'Iowa-Howard' 'Iowa-Lee' 'Iowa-Mills'
#  'Nebraska-Cherry' 'Oklahoma-Tillman' 'Wyoming-Crook' 'Arkansas-Phillips'
#  'Arkansas-Yell' 'Iowa-Clarke' 'Iowa-Hamilton' 'Nebraska-Johnson'
#  'Nebraska-Phelps' 'Nebraska-Seward' 'North Dakota-Emmons' 'Arkansas-Clay'
#  'Arkansas-Franklin' 'Arkansas-Izard' 'Arkansas-Logan' 'Iowa-Chickasaw'
#  'Iowa-Franklin' 'Iowa-Marion' 'Iowa-Winnebago' 'Nebraska-Cheyenne'
#  'Nebraska-Custer' 'Nebraska-Stanton' 'Oklahoma-Jefferson'
#  'Iowa-Buena Vista' 'Iowa-Delaware' 'Iowa-Greene' 'North Dakota-Bowman'
#  'Oklahoma-Beaver' 'Oklahoma-Dewey' 'Oklahoma-Marshall' 'Arkansas-Madison'
#  'Iowa-Worth' 'North Dakota-Stutsman' 'South Dakota-Oglala Lakota'
#  'Nebraska-Burt' 'Nebraska-Polk' 'North Dakota-Richland'
#  'South Dakota-Corson' 'South Dakota-Jerauld' 'Arkansas-Marion'
#  'Iowa-Osceola' 'Iowa-Union' 'Nebraska-Clay' 'Nebraska-Franklin'
#  'Nebraska-Webster' 'North Dakota-Sargent' 'Oklahoma-Murray'
#  'Oklahoma-Okfuskee' 'South Dakota-Miner' 'Wyoming-Niobrara'
#  'Nebraska-Box Butte' 'Nebraska-Pierce' 'Nebraska-Wayne'
#  'North Dakota-Rolette' 'South Dakota-Sanborn' 'Nebraska-Dakota'
#  'South Dakota-Sully' 'South Dakota-Walworth' 'Wyoming-Big Horn'
#  'Arkansas-Jackson' 'Iowa-Cass' 'Oklahoma-Alfalfa' 'South Dakota-Hyde'
#  'Nebraska-Saline' 'Oklahoma-Johnston' 'Nebraska-Morrill' 'Utah-Sevier'
#  'Nebraska-Howard' 'Nebraska-Nance' 'South Dakota-Moody' 'Nebraska-Butler'
#  'Nebraska-Red Willow' 'Oklahoma-Haskell' 'Oklahoma-McIntosh'
#  'Oklahoma-Woods' 'Nebraska-Furnas' 'Oklahoma-Harper' 'Utah-Sanpete'
#  'North Dakota-Nelson' 'Nebraska-Dixon' 'Iowa-Cherokee' 'Iowa-Humboldt'
#  'Oklahoma-Cimarron' 'Nebraska-Fillmore' 'North Dakota-Wells'
#  'Arkansas-Fulton' 'Nebraska-Greeley' 'Nebraska-Sherman'
#  'South Dakota-Stanley' 'Nebraska-Thurston' 'North Dakota-Pembina'
#  'South Dakota-McPherson' 'Nebraska-Jefferson' 'North Dakota-Ransom'
#  'South Dakota-Hand' 'Iowa-Pocahontas' 'Nebraska-Cedar' 'Nebraska-Valley'
#  'Oklahoma-Pushmataha' 'South Dakota-Douglas' 'Arkansas-Montgomery'
#  'South Dakota-Buffalo' 'Iowa-Davis' 'Nebraska-Frontier'
#  'South Dakota-Day' 'Nebraska-Hitchcock' 'Iowa-Calhoun' 'Iowa-Floyd'
#  'Iowa-Sac' 'Iowa-Wayne' 'North Dakota-Renville' 'Nebraska-Keith'
#  'Iowa-Monroe' 'Nebraska-Holt' 'Nebraska-Boone' 'Oklahoma-Blaine'
#  'North Dakota-Mercer' 'Nebraska-Thomas' 'South Dakota-Grant'
#  'South Dakota-Ziebach' 'North Dakota-Benson' 'North Dakota-Traill'
#  'Utah-Piute' 'Iowa-Fremont' 'Iowa-Palo Alto' 'Nebraska-Dawes' 'Iowa-Ida'
#  'Iowa-Emmet' 'Nebraska-Richardson' 'Oklahoma-Washita'
#  'South Dakota-Tripp' 'Arkansas-Little River' 'Nebraska-Nuckolls'
#  'Iowa-Adams' 'Iowa-Lucas' 'North Dakota-Steele' 'Iowa-Ringgold'
#  'North Dakota-Bottineau' 'Oklahoma-Coal' 'Wyoming-Platte'
#  'North Dakota-Griggs' 'Nebraska-Chase' 'South Dakota-Jackson'
#  'Iowa-Decatur' 'Wyoming-Weston' 'Nebraska-Thayer' 'Oklahoma-Hughes'
#  'South Dakota-Edmunds' 'South Dakota-Kingsbury' 'South Dakota-Gregory'
#  'Nebraska-Boyd' 'Nebraska-Garden' 'North Dakota-Dickey'
#  'South Dakota-Brule' 'South Dakota-Hanson' 'South Dakota-Custer'
#  'Nebraska-Garfield' 'North Dakota-LaMoure' 'North Dakota-Sheridan'
#  'South Dakota-Dewey' 'Nebraska-Banner' 'North Dakota-Kidder'
#  'Nebraska-Sioux' 'Utah-Rich' 'South Dakota-Mellette'
#  'South Dakota-Bennett' 'Utah-Beaver' 'North Dakota-Billings'
#  'North Dakota-Cavalier' 'Oklahoma-Ellis' 'Nebraska-Harlan'
#  'Nebraska-Rock' 'Nebraska-Sheridan' 'North Dakota-Hettinger'
#  'Nebraska-Hooker' 'Oklahoma-Harmon' 'Arkansas-Calhoun'
#  'South Dakota-Campbell' 'South Dakota-Haakon' 'North Dakota-Towner'
#  'North Dakota-Logan' 'South Dakota-Butte' 'South Dakota-Jones'
#  'Nebraska-McPherson' 'Oklahoma-Roger Mills' 'Nebraska-Pawnee'
#  'South Dakota-Perkins' 'Nebraska-Deuel' 'North Dakota-Golden Valley'
#  'Nebraska-Dundy' 'Nebraska-Perkins' 'South Dakota-Potter'
#  'Nebraska-Wheeler' 'Utah-Wayne' 'North Dakota-Adams' 'Nebraska-Arthur'
#  'Nebraska-Brown' 'South Dakota-Harding' 'Nebraska-Keya Paha'
#  'Nebraska-Logan' 'Nebraska-Loup' 'Utah-Daggett' 'Nebraska-Grant'
#  'Nebraska-Blaine' 'Nebraska-Hayes']

# %%
missing_column = 'dewpoint_15d_avg'
exist_columns = ['dewpoint_3d_avg', 'dewpoint_5d_avg']

# Find entities where the target column has NaN but the specific columns don't have NaN
entities = sub_data_filtered_2[sub_data_filtered_2[missing_column].isna() & sub_data_filtered_2[exist_columns].notna().any(axis=1)]['entity'].unique()

print(len(entities))
# Out:
# 2912

# %%
precip_features = [col for col in sub_data_filtered_2.columns if 'precip' in col.lower()]

# Find entities where all values for percentile features are NaN
entities_all_na_precip = sub_data_filtered_2[sub_data_filtered_2[precip_features].isna().all(axis=1)]['entity'].unique()

print(len(entities_all_na_precip))
# Out:
# 2196

# %%
def static_check(df):
    non_static = []
    for i in df.entity.unique():
        entity_df = df[df['entity'] == i]
        for j in entity_df.columns.difference(['entity']):
            num_unique = len(entity_df[j].unique())
            if num_unique != 1:
                non_static.append([i, j])
    return non_static

# %%
static_check(sub_data_filtered_2)
# Out:
# [['Washington-Snohomish', 'dewpoint'],
#  ['Washington-Snohomish', 'dewpoint_10d_avg'],
#  ['Washington-Snohomish', 'dewpoint_15d_avg'],
#  ['Washington-Snohomish', 'dewpoint_3d_avg'],
#  ['Washington-Snohomish', 'dewpoint_5d_avg'],
#  ['Washington-Snohomish', 'fog'],
#  ['Washington-Snohomish', 'max_temp'],
#  ['Washington-Snohomish', 'max_temp_10d_avg'],
#  ['Washington-Snohomish', 'max_temp_15d_avg'],
#  ['Washington-Snohomish', 'max_temp_3d_avg'],
#  ['Washington-Snohomish', 'max_temp_5d_avg'],
#  ['Washington-Snohomish', 'max_wind_speed'],
#  ['Washington-Snohomish', 'mean_temp'],
#  ['Washington-Snohomish', 'mean_temp_10d_avg'],
#  ['Washington-Snohomish', 'mean_temp_15d_avg'],
#  ['Washington-Snohomish', 'mean_temp_3d_avg'],
#  ['Washington-Snohomish', 'mean_temp_5d_avg'],
#  ['Washington-Snohomish', 'min_temp'],
#  ['Washington-Snohomish', 'min_temp_10d_avg'],
#  ['Washington-Snohomish', 'min_temp_15d_avg'],
#  ['Washington-Snohomish', 'min_temp_3d_avg'],
#  ['Washington-Snohomish', 'min_temp_5d_avg'],
#  ['Washington-Snohomish', 'precip_flag'],
#  ['Washington-Snohomish', 'precipitation'],
#  ['Washington-Snohomish', 'rain'],
#  ['Washington-Snohomish', 'snow'],
#  ['Washington-Snohomish', 'station_pressure'],
#  ['Washington-Snohomish', 'thunder'],
#  ['Washington-Snohomish', 'visibility'],
#  ['Washington-Snohomish', 'wind_speed'],
#  ['Illinois-Cook', 'dewpoint'],
#  ['Illinois-Cook', 'dewpoint_10d_avg'],
#  ['Illinois-Cook', 'dewpoint_15d_avg'],
#  ['Illinois-Cook', 'dewpoint_3d_avg'],
#  ['Illinois-Cook', 'dewpoint_5d_avg'],
#  ['Illinois-Cook', 'fog'],
#  ['Illinois-Cook', 'hail'],
#  ['Illinois-Cook', 'max_temp'],
#  ['Illinois-Cook', 'max_temp_10d_avg'],
#  ['Illinois-Cook', 'max_temp_15d_avg'],
#  ['Illinois-Cook', 'max_temp_3d_avg'],
#  ['Illinois-Cook', 'max_temp_5d_avg'],
#  ['Illinois-Cook', 'max_wind_speed'],
#  ['Illinois-Cook', 'mean_temp'],
#  ['Illinois-Cook', 'mean_temp_10d_avg'],
#  ['Illinois-Cook', 'mean_temp_15d_avg'],
#  ['Illinois-Cook', 'mean_temp_3d_avg'],
#  ['Illinois-Cook', 'mean_temp_5d_avg'],
#  ['Illinois-Cook', 'min_temp'],
#  ['Illinois-Cook', 'min_temp_10d_avg'],
#  ['Illinois-Cook', 'min_temp_15d_avg'],
#  ['Illinois-Cook', 'min_temp_3d_avg'],
#  ['Illinois-Cook', 'min_temp_5d_avg'],
#  ['Illinois-Cook', 'precip_flag'],
#  ['Illinois-Cook', 'precipitation'],
#  ['Illinois-Cook', 'rain'],
#  ['Illinois-Cook', 'snow'],
#  ['Illinois-Cook', 'station_id'],
#  ['Illinois-Cook', 'station_name'],
#  ['Illinois-Cook', 'station_pressure'],
#  ['Illinois-Cook', 'thunder'],
#  ['Illinois-Cook', 'tornado'],
#  ['Illinois-Cook', 'visibility'],
#  ['Illinois-Cook', 'wind_speed'],
#  ['California-Orange', 'dewpoint'],
#  ['California-Orange', 'dewpoint_10d_avg'],
#  ['California-Orange', 'dewpoint_15d_avg'],
#  ['California-Orange', 'dewpoint_3d_avg'],
#  ['California-Orange', 'dewpoint_5d_avg'],
#  ['California-Orange', 'fog'],
#  ['California-Orange', 'hail'],
#  ['California-Orange', 'max_temp'],
#  ['California-Orange', 'max_temp_10d_avg'],
#  ['California-Orange', 'max_temp_15d_avg'],
#  ['California-Orange', 'max_temp_3d_avg'],
#  ['California-Orange', 'max_temp_5d_avg'],
#  ['California-Orange', 'max_wind_speed'],
#  ['California-Orange', 'mean_temp'],
#  ['California-Orange', 'mean_temp_10d_avg'],
#  ['California-Orange', 'mean_temp_15d_avg'],
#  ['California-Orange', 'mean_temp_3d_avg'],
#  ['California-Orange', 'mean_temp_5d_avg'],
#  ['California-Orange', 'min_temp'],
#  ['California-Orange', 'min_temp_10d_avg'],
#  ['California-Orange', 'min_temp_15d_avg'],
#  ['California-Orange', 'min_temp_3d_avg'],
#  ['California-Orange', 'min_temp_5d_avg'],
#  ['California-Orange', 'precip_flag'],
#  ['California-Orange', 'precipitation'],
#  ['California-Orange', 'rain'],
#  ['California-Orange', 'snow'],
#  ['California-Orange', 'station_id'],
#  ['California-Orange', 'station_name'],
#  ['California-Orange', 'station_pressure'],
#  ['California-Orange', 'thunder'],
#  ['California-Orange', 'tornado'],
#  ['California-Orange', 'visibility'],
#  ['California-Orange', 'wind_speed'],
#  ['Arizona-Maricopa', 'dewpoint'],
#  ['Arizona-Maricopa', 'dewpoint_10d_avg'],
#  ['Arizona-Maricopa', 'dewpoint_15d_avg'],
#  ['Arizona-Maricopa', 'dewpoint_3d_avg'],
#  ['Arizona-Maricopa', 'dewpoint_5d_avg'],
#  ['Arizona-Maricopa', 'fog'],
#  ['Arizona-Maricopa', 'hail'],
#  ['Arizona-Maricopa', 'max_temp'],
#  ['Arizona-Maricopa', 'max_temp_10d_avg'],
#  ['Arizona-Maricopa', 'max_temp_15d_avg'],
#  ['Arizona-Maricopa', 'max_temp_3d_avg'],
#  ['Arizona-Maricopa', 'max_temp_5d_avg'],
#  ['Arizona-Maricopa', 'max_wind_speed'],
#  ['Arizona-Maricopa', 'mean_temp'],
#  ['Arizona-Maricopa', 'mean_temp_10d_avg'],
#  ['Arizona-Maricopa', 'mean_temp_15d_avg'],
#  ['Arizona-Maricopa', 'mean_temp_3d_avg'],
#  ['Arizona-Maricopa', 'mean_temp_5d_avg'],
#  ['Arizona-Maricopa', 'min_temp'],
#  ['Arizona-Maricopa', 'min_temp_10d_avg'],
#  ['Arizona-Maricopa', 'min_temp_15d_avg'],
#  ['Arizona-Maricopa', 'min_temp_3d_avg'],
#  ['Arizona-Maricopa', 'min_temp_5d_avg'],
#  ['Arizona-Maricopa', 'precip_flag'],
#  ['Arizona-Maricopa', 'precipitation'],
#  ['Arizona-Maricopa', 'rain'],
#  ['Arizona-Maricopa', 'snow'],
#  ['Arizona-Maricopa', 'station_id'],
#  ['Arizona-Maricopa', 'station_name'],
#  ['Arizona-Maricopa', 'station_pressure'],
#  ['Arizona-Maricopa', 'thunder'],
#  ['Arizona-Maricopa', 'tornado'],
#  ['Arizona-Maricopa', 'visibility'],
#  ['Arizona-Maricopa', 'wind_speed'],
#  ['California-Los Angeles', 'dewpoint'],
#  ['California-Los Angeles', 'dewpoint_10d_avg'],
#  ['California-Los Angeles', 'dewpoint_15d_avg'],
#  ['California-Los Angeles', 'dewpoint_3d_avg'],
#  ['California-Los Angeles', 'dewpoint_5d_avg'],
#  ['California-Los Angeles', 'fog'],
#  ['California-Los Angeles', 'hail'],
#  ['California-Los Angeles', 'max_temp'],
#  ['California-Los Angeles', 'max_temp_10d_avg'],
#  ['California-Los Angeles', 'max_temp_15d_avg'],
#  ['California-Los Angeles', 'max_temp_3d_avg'],
#  ['California-Los Angeles', 'max_temp_5d_avg'],
#  ['California-Los Angeles', 'max_wind_speed'],
#  ['California-Los Angeles', 'mean_temp'],
#  ['California-Los Angeles', 'mean_temp_10d_avg'],
#  ['California-Los Angeles', 'mean_temp_15d_avg'],
#  ['California-Los Angeles', 'mean_temp_3d_avg'],
#  ['California-Los Angeles', 'mean_temp_5d_avg'],
#  ['California-Los Angeles', 'min_temp'],
#  ['California-Los Angeles', 'min_temp_10d_avg'],
#  ['California-Los Angeles', 'min_temp_15d_avg'],
#  ['California-Los Angeles', 'min_temp_3d_avg'],
#  ['California-Los Angeles', 'min_temp_5d_avg'],
#  ['California-Los Angeles', 'precip_flag'],
#  ['California-Los Angeles', 'precipitation'],
#  ['California-Los Angeles', 'rain'],
#  ['California-Los Angeles', 'snow'],
#  ['California-Los Angeles', 'station_id'],
#  ['California-Los Angeles', 'station_name'],
#  ['California-Los Angeles', 'station_pressure'],
#  ['California-Los Angeles', 'thunder'],
#  ['California-Los Angeles', 'tornado'],
#  ['California-Los Angeles', 'visibility'],
#  ['California-Los Angeles', 'wind_speed'],
#  ['California-Santa Clara', 'dewpoint'],
#  ['California-Santa Clara', 'dewpoint_10d_avg'],
#  ['California-Santa Clara', 'dewpoint_15d_avg'],
#  ['California-Santa Clara', 'dewpoint_3d_avg'],
#  ['California-Santa Clara', 'dewpoint_5d_avg'],
#  ['California-Santa Clara', 'fog'],
#  ['California-Santa Clara', 'hail'],
#  ['California-Santa Clara', 'max_temp'],
#  ['California-Santa Clara', 'max_temp_10d_avg'],
#  ['California-Santa Clara', 'max_temp_15d_avg'],
#  ['California-Santa Clara', 'max_temp_3d_avg'],
#  ['California-Santa Clara', 'max_temp_5d_avg'],
#  ['California-Santa Clara', 'max_wind_speed'],
#  ['California-Santa Clara', 'mean_temp'],
#  ['California-Santa Clara', 'mean_temp_10d_avg'],
#  ['California-Santa Clara', 'mean_temp_15d_avg'],
#  ['California-Santa Clara', 'mean_temp_3d_avg'],
#  ['California-Santa Clara', 'mean_temp_5d_avg'],
#  ['California-Santa Clara', 'min_temp'],
#  ['California-Santa Clara', 'min_temp_10d_avg'],
#  ['California-Santa Clara', 'min_temp_15d_avg'],
#  ['California-Santa Clara', 'min_temp_3d_avg'],
#  ['California-Santa Clara', 'min_temp_5d_avg'],
#  ['California-Santa Clara', 'precip_flag'],
#  ['California-Santa Clara', 'precipitation'],
#  ['California-Santa Clara', 'rain'],
#  ['California-Santa Clara', 'snow'],
#  ['California-Santa Clara', 'station_id'],
#  ['California-Santa Clara', 'station_name'],
#  ['California-Santa Clara', 'station_pressure'],
#  ['California-Santa Clara', 'thunder'],
#  ['California-Santa Clara', 'tornado'],
#  ['California-Santa Clara', 'visibility'],
#  ['California-Santa Clara', 'wind_speed'],
#  ['Massachusetts-Suffolk', 'fog'],
#  ['Massachusetts-Suffolk', 'hail'],
#  ['Massachusetts-Suffolk', 'max_temp'],
#  ['Massachusetts-Suffolk', 'max_temp_10d_avg'],
#  ['Massachusetts-Suffolk', 'max_temp_15d_avg'],
#  ['Massachusetts-Suffolk', 'max_temp_3d_avg'],
#  ['Massachusetts-Suffolk', 'max_temp_5d_avg'],
#  ['Massachusetts-Suffolk', 'mean_temp'],
#  ['Massachusetts-Suffolk', 'mean_temp_10d_avg'],
#  ['Massachusetts-Suffolk', 'mean_temp_15d_avg'],
#  ['Massachusetts-Suffolk', 'mean_temp_3d_avg'],
#  ['Massachusetts-Suffolk', 'mean_temp_5d_avg'],
#  ['Massachusetts-Suffolk', 'min_temp'],
#  ['Massachusetts-Suffolk', 'min_temp_10d_avg'],
#  ['Massachusetts-Suffolk', 'min_temp_15d_avg'],
#  ['Massachusetts-Suffolk', 'min_temp_3d_avg'],
#  ['Massachusetts-Suffolk', 'min_temp_5d_avg'],
#  ['Massachusetts-Suffolk', 'precip_flag'],
#  ['Massachusetts-Suffolk', 'precipitation'],
#  ['Massachusetts-Suffolk', 'rain'],
#  ['Massachusetts-Suffolk', 'snow'],
#  ['Massachusetts-Suffolk', 'station_id'],
#  ['Massachusetts-Suffolk', 'station_name'],
#  ['Massachusetts-Suffolk', 'thunder'],
#  ['Massachusetts-Suffolk', 'tornado'],
#  ['Massachusetts-Suffolk', 'wind_speed'],
#  ['California-San Francisco', 'fog'],
#  ['California-San Francisco', 'hail'],
#  ['California-San Francisco', 'max_temp'],
#  ['California-San Francisco', 'max_temp_10d_avg'],
#  ['California-San Francisco', 'max_temp_15d_avg'],
#  ['California-San Francisco', 'max_temp_3d_avg'],
#  ['California-San Francisco', 'max_temp_5d_avg'],
#  ['California-San Francisco', 'max_wind_speed'],
#  ['California-San Francisco', 'mean_temp'],
#  ['California-San Francisco', 'mean_temp_10d_avg'],
#  ['California-San Francisco', 'mean_temp_15d_avg'],
#  ['California-San Francisco', 'mean_temp_3d_avg'],
#  ['California-San Francisco', 'mean_temp_5d_avg'],
#  ['California-San Francisco', 'min_temp'],
#  ['California-San Francisco', 'min_temp_10d_avg'],
#  ['California-San Francisco', 'min_temp_15d_avg'],
#  ['California-San Francisco', 'min_temp_3d_avg'],
#  ['California-San Francisco', 'min_temp_5d_avg'],
#  ['California-San Francisco', 'precip_flag'],
#  ['California-San Francisco', 'precipitation'],
#  ['California-San Francisco', 'rain'],
#  ['California-San Francisco', 'snow'],
#  ['California-San Francisco', 'station_id'],
#  ['California-San Francisco', 'station_name'],
#  ['California-San Francisco', 'thunder'],
#  ['California-San Francisco', 'tornado'],
#  ['California-San Francisco', 'wind_speed'],
#  ['Wisconsin-Dane', 'dewpoint'],
#  ['Wisconsin-Dane', 'dewpoint_10d_avg'],
#  ['Wisconsin-Dane', 'dewpoint_15d_avg'],
#  ['Wisconsin-Dane', 'dewpoint_3d_avg'],
#  ['Wisconsin-Dane', 'dewpoint_5d_avg'],
#  ['Wisconsin-Dane', 'fog'],
#  ['Wisconsin-Dane', 'max_temp'],
#  ['Wisconsin-Dane', 'max_temp_10d_avg'],
#  ['Wisconsin-Dane', 'max_temp_15d_avg'],
#  ['Wisconsin-Dane', 'max_temp_3d_avg'],
#  ['Wisconsin-Dane', 'max_temp_5d_avg'],
#  ['Wisconsin-Dane', 'max_wind_speed'],
#  ['Wisconsin-Dane', 'mean_temp'],
#  ['Wisconsin-Dane', 'mean_temp_10d_avg'],
#  ['Wisconsin-Dane', 'mean_temp_15d_avg'],
#  ['Wisconsin-Dane', 'mean_temp_3d_avg'],
#  ['Wisconsin-Dane', 'mean_temp_5d_avg'],
#  ['Wisconsin-Dane', 'min_temp'],
#  ['Wisconsin-Dane', 'min_temp_10d_avg'],
#  ['Wisconsin-Dane', 'min_temp_15d_avg'],
#  ['Wisconsin-Dane', 'min_temp_3d_avg'],
#  ['Wisconsin-Dane', 'min_temp_5d_avg'],
#  ['Wisconsin-Dane', 'precip_flag'],
#  ['Wisconsin-Dane', 'precipitation'],
#  ['Wisconsin-Dane', 'rain'],
#  ['Wisconsin-Dane', 'snow'],
#  ['Wisconsin-Dane', 'station_pressure'],
#  ['Wisconsin-Dane', 'thunder'],
#  ['Wisconsin-Dane', 'visibility'],
#  ['Wisconsin-Dane', 'wind_speed'],
#  ['California-San Diego', 'dewpoint'],
#  ['California-San Diego', 'dewpoint_10d_avg'],
#  ['California-San Diego', 'dewpoint_15d_avg'],
#  ['California-San Diego', 'dewpoint_3d_avg'],
#  ['California-San Diego', 'dewpoint_5d_avg'],
#  ['California-San Diego', 'fog'],
#  ['California-San Diego', 'hail'],
#  ['California-San Diego', 'max_temp'],
#  ['California-San Diego', 'max_temp_10d_avg'],
#  ['California-San Diego', 'max_temp_15d_avg'],
#  ['California-San Diego', 'max_temp_3d_avg'],
#  ['California-San Diego', 'max_temp_5d_avg'],
#  ['California-San Diego', 'max_wind_speed'],
#  ['California-San Diego', 'mean_temp'],
#  ['California-San Diego', 'mean_temp_10d_avg'],
#  ['California-San Diego', 'mean_temp_15d_avg'],
#  ['California-San Diego', 'mean_temp_3d_avg'],
#  ['California-San Diego', 'mean_temp_5d_avg'],
#  ['California-San Diego', 'min_temp'],
#  ['California-San Diego', 'min_temp_10d_avg'],
#  ['California-San Diego', 'min_temp_15d_avg'],
#  ['California-San Diego', 'min_temp_3d_avg'],
#  ['California-San Diego', 'min_temp_5d_avg'],
#  ['California-San Diego', 'precip_flag'],
#  ['California-San Diego', 'precipitation'],
#  ['California-San Diego', 'rain'],
#  ['California-San Diego', 'snow'],
#  ['California-San Diego', 'station_id'],
#  ['California-San Diego', 'station_name'],
#  ['California-San Diego', 'station_pressure'],
#  ['California-San Diego', 'thunder'],
#  ['California-San Diego', 'tornado'],
#  ['California-San Diego', 'visibility'],
#  ['California-San Diego', 'wind_speed'],
#  ['Texas-Bexar', 'dewpoint'],
#  ['Texas-Bexar', 'dewpoint_10d_avg'],
#  ['Texas-Bexar', 'dewpoint_15d_avg'],
#  ['Texas-Bexar', 'dewpoint_3d_avg'],
#  ['Texas-Bexar', 'dewpoint_5d_avg'],
#  ['Texas-Bexar', 'fog'],
#  ['Texas-Bexar', 'max_temp'],
#  ['Texas-Bexar', 'max_temp_10d_avg'],
#  ['Texas-Bexar', 'max_temp_15d_avg'],
#  ['Texas-Bexar', 'max_temp_3d_avg'],
#  ['Texas-Bexar', 'max_temp_5d_avg'],
#  ['Texas-Bexar', 'max_wind_speed'],
#  ['Texas-Bexar', 'mean_temp'],
#  ['Texas-Bexar', 'mean_temp_10d_avg'],
#  ['Texas-Bexar', 'mean_temp_15d_avg'],
#  ['Texas-Bexar', 'mean_temp_3d_avg'],
#  ['Texas-Bexar', 'mean_temp_5d_avg'],
#  ['Texas-Bexar', 'min_temp'],
#  ['Texas-Bexar', 'min_temp_10d_avg'],
#  ['Texas-Bexar', 'min_temp_15d_avg'],
#  ['Texas-Bexar', 'min_temp_3d_avg'],
#  ['Texas-Bexar', 'min_temp_5d_avg'],
#  ['Texas-Bexar', 'precip_flag'],
#  ['Texas-Bexar', 'precipitation'],
#  ['Texas-Bexar', 'rain'],
#  ['Texas-Bexar', 'station_pressure'],
#  ['Texas-Bexar', 'thunder'],
#  ['Texas-Bexar', 'visibility'],
#  ['Texas-Bexar', 'wind_speed'],
#  ['Nebraska-Douglas', 'dewpoint'],
#  ['Nebraska-Douglas', 'dewpoint_10d_avg'],
#  ['Nebraska-Douglas', 'dewpoint_15d_avg'],
#  ['Nebraska-Douglas', 'dewpoint_3d_avg'],
#  ['Nebraska-Douglas', 'dewpoint_5d_avg'],
#  ['Nebraska-Douglas', 'fog'],
#  ['Nebraska-Douglas', 'max_temp'],
#  ['Nebraska-Douglas', 'max_temp_10d_avg'],
#  ['Nebraska-Douglas', 'max_temp_15d_avg'],
#  ['Nebraska-Douglas', 'max_temp_3d_avg'],
#  ['Nebraska-Douglas', 'max_temp_5d_avg'],
#  ['Nebraska-Douglas', 'max_wind_speed'],
#  ['Nebraska-Douglas', 'mean_temp'],
#  ['Nebraska-Douglas', 'mean_temp_10d_avg'],
#  ['Nebraska-Douglas', 'mean_temp_15d_avg'],
#  ['Nebraska-Douglas', 'mean_temp_3d_avg'],
#  ['Nebraska-Douglas', 'mean_temp_5d_avg'],
#  ['Nebraska-Douglas', 'min_temp'],
#  ['Nebraska-Douglas', 'min_temp_10d_avg'],
#  ['Nebraska-Douglas', 'min_temp_15d_avg'],
#  ['Nebraska-Douglas', 'min_temp_3d_avg'],
#  ['Nebraska-Douglas', 'min_temp_5d_avg'],
#  ['Nebraska-Douglas', 'precip_flag'],
#  ['Nebraska-Douglas', 'precipitation'],
#  ['Nebraska-Douglas', 'rain'],
#  ['Nebraska-Douglas', 'snow'],
#  ['Nebraska-Douglas', 'station_pressure'],
#  ['Nebraska-Douglas', 'thunder'],
#  ['Nebraska-Douglas', 'visibility'],
#  ['Nebraska-Douglas', 'wind_speed'],
#  ['California-Humboldt', 'dewpoint'],
#  ['California-Humboldt', 'dewpoint_10d_avg'],
#  ['California-Humboldt', 'dewpoint_15d_avg'],
#  ['California-Humboldt', 'dewpoint_3d_avg'],
#  ['California-Humboldt', 'dewpoint_5d_avg'],
#  ['California-Humboldt', 'fog'],
#  ['California-Humboldt', 'hail'],
#  ['California-Humboldt', 'max_temp'],
#  ['California-Humboldt', 'max_temp_10d_avg'],
#  ['California-Humboldt', 'max_temp_15d_avg'],
#  ['California-Humboldt', 'max_temp_3d_avg'],
#  ['California-Humboldt', 'max_temp_5d_avg'],
#  ['California-Humboldt', 'max_wind_speed'],
#  ['California-Humboldt', 'mean_temp'],
#  ['California-Humboldt', 'mean_temp_10d_avg'],
#  ['California-Humboldt', 'mean_temp_15d_avg'],
#  ['California-Humboldt', 'mean_temp_3d_avg'],
#  ['California-Humboldt', 'mean_temp_5d_avg'],
#  ['California-Humboldt', 'min_temp'],
#  ['California-Humboldt', 'min_temp_10d_avg'],
#  ['California-Humboldt', 'min_temp_15d_avg'],
#  ['California-Humboldt', 'min_temp_3d_avg'],
#  ['California-Humboldt', 'min_temp_5d_avg'],
#  ['California-Humboldt', 'precip_flag'],
#  ['California-Humboldt', 'precipitation'],
#  ['California-Humboldt', 'rain'],
#  ['California-Humboldt', 'snow'],
#  ['California-Humboldt', 'station_id'],
#  ['California-Humboldt', 'station_name'],
#  ['California-Humboldt', 'station_pressure'],
#  ['California-Humboldt', 'thunder'],
#  ['California-Humboldt', 'tornado'],
#  ['California-Humboldt', 'visibility'],
#  ['California-Humboldt', 'wind_speed'],
#  ['California-Sacramento', 'dewpoint'],
#  ['California-Sacramento', 'dewpoint_10d_avg'],
#  ['California-Sacramento', 'dewpoint_15d_avg'],
#  ['California-Sacramento', 'dewpoint_3d_avg'],
#  ['California-Sacramento', 'dewpoint_5d_avg'],
#  ['California-Sacramento', 'fog'],
#  ['California-Sacramento', 'hail'],
#  ['California-Sacramento', 'max_temp'],
#  ['California-Sacramento', 'max_temp_10d_avg'],
#  ['California-Sacramento', 'max_temp_15d_avg'],
#  ['California-Sacramento', 'max_temp_3d_avg'],
#  ['California-Sacramento', 'max_temp_5d_avg'],
#  ['California-Sacramento', 'max_wind_speed'],
#  ['California-Sacramento', 'mean_temp'],
#  ['California-Sacramento', 'mean_temp_10d_avg'],
#  ['California-Sacramento', 'mean_temp_15d_avg'],
#  ['California-Sacramento', 'mean_temp_3d_avg'],
#  ['California-Sacramento', 'mean_temp_5d_avg'],
#  ['California-Sacramento', 'min_temp'],
#  ['California-Sacramento', 'min_temp_10d_avg'],
#  ['California-Sacramento', 'min_temp_15d_avg'],
#  ['California-Sacramento', 'min_temp_3d_avg'],
#  ['California-Sacramento', 'min_temp_5d_avg'],
#  ['California-Sacramento', 'precip_flag'],
#  ['California-Sacramento', 'precipitation'],
#  ['California-Sacramento', 'rain'],
#  ['California-Sacramento', 'snow'],
#  ['California-Sacramento', 'station_id'],
#  ['California-Sacramento', 'station_name'],
#  ['California-Sacramento', 'station_pressure'],
#  ['California-Sacramento', 'thunder'],
#  ['California-Sacramento', 'tornado'],
#  ['California-Sacramento', 'visibility'],
#  ['California-Sacramento', 'wind_speed'],
#  ['California-Solano', 'dewpoint'],
#  ['California-Solano', 'dewpoint_10d_avg'],
#  ['California-Solano', 'dewpoint_15d_avg'],
#  ['California-Solano', 'dewpoint_3d_avg'],
#  ['California-Solano', 'dewpoint_5d_avg'],
#  ['California-Solano', 'fog'],
#  ['California-Solano', 'hail'],
#  ['California-Solano', 'max_temp'],
#  ['California-Solano', 'max_temp_10d_avg'],
#  ['California-Solano', 'max_temp_15d_avg'],
#  ['California-Solano', 'max_temp_3d_avg'],
#  ['California-Solano', 'max_temp_5d_avg'],
#  ['California-Solano', 'max_wind_speed'],
#  ['California-Solano', 'mean_temp'],
#  ['California-Solano', 'mean_temp_10d_avg'],
#  ['California-Solano', 'mean_temp_15d_avg'],
#  ['California-Solano', 'mean_temp_3d_avg'],
#  ['California-Solano', 'mean_temp_5d_avg'],
#  ['California-Solano', 'min_temp'],
#  ['California-Solano', 'min_temp_10d_avg'],
#  ['California-Solano', 'min_temp_15d_avg'],
#  ['California-Solano', 'min_temp_3d_avg'],
#  ['California-Solano', 'min_temp_5d_avg'],
#  ['California-Solano', 'precip_flag'],
#  ['California-Solano', 'precipitation'],
#  ['California-Solano', 'rain'],
#  ['California-Solano', 'snow'],
#  ['California-Solano', 'station_id'],
#  ['California-Solano', 'station_name'],
#  ['California-Solano', 'station_pressure'],
#  ['California-Solano', 'thunder'],
#  ['California-Solano', 'tornado'],
#  ['California-Solano', 'visibility'],
#  ['California-Solano', 'wind_speed'],
#  ['Washington-Spokane', 'dewpoint'],
#  ['Washington-Spokane', 'dewpoint_10d_avg'],
#  ['Washington-Spokane', 'dewpoint_15d_avg'],
#  ['Washington-Spokane', 'dewpoint_3d_avg'],
#  ['Washington-Spokane', 'dewpoint_5d_avg'],
#  ['Washington-Spokane', 'fog'],
#  ['Washington-Spokane', 'hail'],
#  ['Washington-Spokane', 'max_temp'],
#  ['Washington-Spokane', 'max_temp_10d_avg'],
#  ['Washington-Spokane', 'max_temp_15d_avg'],
#  ['Washington-Spokane', 'max_temp_3d_avg'],
#  ['Washington-Spokane', 'max_temp_5d_avg'],
#  ['Washington-Spokane', 'max_wind_speed'],
#  ['Washington-Spokane', 'mean_temp'],
#  ['Washington-Spokane', 'mean_temp_10d_avg'],
#  ['Washington-Spokane', 'mean_temp_15d_avg'],
#  ['Washington-Spokane', 'mean_temp_3d_avg'],
#  ['Washington-Spokane', 'mean_temp_5d_avg'],
#  ['Washington-Spokane', 'min_temp'],
#  ['Washington-Spokane', 'min_temp_10d_avg'],
#  ['Washington-Spokane', 'min_temp_15d_avg'],
#  ['Washington-Spokane', 'min_temp_3d_avg'],
#  ['Washington-Spokane', 'min_temp_5d_avg'],
#  ['Washington-Spokane', 'precip_flag'],
#  ['Washington-Spokane', 'precipitation'],
#  ['Washington-Spokane', 'rain'],
#  ['Washington-Spokane', 'snow'],
#  ['Washington-Spokane', 'station_pressure'],
#  ['Washington-Spokane', 'thunder'],
#  ['Washington-Spokane', 'visibility'],
#  ['Washington-Spokane', 'wind_speed'],
#  ['Utah-Salt Lake', 'dewpoint'],
#  ['Utah-Salt Lake', 'dewpoint_10d_avg'],
#  ['Utah-Salt Lake', 'dewpoint_15d_avg'],
#  ['Utah-Salt Lake', 'dewpoint_3d_avg'],
#  ['Utah-Salt Lake', 'dewpoint_5d_avg'],
#  ['Utah-Salt Lake', 'fog'],
#  ['Utah-Salt Lake', 'hail'],
#  ['Utah-Salt Lake', 'max_temp'],
#  ['Utah-Salt Lake', 'max_temp_10d_avg'],
#  ['Utah-Salt Lake', 'max_temp_15d_avg'],
#  ['Utah-Salt Lake', 'max_temp_3d_avg'],
#  ['Utah-Salt Lake', 'max_temp_5d_avg'],
#  ['Utah-Salt Lake', 'max_wind_speed'],
#  ['Utah-Salt Lake', 'mean_temp'],
#  ['Utah-Salt Lake', 'mean_temp_10d_avg'],
#  ['Utah-Salt Lake', 'mean_temp_15d_avg'],
#  ['Utah-Salt Lake', 'mean_temp_3d_avg'],
#  ['Utah-Salt Lake', 'mean_temp_5d_avg'],
#  ['Utah-Salt Lake', 'min_temp'],
#  ['Utah-Salt Lake', 'min_temp_10d_avg'],
#  ['Utah-Salt Lake', 'min_temp_15d_avg'],
#  ['Utah-Salt Lake', 'min_temp_3d_avg'],
#  ['Utah-Salt Lake', 'min_temp_5d_avg'],
#  ['Utah-Salt Lake', 'precip_flag'],
#  ['Utah-Salt Lake', 'precipitation'],
#  ['Utah-Salt Lake', 'rain'],
#  ['Utah-Salt Lake', 'snow'],
#  ['Utah-Salt Lake', 'station_pressure'],
#  ['Utah-Salt Lake', 'thunder'],
#  ['Utah-Salt Lake', 'visibility'],
#  ['Utah-Salt Lake', 'wind_speed'],
#  ['California-Marin', 'dewpoint'],
#  ['California-Marin', 'dewpoint_10d_avg'],
#  ['California-Marin', 'dewpoint_15d_avg'],
#  ['California-Marin', 'dewpoint_3d_avg'],
#  ['California-Marin', 'dewpoint_5d_avg'],
#  ['California-Marin', 'fog'],
#  ['California-Marin', 'hail'],
#  ['California-Marin', 'max_temp'],
#  ['California-Marin', 'max_temp_10d_avg'],
#  ['California-Marin', 'max_temp_15d_avg'],
#  ['California-Marin', 'max_temp_3d_avg'],
#  ['California-Marin', 'max_temp_5d_avg'],
#  ['California-Marin', 'max_wind_speed'],
#  ['California-Marin', 'mean_temp'],
#  ['California-Marin', 'mean_temp_10d_avg'],
#  ['California-Marin', 'mean_temp_15d_avg'],
#  ['California-Marin', 'mean_temp_3d_avg'],
#  ['California-Marin', 'mean_temp_5d_avg'],
#  ['California-Marin', 'min_temp'],
#  ['California-Marin', 'min_temp_10d_avg'],
#  ['California-Marin', 'min_temp_15d_avg'],
#  ['California-Marin', 'min_temp_3d_avg'],
#  ['California-Marin', 'min_temp_5d_avg'],
#  ['California-Marin', 'precip_flag'],
#  ['California-Marin', 'precipitation'],
#  ['California-Marin', 'rain'],
#  ['California-Marin', 'snow'],
#  ['California-Marin', 'station_id'],
#  ['California-Marin', 'station_name'],
#  ['California-Marin', 'station_pressure'],
#  ['California-Marin', 'thunder'],
#  ['California-Marin', 'tornado'],
#  ['California-Marin', 'visibility'],
#  ['California-Marin', 'wind_speed'],
#  ['California-Napa', 'dewpoint'],
#  ['California-Napa', 'dewpoint_10d_avg'],
#  ['California-Napa', 'dewpoint_15d_avg'],
#  ['California-Napa', 'dewpoint_3d_avg'],
#  ['California-Napa', 'dewpoint_5d_avg'],
#  ['California-Napa', 'fog'],
#  ['California-Napa', 'hail'],
#  ['California-Napa', 'max_temp'],
#  ['California-Napa', 'max_temp_10d_avg'],
#  ['California-Napa', 'max_temp_15d_avg'],
#  ['California-Napa', 'max_temp_3d_avg'],
#  ['California-Napa', 'max_temp_5d_avg'],
#  ['California-Napa', 'max_wind_speed'],
#  ['California-Napa', 'mean_temp'],
#  ['California-Napa', 'mean_temp_10d_avg'],
#  ['California-Napa', 'mean_temp_15d_avg'],
#  ['California-Napa', 'mean_temp_3d_avg'],
#  ['California-Napa', 'mean_temp_5d_avg'],
#  ['California-Napa', 'min_temp'],
#  ['California-Napa', 'min_temp_10d_avg'],
#  ['California-Napa', 'min_temp_15d_avg'],
#  ['California-Napa', 'min_temp_3d_avg'],
#  ['California-Napa', 'min_temp_5d_avg'],
#  ['California-Napa', 'precip_flag'],
#  ['California-Napa', 'precipitation'],
#  ['California-Napa', 'rain'],
#  ['California-Napa', 'snow'],
#  ['California-Napa', 'station_id'],
#  ['California-Napa', 'station_name'],
#  ['California-Napa', 'station_pressure'],
#  ['California-Napa', 'thunder'],
#  ['California-Napa', 'tornado'],
#  ['California-Napa', 'visibility'],
#  ['California-Napa', 'wind_speed'],
#  ['California-Sonoma', 'dewpoint'],
#  ['California-Sonoma', 'dewpoint_10d_avg'],
#  ['California-Sonoma', 'dewpoint_15d_avg'],
#  ['California-Sonoma', 'dewpoint_3d_avg'],
#  ['California-Sonoma', 'dewpoint_5d_avg'],
#  ['California-Sonoma', 'fog'],
#  ['California-Sonoma', 'hail'],
#  ['California-Sonoma', 'max_temp'],
#  ['California-Sonoma', 'max_temp_10d_avg'],
#  ['California-Sonoma', 'max_temp_15d_avg'],
#  ['California-Sonoma', 'max_temp_3d_avg'],
#  ['California-Sonoma', 'max_temp_5d_avg'],
#  ['California-Sonoma', 'max_wind_speed'],
#  ['California-Sonoma', 'mean_temp'],
#  ['California-Sonoma', 'mean_temp_10d_avg'],
#  ['California-Sonoma', 'mean_temp_15d_avg'],
#  ['California-Sonoma', 'mean_temp_3d_avg'],
#  ['California-Sonoma', 'mean_temp_5d_avg'],
#  ['California-Sonoma', 'min_temp'],
#  ['California-Sonoma', 'min_temp_10d_avg'],
#  ['California-Sonoma', 'min_temp_15d_avg'],
#  ['California-Sonoma', 'min_temp_3d_avg'],
#  ['California-Sonoma', 'min_temp_5d_avg'],
#  ['California-Sonoma', 'precip_flag'],
#  ['California-Sonoma', 'precipitation'],
#  ['California-Sonoma', 'rain'],
#  ['California-Sonoma', 'snow'],
#  ['California-Sonoma', 'station_id'],
#  ['California-Sonoma', 'station_name'],
#  ['California-Sonoma', 'station_pressure'],
#  ['California-Sonoma', 'thunder'],
#  ['California-Sonoma', 'tornado'],
#  ['California-Sonoma', 'visibility'],
#  ['California-Sonoma', 'wind_speed'],
#  ['Oregon-Washington', 'dewpoint'],
#  ['Oregon-Washington', 'dewpoint_10d_avg'],
#  ['Oregon-Washington', 'dewpoint_15d_avg'],
#  ['Oregon-Washington', 'dewpoint_3d_avg'],
#  ['Oregon-Washington', 'dewpoint_5d_avg'],
#  ['Oregon-Washington', 'fog'],
#  ['Oregon-Washington', 'max_temp'],
#  ['Oregon-Washington', 'max_temp_10d_avg'],
#  ['Oregon-Washington', 'max_temp_15d_avg'],
#  ['Oregon-Washington', 'max_temp_3d_avg'],
#  ['Oregon-Washington', 'max_temp_5d_avg'],
#  ['Oregon-Washington', 'max_wind_speed'],
#  ['Oregon-Washington', 'mean_temp'],
#  ['Oregon-Washington', 'mean_temp_10d_avg'],
#  ['Oregon-Washington', 'mean_temp_15d_avg'],
#  ['Oregon-Washington', 'mean_temp_3d_avg'],
#  ['Oregon-Washington', 'mean_temp_5d_avg'],
#  ['Oregon-Washington', 'min_temp'],
#  ['Oregon-Washington', 'min_temp_10d_avg'],
#  ['Oregon-Washington', 'min_temp_15d_avg'],
#  ['Oregon-Washington', 'min_temp_3d_avg'],
#  ['Oregon-Washington', 'min_temp_5d_avg'],
#  ['Oregon-Washington', 'precip_flag'],
#  ['Oregon-Washington', 'precipitation'],
#  ['Oregon-Washington', 'rain'],
#  ['Oregon-Washington', 'snow'],
#  ['Oregon-Washington', 'station_pressure'],
#  ['Oregon-Washington', 'thunder'],
#  ['Oregon-Washington', 'visibility'],
#  ['Oregon-Washington', 'wind_speed'],
#  ['Washington-King', 'dewpoint'],
#  ['Washington-King', 'dewpoint_10d_avg'],
#  ['Washington-King', 'dewpoint_15d_avg'],
#  ['Washington-King', 'dewpoint_3d_avg'],
#  ['Washington-King', 'dewpoint_5d_avg'],
#  ['Washington-King', 'fog'],
#  ['Washington-King', 'max_temp'],
#  ['Washington-King', 'max_temp_10d_avg'],
#  ['Washington-King', 'max_temp_15d_avg'],
#  ['Washington-King', 'max_temp_3d_avg'],
#  ['Washington-King', 'max_temp_5d_avg'],
#  ['Washington-King', 'max_wind_speed'],
#  ['Washington-King', 'mean_temp'],
#  ['Washington-King', 'mean_temp_10d_avg'],
#  ['Washington-King', 'mean_temp_15d_avg'],
#  ['Washington-King', 'mean_temp_3d_avg'],
#  ['Washington-King', 'mean_temp_5d_avg'],
#  ['Washington-King', 'min_temp'],
#  ['Washington-King', 'min_temp_10d_avg'],
#  ['Washington-King', 'min_temp_15d_avg'],
#  ['Washington-King', 'min_temp_3d_avg'],
#  ['Washington-King', 'min_temp_5d_avg'],
#  ['Washington-King', 'precip_flag'],
#  ['Washington-King', 'precipitation'],
#  ['Washington-King', 'rain'],
#  ['Washington-King', 'station_pressure'],
#  ['Washington-King', 'thunder'],
#  ['Washington-King', 'visibility'],
#  ['Washington-King', 'wind_speed'],
#  ['California-Alameda', 'dewpoint'],
#  ['California-Alameda', 'dewpoint_10d_avg'],
#  ['California-Alameda', 'dewpoint_15d_avg'],
#  ['California-Alameda', 'dewpoint_3d_avg'],
#  ['California-Alameda', 'dewpoint_5d_avg'],
#  ['California-Alameda', 'fog'],
#  ['California-Alameda', 'hail'],
#  ['California-Alameda', 'max_temp'],
#  ['California-Alameda', 'max_temp_10d_avg'],
#  ['California-Alameda', 'max_temp_15d_avg'],
#  ['California-Alameda', 'max_temp_3d_avg'],
#  ['California-Alameda', 'max_temp_5d_avg'],
#  ['California-Alameda', 'max_wind_speed'],
#  ['California-Alameda', 'mean_temp'],
#  ['California-Alameda', 'mean_temp_10d_avg'],
#  ['California-Alameda', 'mean_temp_15d_avg'],
#  ['California-Alameda', 'mean_temp_3d_avg'],
#  ['California-Alameda', 'mean_temp_5d_avg'],
#  ['California-Alameda', 'min_temp'],
#  ['California-Alameda', 'min_temp_10d_avg'],
#  ['California-Alameda', 'min_temp_15d_avg'],
#  ['California-Alameda', 'min_temp_3d_avg'],
#  ['California-Alameda', 'min_temp_5d_avg'],
#  ['California-Alameda', 'precip_flag'],
#  ['California-Alameda', 'precipitation'],
#  ['California-Alameda', 'rain'],
#  ['California-Alameda', 'snow'],
#  ['California-Alameda', 'station_id'],
#  ['California-Alameda', 'station_name'],
#  ['California-Alameda', 'station_pressure'],
#  ['California-Alameda', 'thunder'],
#  ['California-Alameda', 'tornado'],
#  ['California-Alameda', 'visibility'],
#  ['California-Alameda', 'wind_speed'],
#  ['Florida-Hillsborough', 'dewpoint'],
#  ['Florida-Hillsborough', 'dewpoint_10d_avg'],
#  ['Florida-Hillsborough', 'dewpoint_15d_avg'],
#  ['Florida-Hillsborough', 'dewpoint_3d_avg'],
#  ['Florida-Hillsborough', 'dewpoint_5d_avg'],
#  ['Florida-Hillsborough', 'fog'],
#  ['Florida-Hillsborough', 'hail'],
#  ['Florida-Hillsborough', 'max_temp'],
#  ['Florida-Hillsborough', 'max_temp_10d_avg'],
#  ['Florida-Hillsborough', 'max_temp_15d_avg'],
#  ['Florida-Hillsborough', 'max_temp_3d_avg'],
#  ['Florida-Hillsborough', 'max_temp_5d_avg'],
#  ['Florida-Hillsborough', 'max_wind_speed'],
#  ['Florida-Hillsborough', 'mean_temp'],
#  ['Florida-Hillsborough', 'mean_temp_10d_avg'],
#  ['Florida-Hillsborough', 'mean_temp_15d_avg'],
#  ['Florida-Hillsborough', 'mean_temp_3d_avg'],
#  ['Florida-Hillsborough', 'mean_temp_5d_avg'],
#  ['Florida-Hillsborough', 'min_temp'],
#  ['Florida-Hillsborough', 'min_temp_10d_avg'],
#  ['Florida-Hillsborough', 'min_temp_15d_avg'],
#  ['Florida-Hillsborough', 'min_temp_3d_avg'],
#  ['Florida-Hillsborough', 'min_temp_5d_avg'],
#  ['Florida-Hillsborough', 'precip_flag'],
#  ['Florida-Hillsborough', 'precipitation'],
#  ['Florida-Hillsborough', 'rain'],
#  ['Florida-Hillsborough', 'snow'],
#  ['Florida-Hillsborough', 'station_id'],
#  ['Florida-Hillsborough', 'station_name'],
#  ['Florida-Hillsborough', 'station_pressure'],
#  ['Florida-Hillsborough', 'thunder'],
#  ['Florida-Hillsborough', 'tornado'],
#  ['Florida-Hillsborough', 'visibility'],
#  ['Florida-Hillsborough', 'wind_speed'],
#  ['Florida-Manatee', 'dewpoint'],
#  ['Florida-Manatee', 'dewpoint_10d_avg'],
#  ['Florida-Manatee', 'dewpoint_15d_avg'],
#  ['Florida-Manatee', 'dewpoint_3d_avg'],
#  ['Florida-Manatee', 'dewpoint_5d_avg'],
#  ['Florida-Manatee', 'fog'],
#  ['Florida-Manatee', 'hail'],
#  ['Florida-Manatee', 'max_temp'],
#  ['Florida-Manatee', 'max_temp_10d_avg'],
#  ['Florida-Manatee', 'max_temp_15d_avg'],
#  ['Florida-Manatee', 'max_temp_3d_avg'],
#  ['Florida-Manatee', 'max_temp_5d_avg'],
#  ['Florida-Manatee', 'max_wind_speed'],
#  ['Florida-Manatee', 'mean_temp'],
#  ['Florida-Manatee', 'mean_temp_10d_avg'],
#  ['Florida-Manatee', 'mean_temp_15d_avg'],
#  ['Florida-Manatee', 'mean_temp_3d_avg'],
#  ['Florida-Manatee', 'mean_temp_5d_avg'],
#  ['Florida-Manatee', 'min_temp'],
#  ['Florida-Manatee', 'min_temp_10d_avg'],
#  ['Florida-Manatee', 'min_temp_15d_avg'],
#  ['Florida-Manatee', 'min_temp_3d_avg'],
#  ['Florida-Manatee', 'min_temp_5d_avg'],
#  ['Florida-Manatee', 'precip_flag'],
#  ['Florida-Manatee', 'precipitation'],
#  ['Florida-Manatee', 'rain'],
#  ['Florida-Manatee', 'snow'],
#  ['Florida-Manatee', 'station_id'],
#  ['Florida-Manatee', 'station_name'],
#  ['Florida-Manatee', 'station_pressure'],
#  ['Florida-Manatee', 'thunder'],
#  ['Florida-Manatee', 'tornado'],
#  ['Florida-Manatee', 'visibility'],
#  ['Florida-Manatee', 'wind_speed'],
#  ['New York-New York City', 'dewpoint'],
#  ['New York-New York City', 'dewpoint_10d_avg'],
#  ['New York-New York City', 'dewpoint_15d_avg'],
#  ['New York-New York City', 'dewpoint_3d_avg'],
#  ['New York-New York City', 'dewpoint_5d_avg'],
#  ['New York-New York City', 'fog'],
#  ['New York-New York City', 'hail'],
#  ['New York-New York City', 'max_temp'],
#  ['New York-New York City', 'max_temp_10d_avg'],
#  ['New York-New York City', 'max_temp_15d_avg'],
#  ['New York-New York City', 'max_temp_3d_avg'],
#  ['New York-New York City', 'max_temp_5d_avg'],
#  ['New York-New York City', 'max_wind_speed'],
#  ['New York-New York City', 'mean_temp'],
#  ['New York-New York City', 'mean_temp_10d_avg'],
#  ['New York-New York City', 'mean_temp_15d_avg'],
#  ['New York-New York City', 'mean_temp_3d_avg'],
#  ['New York-New York City', 'mean_temp_5d_avg'],
#  ['New York-New York City', 'min_temp'],
#  ['New York-New York City', 'min_temp_10d_avg'],
#  ['New York-New York City', 'min_temp_15d_avg'],
#  ['New York-New York City', 'min_temp_3d_avg'],
#  ['New York-New York City', 'min_temp_5d_avg'],
#  ['New York-New York City', 'precip_flag'],
#  ['New York-New York City', 'precipitation'],
#  ['New York-New York City', 'rain'],
#  ['New York-New York City', 'snow'],
#  ['New York-New York City', 'station_id'],
#  ['New York-New York City', 'station_name'],
#  ['New York-New York City', 'thunder'],
#  ['New York-New York City', 'tornado'],
#  ['New York-New York City', 'visibility'],
#  ['New York-New York City', 'wind_speed'],
#  ['California-Placer', 'dewpoint'],
#  ['California-Placer', 'dewpoint_10d_avg'],
#  ['California-Placer', 'dewpoint_15d_avg'],
#  ['California-Placer', 'dewpoint_3d_avg'],
#  ['California-Placer', 'dewpoint_5d_avg'],
#  ['California-Placer', 'fog'],
#  ['California-Placer', 'hail'],
#  ['California-Placer', 'max_temp'],
#  ['California-Placer', 'max_temp_10d_avg'],
#  ['California-Placer', 'max_temp_15d_avg'],
#  ['California-Placer', 'max_temp_3d_avg'],
#  ['California-Placer', 'max_temp_5d_avg'],
#  ['California-Placer', 'max_wind_speed'],
#  ['California-Placer', 'mean_temp'],
#  ['California-Placer', 'mean_temp_10d_avg'],
#  ['California-Placer', 'mean_temp_15d_avg'],
#  ['California-Placer', 'mean_temp_3d_avg'],
#  ['California-Placer', 'mean_temp_5d_avg'],
#  ['California-Placer', 'min_temp'],
#  ['California-Placer', 'min_temp_10d_avg'],
#  ['California-Placer', 'min_temp_15d_avg'],
#  ['California-Placer', 'min_temp_3d_avg'],
#  ['California-Placer', 'min_temp_5d_avg'],
#  ['California-Placer', 'precip_flag'],
#  ['California-Placer', 'precipitation'],
#  ['California-Placer', 'rain'],
#  ['California-Placer', 'snow'],
#  ['California-Placer', 'station_id'],
#  ['California-Placer', 'station_name'],
#  ['California-Placer', 'station_pressure'],
#  ['California-Placer', 'thunder'],
#  ['California-Placer', 'tornado'],
#  ['California-Placer', 'visibility'],
#  ['California-Placer', 'wind_speed'],
#  ['California-San Mateo', 'dewpoint'],
#  ['California-San Mateo', 'dewpoint_10d_avg'],
#  ['California-San Mateo', 'dewpoint_15d_avg'],
#  ['California-San Mateo', 'dewpoint_3d_avg'],
#  ['California-San Mateo', 'dewpoint_5d_avg'],
#  ['California-San Mateo', 'fog'],
#  ['California-San Mateo', 'hail'],
#  ['California-San Mateo', 'max_temp'],
#  ['California-San Mateo', 'max_temp_10d_avg'],
#  ['California-San Mateo', 'max_temp_15d_avg'],
#  ['California-San Mateo', 'max_temp_3d_avg'],
#  ['California-San Mateo', 'max_temp_5d_avg'],
#  ['California-San Mateo', 'max_wind_speed'],
#  ['California-San Mateo', 'mean_temp'],
#  ['California-San Mateo', 'mean_temp_10d_avg'],
#  ['California-San Mateo', 'mean_temp_15d_avg'],
#  ['California-San Mateo', 'mean_temp_3d_avg'],
#  ['California-San Mateo', 'mean_temp_5d_avg'],
#  ['California-San Mateo', 'min_temp'],
#  ['California-San Mateo', 'min_temp_10d_avg'],
#  ['California-San Mateo', 'min_temp_15d_avg'],
#  ['California-San Mateo', 'min_temp_3d_avg'],
#  ['California-San Mateo', 'min_temp_5d_avg'],
#  ['California-San Mateo', 'precip_flag'],
#  ['California-San Mateo', 'precipitation'],
#  ['California-San Mateo', 'rain'],
#  ['California-San Mateo', 'snow'],
#  ['California-San Mateo', 'station_id'],
#  ['California-San Mateo', 'station_name'],
#  ['California-San Mateo', 'station_pressure'],
#  ['California-San Mateo', 'thunder'],
#  ['California-San Mateo', 'tornado'],
#  ['California-San Mateo', 'visibility'],
#  ['California-San Mateo', 'wind_speed'],
#  ['Georgia-Fulton', 'dewpoint'],
#  ['Georgia-Fulton', 'dewpoint_10d_avg'],
#  ['Georgia-Fulton', 'dewpoint_15d_avg'],
#  ['Georgia-Fulton', 'dewpoint_3d_avg'],
#  ['Georgia-Fulton', 'dewpoint_5d_avg'],
#  ['Georgia-Fulton', 'fog'],
#  ['Georgia-Fulton', 'hail'],
#  ['Georgia-Fulton', 'max_temp'],
#  ['Georgia-Fulton', 'max_temp_10d_avg'],
#  ['Georgia-Fulton', 'max_temp_15d_avg'],
#  ['Georgia-Fulton', 'max_temp_3d_avg'],
#  ['Georgia-Fulton', 'max_temp_5d_avg'],
#  ['Georgia-Fulton', 'max_wind_speed'],
#  ['Georgia-Fulton', 'mean_temp'],
#  ['Georgia-Fulton', 'mean_temp_10d_avg'],
#  ['Georgia-Fulton', 'mean_temp_15d_avg'],
#  ['Georgia-Fulton', 'mean_temp_3d_avg'],
#  ['Georgia-Fulton', 'mean_temp_5d_avg'],
#  ['Georgia-Fulton', 'min_temp'],
#  ['Georgia-Fulton', 'min_temp_10d_avg'],
#  ['Georgia-Fulton', 'min_temp_15d_avg'],
#  ['Georgia-Fulton', 'min_temp_3d_avg'],
#  ['Georgia-Fulton', 'min_temp_5d_avg'],
#  ['Georgia-Fulton', 'precip_flag'],
#  ['Georgia-Fulton', 'precipitation'],
#  ['Georgia-Fulton', 'rain'],
#  ['Georgia-Fulton', 'snow'],
#  ['Georgia-Fulton', 'station_id'],
#  ['Georgia-Fulton', 'station_name'],
#  ['Georgia-Fulton', 'station_pressure'],
#  ['Georgia-Fulton', 'thunder'],
#  ['Georgia-Fulton', 'tornado'],
#  ['Georgia-Fulton', 'visibility'],
#  ['Georgia-Fulton', 'wind_speed'],
#  ['Massachusetts-Norfolk', 'dewpoint'],
#  ['Massachusetts-Norfolk', 'dewpoint_10d_avg'],
#  ['Massachusetts-Norfolk', 'dewpoint_15d_avg'],
#  ['Massachusetts-Norfolk', 'dewpoint_3d_avg'],
#  ['Massachusetts-Norfolk', 'dewpoint_5d_avg'],
#  ['Massachusetts-Norfolk', 'fog'],
#  ['Massachusetts-Norfolk', 'max_temp'],
#  ['Massachusetts-Norfolk', 'max_temp_10d_avg'],
#  ['Massachusetts-Norfolk', 'max_temp_15d_avg'],
#  ['Massachusetts-Norfolk', 'max_temp_3d_avg'],
#  ['Massachusetts-Norfolk', 'max_temp_5d_avg'],
#  ['Massachusetts-Norfolk', 'max_wind_speed'],
#  ['Massachusetts-Norfolk', 'mean_temp'],
#  ['Massachusetts-Norfolk', 'mean_temp_10d_avg'],
#  ['Massachusetts-Norfolk', 'mean_temp_15d_avg'],
#  ['Massachusetts-Norfolk', 'mean_temp_3d_avg'],
#  ['Massachusetts-Norfolk', 'mean_temp_5d_avg'],
#  ['Massachusetts-Norfolk', 'min_temp'],
#  ['Massachusetts-Norfolk', 'min_temp_10d_avg'],
#  ['Massachusetts-Norfolk', 'min_temp_15d_avg'],
#  ['Massachusetts-Norfolk', 'min_temp_3d_avg'],
#  ['Massachusetts-Norfolk', 'min_temp_5d_avg'],
#  ['Massachusetts-Norfolk', 'precip_flag'],
#  ['Massachusetts-Norfolk', 'precipitation'],
#  ['Massachusetts-Norfolk', 'rain'],
#  ['Massachusetts-Norfolk', 'snow'],
#  ['Massachusetts-Norfolk', 'station_pressure'],
#  ['Massachusetts-Norfolk', 'thunder'],
#  ['Massachusetts-Norfolk', 'visibility'],
#  ['Massachusetts-Norfolk', 'wind_speed'],
#  ['New Hampshire-Grafton', 'dewpoint'],
#  ['New Hampshire-Grafton', 'dewpoint_10d_avg'],
#  ['New Hampshire-Grafton', 'dewpoint_15d_avg'],
#  ['New Hampshire-Grafton', 'dewpoint_3d_avg'],
#  ['New Hampshire-Grafton', 'dewpoint_5d_avg'],
#  ['New Hampshire-Grafton', 'fog'],
#  ['New Hampshire-Grafton', 'max_temp'],
#  ['New Hampshire-Grafton', 'max_temp_10d_avg'],
#  ['New Hampshire-Grafton', 'max_temp_15d_avg'],
#  ['New Hampshire-Grafton', 'max_temp_3d_avg'],
#  ['New Hampshire-Grafton', 'max_temp_5d_avg'],
#  ['New Hampshire-Grafton', 'max_wind_speed'],
#  ['New Hampshire-Grafton', 'mean_temp'],
#  ['New Hampshire-Grafton', 'mean_temp_10d_avg'],
#  ['New Hampshire-Grafton', 'mean_temp_15d_avg'],
#  ['New Hampshire-Grafton', 'mean_temp_3d_avg'],
#  ['New Hampshire-Grafton', 'mean_temp_5d_avg'],
#  ['New Hampshire-Grafton', 'min_temp'],
#  ['New Hampshire-Grafton', 'min_temp_10d_avg'],
#  ['New Hampshire-Grafton', 'min_temp_15d_avg'],
#  ['New Hampshire-Grafton', 'min_temp_3d_avg'],
#  ['New Hampshire-Grafton', 'min_temp_5d_avg'],
#  ['New Hampshire-Grafton', 'precip_flag'],
#  ['New Hampshire-Grafton', 'precipitation'],
#  ['New Hampshire-Grafton', 'rain'],
#  ['New Hampshire-Grafton', 'snow'],
#  ['New Hampshire-Grafton', 'station_pressure'],
#  ['New Hampshire-Grafton', 'thunder'],
#  ['New Hampshire-Grafton', 'visibility'],
#  ['New Hampshire-Grafton', 'wind_speed'],
#  ['Washington-Walla Walla', 'dewpoint'],
#  ['Washington-Walla Walla', 'dewpoint_10d_avg'],
#  ...]

# %%
data['entity'] = data['state'] + '-' + data['county']
cook = data[data['entity']=='Illinois-Cook']

# %%
import matplotlib.pyplot as plt

# Now let's create the scatter plot
plt.figure(figsize=(10, 5))

# Scatter plot for population vs cases
plt.scatter(cook['date'],cook['mean_temp_3d_avg'])
plt.scatter(cook['date'],cook['cases']/5000)
# Adding title and labels
plt.title('Case and Temperature Progression in Cook County')
plt.xlabel('Date')
plt.ylabel('Cases (Orange) \n Temp (Blue)')
plt.tick_params(labelbottom = False, labelleft = False, left = False, bottom = False)

# Show the plot
plt.show()

# %%
la = data[data['entity']=='California-Los Angeles']

# %%
import matplotlib.pyplot as plt

# Now let's create the scatter plot
plt.figure(figsize=(10, 6))

# Scatter plot for population vs cases
plt.scatter(la['date'],la['mean_temp_3d_avg'])
plt.scatter(la['date'],la['cases']/10000)
# Adding title and labels
plt.title('Mean Temp vs Case')
plt.xlabel('Mean Temp')
plt.ylabel('Cases')

# Show the plot
plt.show()

# %%
cook.head()
# Out:
#           date county     state   fips  cases  deaths stay_at_home_announced  \
# 3   2020-01-24   Cook  Illinois  17031      1     0.0                     no
# 6   2020-01-25   Cook  Illinois  17031      1     0.0                     no
# 11  2020-01-26   Cook  Illinois  17031      1     0.0                     no
# 16  2020-01-27   Cook  Illinois  17031      1     0.0                     no
# 21  2020-01-28   Cook  Illinois  17031      1     0.0                     no
#
#    stay_at_home_effective        lat        lon  ...  min_temp_5d_avg  \
# 3                      no  41.840039 -87.816716  ...            30.02
# 6                      no  41.840039 -87.816716  ...            30.80
# 11                     no  41.840039 -87.816716  ...            31.20
# 16                     no  41.840039 -87.816716  ...            30.40
# 21                     no  41.840039 -87.816716  ...            29.96
#
#     min_temp_10d_avg  min_temp_15d_avg  dewpoint_3d_avg  dewpoint_5d_avg  \
# 3              27.43         24.886667        31.433333            28.50
# 6              28.81         25.953333        32.233333            29.98
# 11             30.19         27.080000        29.600000            30.02
# 16             31.09         28.880000        27.400000            28.00
# 21             31.49         29.873333        26.000000            26.10
#
#     dewpoint_10d_avg  dewpoint_15d_avg  date_stay_at_home_announced  \
# 3              25.00         22.693333                   2020-03-20
# 6              25.96         24.000000                   2020-03-20
# 11             27.15         24.266667                   2020-03-20
# 16             28.27         26.313333                   2020-03-20
# 21             28.76         27.246667                   2020-03-20
#
#     date_stay_at_home_effective         entity
# 3                    2020-03-21  Illinois-Cook
# 6                    2020-03-21  Illinois-Cook
# 11                   2020-03-21  Illinois-Cook
# 16                   2020-03-21  Illinois-Cook
# 21                   2020-03-21  Illinois-Cook
#
# [5 rows x 228 columns]
