# %% [markdown]
# # Arima Models for California Counties

# %%
pip install prophet
# Out:
# Requirement already satisfied: prophet in /Users/elenallaguno/anaconda3/lib/python3.11/site-packages (1.1.5)
# Requirement already satisfied: cmdstanpy>=1.0.4 in /Users/elenallaguno/anaconda3/lib/python3.11/site-packages (from prophet) (1.2.1)
# Requirement already satisfied: numpy>=1.15.4 in /Users/elenallaguno/anaconda3/lib/python3.11/site-packages (from prophet) (1.23.5)
# Requirement already satisfied: matplotlib>=2.0.0 in /Users/elenallaguno/anaconda3/lib/python3.11/site-packages (from prophet) (3.7.2)
# Requirement already satisfied: pandas>=1.0.4 in /Users/elenallaguno/anaconda3/lib/python3.11/site-packages (from prophet) (2.1.1)
# Requirement already satisfied: holidays>=0.25 in /Users/elenallaguno/anaconda3/lib/python3.11/site-packages (from prophet) (0.43)
# Requirement already satisfied: tqdm>=4.36.1 in /Users/elenallaguno/anaconda3/lib/python3.11/site-packages (from prophet) (4.65.0)
# Requirement already satisfied: importlib-resources in /Users/elenallaguno/anaconda3/lib/python3.11/site-packages (from prophet) (6.1.1)
# Requirement already satisfied: stanio~=0.3.0 in /Users/elenallaguno/anaconda3/lib/python3.11/site-packages (from cmdstanpy>=1.0.4->prophet) (0.3.0)
# Requirement already satisfied: python-dateutil in /Users/elenallaguno/anaconda3/lib/python3.11/site-packages (from holidays>=0.25->prophet) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/elenallaguno/anaconda3/lib/python3.11/site-packages (from matplotlib>=2.0.0->prophet) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/elenallaguno/anaconda3/lib/python3.11/site-packages (from matplotlib>=2.0.0->prophet) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/elenallaguno/anaconda3/lib/python3.11/site-packages (from matplotlib>=2.0.0->prophet) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/elenallaguno/anaconda3/lib/python3.11/site-packages (from matplotlib>=2.0.0->prophet) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/elenallaguno/anaconda3/lib/python3.11/site-packages (from matplotlib>=2.0.0->prophet) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/elenallaguno/anaconda3/lib/python3.11/site-packages (from matplotlib>=2.0.0->prophet) (10.0.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /Users/elenallaguno/anaconda3/lib/python3.11/site-packages (from matplotlib>=2.0.0->prophet) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in /Users/elenallaguno/anaconda3/lib/python3.11/site-packages (from pandas>=1.0.4->prophet) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/elenallaguno/anaconda3/lib/python3.11/site-packages (from pandas>=1.0.4->prophet) (2023.3)
# Requirement already satisfied: six>=1.5 in /Users/elenallaguno/anaconda3/lib/python3.11/site-packages (from python-dateutil->holidays>=0.25->prophet) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import warnings
import pandas as pd
from matplotlib import pyplot
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import r2_score, mean_squared_error
warnings.filterwarnings('ignore')
from statsmodels.tsa.arima.model import ARIMA
import statsmodels.api as sm
from pmdarima import auto_arima
from sklearn.model_selection import TimeSeriesSplit
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error
from pmdarima import auto_arima
import pandas as pd
from sklearn.metrics import r2_score
import numpy as np
from prophet import Prophet
import pandas as pd
import itertools
from prophet import Prophet
from prophet.diagnostics import cross_validation, performance_metrics
import pandas as pd

# %%
data = pd.read_csv('finalized_county.csv')

# %%
california_data = data[data['state'] == 'California']
california_data['date'] = pd.to_datetime(california_data['date'], format="%Y-%m-%d")
california_data['county'].unique()
# Out:
# array(['Los Angeles', 'Orange', 'San Diego'], dtype=object)

# %% [markdown]
# # Los Angeles

# %%
la = california_data[california_data['county'] == 'Los Angeles'].loc[:, ['date', 'incremental_cases']]
la['incremental_cases'] = la['incremental_cases'].astype('int')
la['date'] = pd.to_datetime(la['date'], format="%Y-%m-%d")

# %%
la.shape
# Out:
# (270, 2)

# %%
# use 85%-15% for train-test split
train = la.iloc[:230, :]
test = la.iloc[230:, :]

# %%
# use non-differenced cases for test actuals
testing = data[data['county'] == 'Los Angeles'].loc[:, ['date', 'incremental_cases']]
test = testing.iloc[230:, :]

# Plotting actual test data
sns.lineplot(x="date", y="incremental_cases",legend = 'full' , data=testing)
# Out:
# <Axes: xlabel='date', ylabel='incremental_cases'>

# %%
# Prepare the training data for Prophet
train = train.reset_index().rename(columns={'date': 'ds', 'incremental_cases': 'y'})
test = test.reset_index().rename(columns={'date': 'ds', 'incremental_cases': 'y'})

# Define the parameter grid to search
param_grid = {
    'changepoint_prior_scale': [0.001, 0.01, 0.1, 0.5, 1, 1.5, 2],
    'seasonality_prior_scale': [0.01, 0.1, 1.0, 1.5, 2],
}

# Generate all combinations of parameters
all_params = [dict(zip(param_grid.keys(), v)) for v in itertools.product(*param_grid.values())]
mses = []  # Store the MSEs for each params here

# Use cross-validation to evaluate all parameters
for params in all_params:
    m = Prophet(**params)
    m.fit(train)  # Fit model with given params
    df_cv = cross_validation(m, initial='190 days', period='180 days', horizon='20 days')
    df_p = performance_metrics(df_cv, rolling_window=1)
    mses.append(df_p['mse'].values[0])  # Use MSE

# Find the best parameters
tuning_results = pd.DataFrame(all_params)
tuning_results['mse'] = mses
best_parameters = tuning_results.loc[tuning_results['mse'].idxmin()]

print(tuning_results)
print(f"Best Parameters: {best_parameters}")
# Out:
# 18:03:53 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:53 - cmdstanpy - INFO - Chain [1] done processing
# 18:03:53 - cmdstanpy - ERROR - Chain [1] error: error during processing Operation not permitted
# Optimization terminated abnormally. Falling back to Newton.
# 18:03:53 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:53 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:03:53 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:53 - cmdstanpy - INFO - Chain [1] done processing
# 18:03:53 - cmdstanpy - ERROR - Chain [1] error: error during processing Operation not permitted
# Optimization terminated abnormally. Falling back to Newton.
# 18:03:53 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:53 - cmdstanpy - INFO - Chain [1] done processing
# 18:03:53 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:53 - cmdstanpy - INFO - Chain [1] done processing
# 18:03:53 - cmdstanpy - ERROR - Chain [1] error: error during processing Operation not permitted
# Optimization terminated abnormally. Falling back to Newton.
# 18:03:53 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:53 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:03:53 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:53 - cmdstanpy - INFO - Chain [1] done processing
# 18:03:53 - cmdstanpy - ERROR - Chain [1] error: error during processing Operation not permitted
# Optimization terminated abnormally. Falling back to Newton.
# 18:03:53 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:53 - cmdstanpy - INFO - Chain [1] done processing
# 18:03:54 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:54 - cmdstanpy - INFO - Chain [1] done processing
# 18:03:54 - cmdstanpy - ERROR - Chain [1] error: error during processing Operation not permitted
# Optimization terminated abnormally. Falling back to Newton.
# 18:03:54 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:54 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:03:54 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:54 - cmdstanpy - INFO - Chain [1] done processing
# 18:03:54 - cmdstanpy - ERROR - Chain [1] error: error during processing Operation not permitted
# Optimization terminated abnormally. Falling back to Newton.
# 18:03:54 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:54 - cmdstanpy - INFO - Chain [1] done processing
# 18:03:54 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:54 - cmdstanpy - INFO - Chain [1] done processing
# 18:03:54 - cmdstanpy - ERROR - Chain [1] error: error during processing Operation not permitted
# Optimization terminated abnormally. Falling back to Newton.
# 18:03:54 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:54 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:03:54 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:54 - cmdstanpy - INFO - Chain [1] done processing
# 18:03:54 - cmdstanpy - ERROR - Chain [1] error: error during processing Operation not permitted
# Optimization terminated abnormally. Falling back to Newton.
# 18:03:54 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:54 - cmdstanpy - INFO - Chain [1] done processing
# 18:03:54 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:54 - cmdstanpy - INFO - Chain [1] done processing
# 18:03:54 - cmdstanpy - ERROR - Chain [1] error: error during processing Operation not permitted
# Optimization terminated abnormally. Falling back to Newton.
# 18:03:54 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:54 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:03:54 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:54 - cmdstanpy - INFO - Chain [1] done processing
# 18:03:54 - cmdstanpy - ERROR - Chain [1] error: error during processing Operation not permitted
# Optimization terminated abnormally. Falling back to Newton.
# 18:03:54 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:55 - cmdstanpy - INFO - Chain [1] done processing
# 18:03:55 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:55 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:03:55 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:55 - cmdstanpy - INFO - Chain [1] done processing
# 18:03:55 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:55 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:03:55 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:55 - cmdstanpy - INFO - Chain [1] done processing
# 18:03:55 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:55 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:03:55 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:55 - cmdstanpy - INFO - Chain [1] done processing
# 18:03:55 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:55 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:03:55 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:55 - cmdstanpy - INFO - Chain [1] done processing
# 18:03:55 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:55 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:03:55 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:55 - cmdstanpy - INFO - Chain [1] done processing
# 18:03:55 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:55 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:03:55 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:55 - cmdstanpy - INFO - Chain [1] done processing
# 18:03:55 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:55 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:03:55 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:55 - cmdstanpy - INFO - Chain [1] done processing
# 18:03:55 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:55 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:03:55 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:55 - cmdstanpy - INFO - Chain [1] done processing
# 18:03:55 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:55 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:03:55 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:55 - cmdstanpy - INFO - Chain [1] done processing
# 18:03:55 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:55 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:03:55 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:55 - cmdstanpy - INFO - Chain [1] done processing
# 18:03:55 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:56 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:03:56 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:56 - cmdstanpy - INFO - Chain [1] done processing
# 18:03:56 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:56 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:03:56 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:56 - cmdstanpy - INFO - Chain [1] done processing
# 18:03:56 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:56 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:03:56 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:56 - cmdstanpy - INFO - Chain [1] done processing
# 18:03:56 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:56 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:03:56 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:56 - cmdstanpy - INFO - Chain [1] done processing
# 18:03:56 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:56 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:03:56 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:56 - cmdstanpy - INFO - Chain [1] done processing
# 18:03:56 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:56 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:03:56 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:56 - cmdstanpy - INFO - Chain [1] done processing
# 18:03:56 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:56 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:03:56 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:56 - cmdstanpy - INFO - Chain [1] done processing
# 18:03:56 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:56 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:03:56 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:56 - cmdstanpy - INFO - Chain [1] done processing
# 18:03:56 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:56 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:03:56 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:56 - cmdstanpy - INFO - Chain [1] done processing
# 18:03:56 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:56 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:03:56 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:56 - cmdstanpy - INFO - Chain [1] done processing
# 18:03:56 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:57 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:03:57 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:57 - cmdstanpy - INFO - Chain [1] done processing
# 18:03:57 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:57 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:03:57 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:57 - cmdstanpy - INFO - Chain [1] done processing
# 18:03:57 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:57 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:03:57 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:57 - cmdstanpy - INFO - Chain [1] done processing
# 18:03:57 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:57 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:03:57 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:57 - cmdstanpy - INFO - Chain [1] done processing
# 18:03:57 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:57 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:03:57 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:57 - cmdstanpy - INFO - Chain [1] done processing
# 18:03:57 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:57 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:03:57 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:57 - cmdstanpy - INFO - Chain [1] done processing
# 18:03:57 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:57 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:03:57 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:57 - cmdstanpy - INFO - Chain [1] done processing
# 18:03:57 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:57 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:03:57 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:57 - cmdstanpy - INFO - Chain [1] done processing
# 18:03:57 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:57 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:03:57 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:57 - cmdstanpy - INFO - Chain [1] done processing
# 18:03:57 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:57 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:03:57 - cmdstanpy - INFO - Chain [1] start processing
# 18:03:57 - cmdstanpy - INFO - Chain [1] done processing
#     changepoint_prior_scale  seasonality_prior_scale           mse
# 0                     0.001                     0.01  1.155375e+06
# 1                     0.001                     0.10  1.127992e+06
# 2                     0.001                     1.00  1.075051e+06
# 3                     0.001                     1.50  1.069239e+06
# 4                     0.001                     2.00  1.070097e+06
# 5                     0.010                     0.01  9.910220e+05
# 6                     0.010                     0.10  9.644628e+05
# 7                     0.010                     1.00  9.504043e+05
# 8                     0.010                     1.50  9.508167e+05
# 9                     0.010                     2.00  9.504983e+05
# 10                    0.100                     0.01  1.509075e+06
# 11                    0.100                     0.10  1.490289e+06
# 12                    0.100                     1.00  1.509245e+06
# 13                    0.100                     1.50  1.485461e+06
# 14                    0.100                     2.00  1.509149e+06
# 15                    0.500                     0.01  9.566520e+05
# 16                    0.500                     0.10  9.152169e+05
# 17                    0.500                     1.00  9.123899e+05
# 18                    0.500                     1.50  8.904170e+05
# 19                    0.500                     2.00  9.155110e+05
# 20                    1.000                     0.01  8.830048e+05
# 21                    1.000                     0.10  8.466658e+05
# 22                    1.000                     1.00  8.435658e+05
# 23                    1.000                     1.50  8.338737e+05
# 24                    1.000                     2.00  8.381309e+05
# 25                    1.500                     0.01  8.504973e+05
# 26                    1.500                     0.10  8.116862e+05
# 27                    1.500                     1.00  7.993806e+05
# 28                    1.500                     1.50  8.125546e+05
# 29                    1.500                     2.00  8.049347e+05
# 30                    2.000                     0.01  8.181454e+05
# 31                    2.000                     0.10  7.891709e+05
# 32                    2.000                     1.00  7.839143e+05
# 33                    2.000                     1.50  7.835792e+05
# 34                    2.000                     2.00  7.891571e+05
# Best Parameters: changepoint_prior_scale         2.000000
# seasonality_prior_scale         1.500000
# mse                        783579.174149
# Name: 33, dtype: float64

# %%
from prophet import Prophet
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# Your best parameters
best_params = {
    'changepoint_prior_scale': 2,
    'seasonality_prior_scale': 1.5,
}

# Create and fit a Prophet model with the best parameters
model = Prophet(changepoint_prior_scale=best_params['changepoint_prior_scale'],
                seasonality_prior_scale=best_params['seasonality_prior_scale'])
model.fit(train)

# Make predictions on the training set
train_forecast = model.predict(train)

# Make predictions on the test set
test_forecast = model.predict(test)

# Calculate R^2 for the training set
train_r2 = r2_score(train['y'], train_forecast['yhat'])
print(f'Training Set R^2: {train_r2}')

# Calculate R^2 for the test set
test_r2 = r2_score(test['y'], test_forecast['yhat'])
print(f'Test Set R^2: {test_r2}')
# Out:
# 18:04:04 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:04 - cmdstanpy - INFO - Chain [1] done processing
# Training Set R^2: 0.759954462388528
# Test Set R^2: -0.6501646519971056

# %%
# Plot the training data and predictions
fig, ax = plt.subplots(ncols=2, figsize=(14, 6))

# Configure date formatting and rotate date labels for better visibility
date_formatter = mdates.DateFormatter('%Y-%m-%d')
test['ds'] = pd.to_datetime(test['ds'])


# Training plot
ax[0].plot(train['ds'], train['y'], label='Actual')
ax[0].plot(train['ds'], train_forecast['yhat'], label='Predicted')
ax[0].fill_between(train['ds'], train_forecast['yhat_lower'], train_forecast['yhat_upper'], alpha=0.2)
ax[0].set_title('Prophet Los Angeles - Training Data and Predictions')
ax[0].xaxis.set_major_locator(mdates.AutoDateLocator())
ax[0].xaxis.set_major_formatter(date_formatter)
plt.setp(ax[0].get_xticklabels(), rotation=45, ha='right')

# Test plot
ax[1].plot(test['ds'], test['y'], label='Actual')
ax[1].plot(test['ds'], test_forecast['yhat'], label='Predicted')
ax[1].fill_between(test['ds'], test_forecast['yhat_lower'], test_forecast['yhat_upper'], alpha=0.2)
ax[1].set_title('Prophet Los Angeles - Test Data and Predictions')
ax[1].xaxis.set_major_locator(mdates.AutoDateLocator())
ax[1].xaxis.set_major_formatter(date_formatter)
plt.setp(ax[1].get_xticklabels(), rotation=45, ha='right')

# Adjust layout
plt.tight_layout()

# Show the plot with the new date format
plt.show()

# %% [markdown]
# # Orange

# %%
orange = california_data[california_data['county'] == 'Orange'].loc[:, ['date', 'incremental_cases']]
orange['incremental_cases'] = orange['incremental_cases'].astype('int')
orange['date'] = pd.to_datetime(orange['date'], format="%Y-%m-%d")

def stationary_test(series):
    result = adfuller(series)
    return (result[0], result[1])

# Orange is non-stationary
print("Stationary or not?:", stationary_test(orange.incremental_cases))
# Out:
# Stationary or not?: (-0.1897980045327783, 0.9397267929055788)

# %%
orange.shape
# Out:
# (270, 2)

# %%
# use 85%-15% for train-test split
train = orange.iloc[:230, :]
test = orange.iloc[230:, :]

# %%
# use non-differenced cases for test actuals
testing = data[data['county'] == 'Orange'].loc[:, ['date', 'incremental_cases']]
test = testing.iloc[230:, :]

# Plotting actual test data
sns.lineplot(x="date", y="incremental_cases",legend = 'full' , data=testing)
# Out:
# <Axes: xlabel='date', ylabel='incremental_cases'>

# %%
# Prepare the training data for Prophet
train = train.reset_index().rename(columns={'date': 'ds', 'incremental_cases': 'y'})
test = test.reset_index().rename(columns={'date': 'ds', 'incremental_cases': 'y'})

# Define the parameter grid to search
param_grid = {
    'changepoint_prior_scale': [0.001, 0.01, 0.1, 0.5, 1, 1.5, 2, 2.5],
    'seasonality_prior_scale': [0.01, 0.1, 1.0, 1.5, 2],
}

# Generate all combinations of parameters
all_params = [dict(zip(param_grid.keys(), v)) for v in itertools.product(*param_grid.values())]
mses = []  # Store the MSEs for each params here

# Use cross-validation to evaluate all parameters
for params in all_params:
    m = Prophet(**params)
    m.fit(train)  # Fit model with given params
    df_cv = cross_validation(m, initial='190 days', period='180 days', horizon='20 days')
    df_p = performance_metrics(df_cv, rolling_window=1)
    mses.append(df_p['mse'].values[0])  # Use MSE

# Find the best parameters
tuning_results = pd.DataFrame(all_params)
tuning_results['mse'] = mses
best_parameters = tuning_results.loc[tuning_results['mse'].idxmin()]

print(tuning_results)
print(f"Best Parameters: {best_parameters}")
# Out:
# 18:04:19 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:19 - cmdstanpy - INFO - Chain [1] done processing
# 18:04:19 - cmdstanpy - ERROR - Chain [1] error: error during processing Operation not permitted
# Optimization terminated abnormally. Falling back to Newton.
# 18:04:19 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:19 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:04:19 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:19 - cmdstanpy - INFO - Chain [1] done processing
# 18:04:19 - cmdstanpy - ERROR - Chain [1] error: error during processing Operation not permitted
# Optimization terminated abnormally. Falling back to Newton.
# 18:04:19 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:19 - cmdstanpy - INFO - Chain [1] done processing
# 18:04:19 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:19 - cmdstanpy - INFO - Chain [1] done processing
# 18:04:19 - cmdstanpy - ERROR - Chain [1] error: error during processing Operation not permitted
# Optimization terminated abnormally. Falling back to Newton.
# 18:04:19 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:20 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:04:20 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:20 - cmdstanpy - INFO - Chain [1] done processing
# 18:04:20 - cmdstanpy - ERROR - Chain [1] error: error during processing Operation not permitted
# Optimization terminated abnormally. Falling back to Newton.
# 18:04:20 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:20 - cmdstanpy - INFO - Chain [1] done processing
# 18:04:20 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:20 - cmdstanpy - INFO - Chain [1] done processing
# 18:04:20 - cmdstanpy - ERROR - Chain [1] error: error during processing Operation not permitted
# Optimization terminated abnormally. Falling back to Newton.
# 18:04:20 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:20 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:04:20 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:20 - cmdstanpy - INFO - Chain [1] done processing
# 18:04:20 - cmdstanpy - ERROR - Chain [1] error: error during processing Operation not permitted
# Optimization terminated abnormally. Falling back to Newton.
# 18:04:20 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:20 - cmdstanpy - INFO - Chain [1] done processing
# 18:04:20 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:20 - cmdstanpy - INFO - Chain [1] done processing
# 18:04:20 - cmdstanpy - ERROR - Chain [1] error: error during processing Operation not permitted
# Optimization terminated abnormally. Falling back to Newton.
# 18:04:20 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:20 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:04:20 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:20 - cmdstanpy - INFO - Chain [1] done processing
# 18:04:20 - cmdstanpy - ERROR - Chain [1] error: error during processing Operation not permitted
# Optimization terminated abnormally. Falling back to Newton.
# 18:04:20 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:21 - cmdstanpy - INFO - Chain [1] done processing
# 18:04:21 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:21 - cmdstanpy - INFO - Chain [1] done processing
# 18:04:21 - cmdstanpy - ERROR - Chain [1] error: error during processing Operation not permitted
# Optimization terminated abnormally. Falling back to Newton.
# 18:04:21 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:21 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:04:21 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:21 - cmdstanpy - INFO - Chain [1] done processing
# 18:04:21 - cmdstanpy - ERROR - Chain [1] error: error during processing Operation not permitted
# Optimization terminated abnormally. Falling back to Newton.
# 18:04:21 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:21 - cmdstanpy - INFO - Chain [1] done processing
# 18:04:21 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:21 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:04:21 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:21 - cmdstanpy - INFO - Chain [1] done processing
# 18:04:21 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:21 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:04:21 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:21 - cmdstanpy - INFO - Chain [1] done processing
# 18:04:21 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:21 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:04:21 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:21 - cmdstanpy - INFO - Chain [1] done processing
# 18:04:21 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:21 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:04:21 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:21 - cmdstanpy - INFO - Chain [1] done processing
# 18:04:21 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:21 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:04:21 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:21 - cmdstanpy - INFO - Chain [1] done processing
# 18:04:21 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:21 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:04:21 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:22 - cmdstanpy - INFO - Chain [1] done processing
# 18:04:22 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:22 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:04:22 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:22 - cmdstanpy - INFO - Chain [1] done processing
# 18:04:22 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:22 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:04:22 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:22 - cmdstanpy - INFO - Chain [1] done processing
# 18:04:22 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:22 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:04:22 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:22 - cmdstanpy - INFO - Chain [1] done processing
# 18:04:22 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:22 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:04:22 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:22 - cmdstanpy - INFO - Chain [1] done processing
# 18:04:22 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:22 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:04:22 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:22 - cmdstanpy - INFO - Chain [1] done processing
# 18:04:22 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:22 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:04:22 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:22 - cmdstanpy - INFO - Chain [1] done processing
# 18:04:22 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:22 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:04:22 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:22 - cmdstanpy - INFO - Chain [1] done processing
# 18:04:22 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:22 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:04:22 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:22 - cmdstanpy - INFO - Chain [1] done processing
# 18:04:22 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:22 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:04:22 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:22 - cmdstanpy - INFO - Chain [1] done processing
# 18:04:22 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:22 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:04:22 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:22 - cmdstanpy - INFO - Chain [1] done processing
# 18:04:22 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:22 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:04:22 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:23 - cmdstanpy - INFO - Chain [1] done processing
# 18:04:23 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:23 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:04:23 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:23 - cmdstanpy - INFO - Chain [1] done processing
# 18:04:23 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:23 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:04:23 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:23 - cmdstanpy - INFO - Chain [1] done processing
# 18:04:23 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:23 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:04:23 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:23 - cmdstanpy - INFO - Chain [1] done processing
# 18:04:23 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:23 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:04:23 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:23 - cmdstanpy - INFO - Chain [1] done processing
# 18:04:23 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:23 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:04:23 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:23 - cmdstanpy - INFO - Chain [1] done processing
# 18:04:23 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:23 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:04:23 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:23 - cmdstanpy - INFO - Chain [1] done processing
# 18:04:23 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:23 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:04:23 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:23 - cmdstanpy - INFO - Chain [1] done processing
# 18:04:23 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:23 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:04:23 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:23 - cmdstanpy - INFO - Chain [1] done processing
# 18:04:23 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:23 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:04:23 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:23 - cmdstanpy - INFO - Chain [1] done processing
# 18:04:24 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:24 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:04:24 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:24 - cmdstanpy - INFO - Chain [1] done processing
# 18:04:24 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:24 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:04:24 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:24 - cmdstanpy - INFO - Chain [1] done processing
# 18:04:24 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:24 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:04:24 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:24 - cmdstanpy - INFO - Chain [1] done processing
# 18:04:24 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:24 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:04:24 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:24 - cmdstanpy - INFO - Chain [1] done processing
# 18:04:24 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:24 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:04:24 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:24 - cmdstanpy - INFO - Chain [1] done processing
# 18:04:24 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:24 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:04:24 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:24 - cmdstanpy - INFO - Chain [1] done processing
# 18:04:24 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:24 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:04:24 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:24 - cmdstanpy - INFO - Chain [1] done processing
# 18:04:24 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:24 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:04:24 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:24 - cmdstanpy - INFO - Chain [1] done processing
# 18:04:25 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:25 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:04:25 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:25 - cmdstanpy - INFO - Chain [1] done processing
#     changepoint_prior_scale  seasonality_prior_scale           mse
# 0                     0.001                     0.01  84519.498480
# 1                     0.001                     0.10  77760.487940
# 2                     0.001                     1.00  80863.900967
# 3                     0.001                     1.50  80941.834667
# 4                     0.001                     2.00  80976.988298
# 5                     0.010                     0.01  85219.464996
# 6                     0.010                     0.10  46851.750694
# 7                     0.010                     1.00  46279.873521
# 8                     0.010                     1.50  48231.393708
# 9                     0.010                     2.00  46519.820535
# 10                    0.100                     0.01  22431.572322
# 11                    0.100                     0.10  20274.387074
# 12                    0.100                     1.00  22000.896759
# 13                    0.100                     1.50  23514.784355
# 14                    0.100                     2.00  20621.889769
# 15                    0.500                     0.01  21100.367812
# 16                    0.500                     0.10  21163.659582
# 17                    0.500                     1.00  21946.997685
# 18                    0.500                     1.50  24102.155216
# 19                    0.500                     2.00  21176.331061
# 20                    1.000                     0.01  19512.377438
# 21                    1.000                     0.10  20489.170238
# 22                    1.000                     1.00  19933.943660
# 23                    1.000                     1.50  19217.875381
# 24                    1.000                     2.00  20538.378007
# 25                    1.500                     0.01  18860.087776
# 26                    1.500                     0.10  19067.352488
# 27                    1.500                     1.00  19185.903699
# 28                    1.500                     1.50  19696.004095
# 29                    1.500                     2.00  18668.041542
# 30                    2.000                     0.01  17599.623698
# 31                    2.000                     0.10  16747.586072
# 32                    2.000                     1.00  17683.927397
# 33                    2.000                     1.50  17227.558225
# 34                    2.000                     2.00  17495.244633
# 35                    2.500                     0.01  15364.399435
# 36                    2.500                     0.10  15937.691000
# 37                    2.500                     1.00  15831.324003
# 38                    2.500                     1.50  16087.739621
# 39                    2.500                     2.00  15899.454126
# Best Parameters: changepoint_prior_scale        2.500000
# seasonality_prior_scale        0.010000
# mse                        15364.399435
# Name: 35, dtype: float64

# %%
from prophet import Prophet
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# Your best parameters
best_params = {
    'changepoint_prior_scale': 2.5,
    'seasonality_prior_scale': 0.01,
}

# Create and fit a Prophet model with the best parameters
model = Prophet(changepoint_prior_scale=best_params['changepoint_prior_scale'],
                seasonality_prior_scale=best_params['seasonality_prior_scale'])
model.fit(train)

# Make predictions on the training set
train_forecast = model.predict(train)

# Make predictions on the test set
test_forecast = model.predict(test)

# Calculate R^2 for the training set
train_r2 = r2_score(train['y'], train_forecast['yhat'])
print(f'Training Set R^2: {train_r2}')

# Calculate R^2 for the test set
test_r2 = r2_score(test['y'], test_forecast['yhat'])
print(f'Test Set R^2: {test_r2}')
# Out:
# 18:04:32 - cmdstanpy - INFO - Chain [1] start processing
# 18:04:32 - cmdstanpy - INFO - Chain [1] done processing
# Training Set R^2: 0.6768928590322998
# Test Set R^2: -0.8904848136868628

# %%
# Plot the training data and predictions
fig, ax = plt.subplots(ncols=2, figsize=(14, 6))

# Configure date formatting and rotate date labels for better visibility
date_formatter = mdates.DateFormatter('%Y-%m-%d')
test['ds'] = pd.to_datetime(test['ds'])

# Training plot
ax[0].plot(train['ds'], train['y'], label='Actual')
ax[0].plot(train['ds'], train_forecast['yhat'], label='Predicted')
ax[0].fill_between(train['ds'], train_forecast['yhat_lower'], train_forecast['yhat_upper'], alpha=0.2)
ax[0].set_title('Prophet Orange - Training Data and Predictions')
ax[0].xaxis.set_major_locator(mdates.AutoDateLocator())
ax[0].xaxis.set_major_formatter(date_formatter)
plt.setp(ax[0].get_xticklabels(), rotation=45, ha='right')

# Test plot
ax[1].plot(test['ds'], test['y'], label='Actual')
ax[1].plot(test['ds'], test_forecast['yhat'], label='Predicted')
ax[1].fill_between(test['ds'], test_forecast['yhat_lower'], test_forecast['yhat_upper'], alpha=0.2)
ax[1].set_title('Prophet Orange - Test Data and Predictions')
ax[1].xaxis.set_major_locator(mdates.AutoDateLocator())
ax[1].xaxis.set_major_formatter(date_formatter)
plt.setp(ax[1].get_xticklabels(), rotation=45, ha='right')


plt.tight_layout()
plt.show()

# %% [markdown]
# # San Diego

# %%
sandiego = california_data[california_data['county'] == 'San Diego'].loc[:, ['date', 'incremental_cases']]
sandiego['incremental_cases'] = sandiego['incremental_cases'].astype('int')
sandiego['date'] = pd.to_datetime(sandiego['date'], format="%Y-%m-%d")

def stationary_test(series):
    result = adfuller(series)
    return (result[0], result[1])

# San Diego is non-stationary
print("Stationary or not?:", stationary_test(sandiego.incremental_cases))
# Out:
# Stationary or not?: (0.6357611259888307, 0.9884647007943559)

# %%
sandiego.shape
# Out:
# (270, 2)

# %%
# use 85%-15% for train-test split
train = sandiego.iloc[:230, :]
test = sandiego.iloc[230:, :]

# %%
# use non-differenced cases for test actuals
testing = data[data['county'] == 'San Diego'].loc[:, ['date', 'incremental_cases']]
test = testing.iloc[230:, :]

# Plotting actual test data
sns.lineplot(x="date", y="incremental_cases",legend = 'full' , data=testing)
# Out:
# <Axes: xlabel='date', ylabel='incremental_cases'>

# %%
# Prepare the training data for Prophet
train = train.reset_index().rename(columns={'date': 'ds', 'incremental_cases': 'y'})
test = test.reset_index().rename(columns={'date': 'ds', 'incremental_cases': 'y'})

# Define the parameter grid to search
param_grid = {
    'changepoint_prior_scale': [0.001, 0.01, 0.1, 0.5, 1, 1.5, 2, 2.5],
    'seasonality_prior_scale': [0.01, 0.1, 1.0, 1.5, 2],
}

# Generate all combinations of parameters
all_params = [dict(zip(param_grid.keys(), v)) for v in itertools.product(*param_grid.values())]
mses = []  # Store the MSEs for each params here

# Use cross-validation to evaluate all parameters
for params in all_params:
    m = Prophet(**params)
    m.fit(train)  # Fit model with given params
    df_cv = cross_validation(m, initial='190 days', period='180 days', horizon='20 days')
    df_p = performance_metrics(df_cv, rolling_window=1)
    mses.append(df_p['mse'].values[0])  # Use MSE

# Find the best parameters
tuning_results = pd.DataFrame(all_params)
tuning_results['mse'] = mses
best_parameters = tuning_results.loc[tuning_results['mse'].idxmin()]

print(tuning_results)
print(f"Best Parameters: {best_parameters}")
# Out:
# 18:05:11 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:11 - cmdstanpy - INFO - Chain [1] done processing
# 18:05:11 - cmdstanpy - ERROR - Chain [1] error: error during processing Operation not permitted
# Optimization terminated abnormally. Falling back to Newton.
# 18:05:11 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:11 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:05:11 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:11 - cmdstanpy - INFO - Chain [1] done processing
# 18:05:11 - cmdstanpy - ERROR - Chain [1] error: error during processing Operation not permitted
# Optimization terminated abnormally. Falling back to Newton.
# 18:05:11 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:11 - cmdstanpy - INFO - Chain [1] done processing
# 18:05:11 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:11 - cmdstanpy - INFO - Chain [1] done processing
# 18:05:11 - cmdstanpy - ERROR - Chain [1] error: error during processing Operation not permitted
# Optimization terminated abnormally. Falling back to Newton.
# 18:05:11 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:12 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:05:12 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:12 - cmdstanpy - INFO - Chain [1] done processing
# 18:05:12 - cmdstanpy - ERROR - Chain [1] error: error during processing Operation not permitted
# Optimization terminated abnormally. Falling back to Newton.
# 18:05:12 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:12 - cmdstanpy - INFO - Chain [1] done processing
# 18:05:12 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:12 - cmdstanpy - INFO - Chain [1] done processing
# 18:05:12 - cmdstanpy - ERROR - Chain [1] error: error during processing Operation not permitted
# Optimization terminated abnormally. Falling back to Newton.
# 18:05:12 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:12 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:05:12 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:12 - cmdstanpy - INFO - Chain [1] done processing
# 18:05:12 - cmdstanpy - ERROR - Chain [1] error: error during processing Operation not permitted
# Optimization terminated abnormally. Falling back to Newton.
# 18:05:12 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:12 - cmdstanpy - INFO - Chain [1] done processing
# 18:05:12 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:12 - cmdstanpy - INFO - Chain [1] done processing
# 18:05:12 - cmdstanpy - ERROR - Chain [1] error: error during processing Operation not permitted
# Optimization terminated abnormally. Falling back to Newton.
# 18:05:12 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:12 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:05:12 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:12 - cmdstanpy - INFO - Chain [1] done processing
# 18:05:12 - cmdstanpy - ERROR - Chain [1] error: error during processing Operation not permitted
# Optimization terminated abnormally. Falling back to Newton.
# 18:05:12 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:13 - cmdstanpy - INFO - Chain [1] done processing
# 18:05:13 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:13 - cmdstanpy - INFO - Chain [1] done processing
# 18:05:13 - cmdstanpy - ERROR - Chain [1] error: error during processing Operation not permitted
# Optimization terminated abnormally. Falling back to Newton.
# 18:05:13 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:13 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:05:13 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:13 - cmdstanpy - INFO - Chain [1] done processing
# 18:05:13 - cmdstanpy - ERROR - Chain [1] error: error during processing Operation not permitted
# Optimization terminated abnormally. Falling back to Newton.
# 18:05:13 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:13 - cmdstanpy - INFO - Chain [1] done processing
# 18:05:13 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:13 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:05:13 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:13 - cmdstanpy - INFO - Chain [1] done processing
# 18:05:13 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:13 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:05:13 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:13 - cmdstanpy - INFO - Chain [1] done processing
# 18:05:13 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:13 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:05:13 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:13 - cmdstanpy - INFO - Chain [1] done processing
# 18:05:13 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:13 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:05:13 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:13 - cmdstanpy - INFO - Chain [1] done processing
# 18:05:13 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:13 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:05:13 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:13 - cmdstanpy - INFO - Chain [1] done processing
# 18:05:13 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:13 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:05:13 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:13 - cmdstanpy - INFO - Chain [1] done processing
# 18:05:13 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:13 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:05:13 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:13 - cmdstanpy - INFO - Chain [1] done processing
# 18:05:14 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:14 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:05:14 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:14 - cmdstanpy - INFO - Chain [1] done processing
# 18:05:14 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:14 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:05:14 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:14 - cmdstanpy - INFO - Chain [1] done processing
# 18:05:14 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:14 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:05:14 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:14 - cmdstanpy - INFO - Chain [1] done processing
# 18:05:14 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:14 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:05:14 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:14 - cmdstanpy - INFO - Chain [1] done processing
# 18:05:14 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:14 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:05:14 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:14 - cmdstanpy - INFO - Chain [1] done processing
# 18:05:14 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:14 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:05:14 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:14 - cmdstanpy - INFO - Chain [1] done processing
# 18:05:14 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:14 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:05:14 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:14 - cmdstanpy - INFO - Chain [1] done processing
# 18:05:14 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:14 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:05:14 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:14 - cmdstanpy - INFO - Chain [1] done processing
# 18:05:14 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:14 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:05:14 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:14 - cmdstanpy - INFO - Chain [1] done processing
# 18:05:14 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:14 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:05:14 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:14 - cmdstanpy - INFO - Chain [1] done processing
# 18:05:15 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:15 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:05:15 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:15 - cmdstanpy - INFO - Chain [1] done processing
# 18:05:15 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:15 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:05:15 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:15 - cmdstanpy - INFO - Chain [1] done processing
# 18:05:15 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:15 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:05:15 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:15 - cmdstanpy - INFO - Chain [1] done processing
# 18:05:15 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:15 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:05:15 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:15 - cmdstanpy - INFO - Chain [1] done processing
# 18:05:15 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:15 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:05:15 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:15 - cmdstanpy - INFO - Chain [1] done processing
# 18:05:15 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:15 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:05:15 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:15 - cmdstanpy - INFO - Chain [1] done processing
# 18:05:15 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:15 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:05:15 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:15 - cmdstanpy - INFO - Chain [1] done processing
# 18:05:15 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:15 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:05:15 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:15 - cmdstanpy - INFO - Chain [1] done processing
# 18:05:15 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:15 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:05:15 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:16 - cmdstanpy - INFO - Chain [1] done processing
# 18:05:16 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:16 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:05:16 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:16 - cmdstanpy - INFO - Chain [1] done processing
# 18:05:16 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:16 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:05:16 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:16 - cmdstanpy - INFO - Chain [1] done processing
# 18:05:16 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:16 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:05:16 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:16 - cmdstanpy - INFO - Chain [1] done processing
# 18:05:16 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:16 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:05:16 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:16 - cmdstanpy - INFO - Chain [1] done processing
# 18:05:16 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:16 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:05:16 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:16 - cmdstanpy - INFO - Chain [1] done processing
# 18:05:16 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:16 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:05:16 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:16 - cmdstanpy - INFO - Chain [1] done processing
# 18:05:16 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:16 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:05:16 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:16 - cmdstanpy - INFO - Chain [1] done processing
# 18:05:16 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:16 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:05:16 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:16 - cmdstanpy - INFO - Chain [1] done processing
# 18:05:16 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:17 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/1 [00:00<?, ?it/s]
# 18:05:17 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:17 - cmdstanpy - INFO - Chain [1] done processing
#     changepoint_prior_scale  seasonality_prior_scale           mse
# 0                     0.001                     0.01  22733.084636
# 1                     0.001                     0.10  22817.281273
# 2                     0.001                     1.00  23045.531925
# 3                     0.001                     1.50  23060.678644
# 4                     0.001                     2.00  23043.382648
# 5                     0.010                     0.01  15102.745916
# 6                     0.010                     0.10  14939.359851
# 7                     0.010                     1.00  14967.523902
# 8                     0.010                     1.50  14956.813817
# 9                     0.010                     2.00  14958.524477
# 10                    0.100                     0.01  10864.084612
# 11                    0.100                     0.10  11431.735237
# 12                    0.100                     1.00  12112.667910
# 13                    0.100                     1.50  10963.351159
# 14                    0.100                     2.00  11826.054886
# 15                    0.500                     0.01   6393.616383
# 16                    0.500                     0.10   6276.103088
# 17                    0.500                     1.00   6190.553368
# 18                    0.500                     1.50   6373.801415
# 19                    0.500                     2.00   6173.079010
# 20                    1.000                     0.01   6213.963595
# 21                    1.000                     0.10   6094.803406
# 22                    1.000                     1.00   6146.523647
# 23                    1.000                     1.50   5990.044920
# 24                    1.000                     2.00   6032.230933
# 25                    1.500                     0.01   6123.097382
# 26                    1.500                     0.10   5996.816757
# 27                    1.500                     1.00   5960.083233
# 28                    1.500                     1.50   5966.889062
# 29                    1.500                     2.00   5948.350045
# 30                    2.000                     0.01   6096.017214
# 31                    2.000                     0.10   5926.631315
# 32                    2.000                     1.00   5928.859230
# 33                    2.000                     1.50   5926.509280
# 34                    2.000                     2.00   5943.152506
# 35                    2.500                     0.01   6071.692684
# 36                    2.500                     0.10   5923.934579
# 37                    2.500                     1.00   5912.977403
# 38                    2.500                     1.50   5913.037376
# 39                    2.500                     2.00   5914.522575
# Best Parameters: changepoint_prior_scale       2.500000
# seasonality_prior_scale       1.000000
# mse                        5912.977403
# Name: 37, dtype: float64

# %%
from prophet import Prophet
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# Your best parameters
best_params = {
    'changepoint_prior_scale': 2.5,
    'seasonality_prior_scale': 1,
}

# Create and fit a Prophet model with the best parameters
model = Prophet(changepoint_prior_scale=best_params['changepoint_prior_scale'],
                seasonality_prior_scale=best_params['seasonality_prior_scale'])
model.fit(train)

# Make predictions on the training set
train_forecast = model.predict(train)

# Make predictions on the test set
test_forecast = model.predict(test)

# Calculate R^2 for the training set
train_r2 = r2_score(train['y'], train_forecast['yhat'])
print(f'Training Set R^2: {train_r2}')

# Calculate R^2 for the test set
test_r2 = r2_score(test['y'], test_forecast['yhat'])
print(f'Test Set R^2: {test_r2}')
# Out:
# 18:05:23 - cmdstanpy - INFO - Chain [1] start processing
# 18:05:23 - cmdstanpy - INFO - Chain [1] done processing
# Training Set R^2: 0.8281680414841398
# Test Set R^2: -0.7491792900090342

# %%
# Plot the training data and predictions
fig, ax = plt.subplots(ncols=2, figsize=(14, 6))

# Configure date formatting and rotate date labels for better visibility
date_formatter = mdates.DateFormatter('%Y-%m-%d')
test['ds'] = pd.to_datetime(test['ds'])


# Training plot
ax[0].plot(train['ds'], train['y'], label='Actual')
ax[0].plot(train['ds'], train_forecast['yhat'], label='Predicted')
ax[0].fill_between(train['ds'], train_forecast['yhat_lower'], train_forecast['yhat_upper'], alpha=0.2)
ax[0].set_title('Prophet San Diego - Training Data and Predictions')
ax[0].xaxis.set_major_locator(mdates.AutoDateLocator())
ax[0].xaxis.set_major_formatter(date_formatter)
plt.setp(ax[0].get_xticklabels(), rotation=45, ha='right')

# Test plot
ax[1].plot(test['ds'], test['y'], label='Actual')
ax[1].plot(test['ds'], test_forecast['yhat'], label='Predicted')
ax[1].fill_between(test['ds'], test_forecast['yhat_lower'], test_forecast['yhat_upper'], alpha=0.2)
ax[1].set_title('Prophet San Diego - Test Data and Predictions')
ax[1].xaxis.set_major_locator(mdates.AutoDateLocator())
ax[1].xaxis.set_major_formatter(date_formatter)
plt.setp(ax[1].get_xticklabels(), rotation=45, ha='right')

# Adjust layout
plt.tight_layout()

# Show the plot with the new date format
plt.show()
