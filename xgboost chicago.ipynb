# %%
import pandas as pd

import xgboost as xgb

# %%
df = pd.read_csv('variable_selected_county_dataset.csv', index_col=0)

# %%
df
# Out:
#             date   cases stay_at_home_announced stay_at_home_effective  \
# 190   2020-03-10      20                     no                     no
# 201   2020-03-11      28                     no                     no
# 213   2020-03-12      32                     no                     no
# 225   2020-03-13      40                     no                     no
# 237   2020-03-14      53                     no                     no
# ...          ...     ...                    ...                    ...
# 3380  2020-11-30  100650                    yes                    yes
# 3392  2020-12-01  102051                    yes                    yes
# 3404  2020-12-02  103781                    yes                    yes
# 3416  2020-12-03  105675                    yes                    yes
# 3428  2020-12-04  107178                    yes                    yes
#
#       total_population    area_sqmi  population_density_per_sqmi  \
# 190         10057155.0  4058.183382                  2478.240645
# 201         10057155.0  4058.183382                  2478.240645
# 213         10057155.0  4058.183382                  2478.240645
# 225         10057155.0  4058.183382                  2478.240645
# 237         10057155.0  4058.183382                  2478.240645
# ...                ...          ...                          ...
# 3380         1947529.0   863.649681                  2254.998805
# 3392         1947529.0   863.649681                  2254.998805
# 3404         1947529.0   863.649681                  2254.998805
# 3416         1947529.0   863.649681                  2254.998805
# 3428         1947529.0   863.649681                  2254.998805
#
#       percent_fair_or_poor_health  \
# 190                     16.418669
# 201                     16.418669
# 213                     16.418669
# 225                     16.418669
# 237                     16.418669
# ...                           ...
# 3380                    19.945542
# 3392                    19.945542
# 3404                    19.945542
# 3416                    19.945542
# 3428                    19.945542
#
#       average_number_of_physically_unhealthy_days  \
# 190                                      3.550138
# 201                                      3.550138
# 213                                      3.550138
# 225                                      3.550138
# 237                                      3.550138
# ...                                           ...
# 3380                                     3.633687
# 3392                                     3.633687
# 3404                                     3.633687
# 3416                                     3.633687
# 3428                                     3.633687
#
#       average_number_of_mentally_unhealthy_days  ...  thunder  tornado  \
# 190                                    3.616494  ...      0.0      0.0
# 201                                    3.616494  ...      0.0      0.0
# 213                                    3.616494  ...      0.0      0.0
# 225                                    3.616494  ...      0.0      0.0
# 237                                    3.616494  ...      0.0      0.0
# ...                                         ...  ...      ...      ...
# 3380                                   3.878487  ...      0.0      0.0
# 3392                                   3.878487  ...      0.0      0.0
# 3404                                   3.878487  ...      0.0      0.0
# 3416                                   3.878487  ...      0.0      0.0
# 3428                                   3.878487  ...      0.0      0.0
#
#       mean_temp_3d_avg  max_temp_3d_avg  min_temp_3d_avg  dewpoint_3d_avg  \
# 190          61.366667        67.400000        53.600000        47.000000
# 201          60.666667        66.800000        54.200000        51.566667
# 213          57.033333        62.600000        52.400000        50.833333
# 225          53.933333        58.400000        50.600000        50.800000
# 237          53.400000        55.400000        51.800000        48.866667
# ...                ...              ...              ...              ...
# 3380         42.966667        52.633333        33.333333        29.666667
# 3392         43.166667        54.300000        32.666667        26.733333
# 3404         43.133333        53.266667        34.366667        30.100000
# 3416         42.400000        47.633333        36.700000        33.633333
# 3428               NaN              NaN              NaN              NaN
#
#       date_stay_at_home_announced  date_stay_at_home_effective  \
# 190                    2020-03-19                   2020-03-19
# 201                    2020-03-19                   2020-03-19
# 213                    2020-03-19                   2020-03-19
# 225                    2020-03-19                   2020-03-19
# 237                    2020-03-19                   2020-03-19
# ...                           ...                          ...
# 3380                   2020-03-31                   2020-04-02
# 3392                   2020-03-31                   2020-04-02
# 3404                   2020-03-31                   2020-04-02
# 3416                   2020-03-31                   2020-04-02
# 3428                   2020-03-31                   2020-04-02
#
#                       entity  incremental_cases
# 190   California-Los Angeles                1.0
# 201   California-Los Angeles                8.0
# 213   California-Los Angeles                4.0
# 225   California-Los Angeles                8.0
# 237   California-Los Angeles               13.0
# ...                      ...                ...
# 3380           Texas-Tarrant             3356.0
# 3392           Texas-Tarrant             1401.0
# 3404           Texas-Tarrant             1730.0
# 3416           Texas-Tarrant             1894.0
# 3428           Texas-Tarrant             1503.0
#
# [3240 rows x 134 columns]

# %%
dfToUse = df.drop(labels=['cases'],axis=1)
dfToUse = dfToUse[dfToUse['entity'] == 'Illinois-Cook']

# %%
toDrop = dfToUse.columns[dfToUse.nunique() == 1].tolist()
toDrop.pop()
dfToUse.drop(labels=toDrop, axis=1, inplace=True)

# %%
train = dfToUse[dfToUse['date'] < '2020-10-26'].sort_values(by=['date']).reset_index().drop(labels=['index'],axis=1)
test = dfToUse[dfToUse['date'] >= '2020-10-26']
train.date = pd.to_datetime(train.date)
train['month'] = train.date.dt.month
train['day'] = train.date.dt.day

test.date = pd.to_datetime(test.date)
test['month'] = test.date.dt.month
test['day'] = test.date.dt.day
# Out:
# C:\Users\Albert Song\AppData\Local\Temp\ipykernel_5900\3474772313.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test.date = pd.to_datetime(test.date)
# C:\Users\Albert Song\AppData\Local\Temp\ipykernel_5900\3474772313.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['month'] = test.date.dt.month
# C:\Users\Albert Song\AppData\Local\Temp\ipykernel_5900\3474772313.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['day'] = test.date.dt.day

# %%
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error
import numpy as np

#train.reset_index(inplace=True)

n_splits = 3

tscv = TimeSeriesSplit(n_splits=n_splits)

# %%
yTrain = train['incremental_cases']
xTrain = train.drop(labels=['incremental_cases', 'date'],axis=1)

# %%
finalXTrain = pd.get_dummies(xTrain)

# %%
nEst = [2500, 5000, 7500]
lr = [0.001,0.1,0.5]
md = [4,6,8]
ss = [0.1,0.5,0.8]
rl = [0,1]
gam = [0,0.1,1]
best_score, best_cfg = float("inf"), None
for n in nEst:
    for l in lr:
        for m in md:
            for s in ss:
                for r in rl:
                    for g in gam:
                        eval = (n,l,m,s,r,g)
                        avg = 0
                        print(eval)
                        for train_index, val_index in tscv.split(finalXTrain):
                            train_data, val_data = finalXTrain.loc[train_index], finalXTrain.loc[val_index]
                            yFit = yTrain.loc[train_index]
                            yVal = yTrain.loc[val_index]
                            model = xgb.XGBRegressor(n_estimators=n, learning_rate=l, max_depth=m, subsample=s, reg_lambda=r, gamma=g)
                            model.fit(train_data, yFit)
                            forecast = model.predict(val_data)
                            mse = mean_squared_error(yVal, forecast)
                            avg += mse
                        if avg < best_score:
                            best_score, best_cfg = avg, eval
# Out:
# (2500, 0.001, 4, 0.1, 0, 0)
# (2500, 0.001, 4, 0.1, 0, 0.1)
# (2500, 0.001, 4, 0.1, 0, 1)
# (2500, 0.001, 4, 0.1, 1, 0)
# (2500, 0.001, 4, 0.1, 1, 0.1)
# (2500, 0.001, 4, 0.1, 1, 1)
# (2500, 0.001, 4, 0.5, 0, 0)
# (2500, 0.001, 4, 0.5, 0, 0.1)
# (2500, 0.001, 4, 0.5, 0, 1)
# (2500, 0.001, 4, 0.5, 1, 0)
# (2500, 0.001, 4, 0.5, 1, 0.1)
# (2500, 0.001, 4, 0.5, 1, 1)
# (2500, 0.001, 4, 0.8, 0, 0)
# (2500, 0.001, 4, 0.8, 0, 0.1)
# (2500, 0.001, 4, 0.8, 0, 1)
# (2500, 0.001, 4, 0.8, 1, 0)
# (2500, 0.001, 4, 0.8, 1, 0.1)
# (2500, 0.001, 4, 0.8, 1, 1)
# (2500, 0.001, 6, 0.1, 0, 0)
# (2500, 0.001, 6, 0.1, 0, 0.1)
# (2500, 0.001, 6, 0.1, 0, 1)
# (2500, 0.001, 6, 0.1, 1, 0)
# (2500, 0.001, 6, 0.1, 1, 0.1)
# (2500, 0.001, 6, 0.1, 1, 1)
# (2500, 0.001, 6, 0.5, 0, 0)
# (2500, 0.001, 6, 0.5, 0, 0.1)
# (2500, 0.001, 6, 0.5, 0, 1)
# (2500, 0.001, 6, 0.5, 1, 0)
# (2500, 0.001, 6, 0.5, 1, 0.1)
# (2500, 0.001, 6, 0.5, 1, 1)
# (2500, 0.001, 6, 0.8, 0, 0)
# (2500, 0.001, 6, 0.8, 0, 0.1)
# (2500, 0.001, 6, 0.8, 0, 1)
# (2500, 0.001, 6, 0.8, 1, 0)
# (2500, 0.001, 6, 0.8, 1, 0.1)
# (2500, 0.001, 6, 0.8, 1, 1)
# (2500, 0.001, 8, 0.1, 0, 0)
# (2500, 0.001, 8, 0.1, 0, 0.1)
# (2500, 0.001, 8, 0.1, 0, 1)
# (2500, 0.001, 8, 0.1, 1, 0)
# (2500, 0.001, 8, 0.1, 1, 0.1)
# (2500, 0.001, 8, 0.1, 1, 1)
# (2500, 0.001, 8, 0.5, 0, 0)
# (2500, 0.001, 8, 0.5, 0, 0.1)
# (2500, 0.001, 8, 0.5, 0, 1)
# (2500, 0.001, 8, 0.5, 1, 0)
# (2500, 0.001, 8, 0.5, 1, 0.1)
# (2500, 0.001, 8, 0.5, 1, 1)
# (2500, 0.001, 8, 0.8, 0, 0)
# (2500, 0.001, 8, 0.8, 0, 0.1)
# (2500, 0.001, 8, 0.8, 0, 1)
# (2500, 0.001, 8, 0.8, 1, 0)
# (2500, 0.001, 8, 0.8, 1, 0.1)
# (2500, 0.001, 8, 0.8, 1, 1)
# (2500, 0.1, 4, 0.1, 0, 0)
# (2500, 0.1, 4, 0.1, 0, 0.1)
# (2500, 0.1, 4, 0.1, 0, 1)
# (2500, 0.1, 4, 0.1, 1, 0)
# (2500, 0.1, 4, 0.1, 1, 0.1)
# (2500, 0.1, 4, 0.1, 1, 1)
# (2500, 0.1, 4, 0.5, 0, 0)
# (2500, 0.1, 4, 0.5, 0, 0.1)
# (2500, 0.1, 4, 0.5, 0, 1)
# (2500, 0.1, 4, 0.5, 1, 0)
# (2500, 0.1, 4, 0.5, 1, 0.1)
# (2500, 0.1, 4, 0.5, 1, 1)
# (2500, 0.1, 4, 0.8, 0, 0)
# (2500, 0.1, 4, 0.8, 0, 0.1)
# (2500, 0.1, 4, 0.8, 0, 1)
# (2500, 0.1, 4, 0.8, 1, 0)
# (2500, 0.1, 4, 0.8, 1, 0.1)
# (2500, 0.1, 4, 0.8, 1, 1)
# (2500, 0.1, 6, 0.1, 0, 0)
# (2500, 0.1, 6, 0.1, 0, 0.1)
# (2500, 0.1, 6, 0.1, 0, 1)
# (2500, 0.1, 6, 0.1, 1, 0)
# (2500, 0.1, 6, 0.1, 1, 0.1)
# (2500, 0.1, 6, 0.1, 1, 1)
# (2500, 0.1, 6, 0.5, 0, 0)
# (2500, 0.1, 6, 0.5, 0, 0.1)
# (2500, 0.1, 6, 0.5, 0, 1)
# (2500, 0.1, 6, 0.5, 1, 0)
# (2500, 0.1, 6, 0.5, 1, 0.1)
# (2500, 0.1, 6, 0.5, 1, 1)
# (2500, 0.1, 6, 0.8, 0, 0)
# (2500, 0.1, 6, 0.8, 0, 0.1)
# (2500, 0.1, 6, 0.8, 0, 1)
# (2500, 0.1, 6, 0.8, 1, 0)
# (2500, 0.1, 6, 0.8, 1, 0.1)
# (2500, 0.1, 6, 0.8, 1, 1)
# (2500, 0.1, 8, 0.1, 0, 0)
# (2500, 0.1, 8, 0.1, 0, 0.1)
# (2500, 0.1, 8, 0.1, 0, 1)
# (2500, 0.1, 8, 0.1, 1, 0)
# (2500, 0.1, 8, 0.1, 1, 0.1)
# (2500, 0.1, 8, 0.1, 1, 1)
# (2500, 0.1, 8, 0.5, 0, 0)
# (2500, 0.1, 8, 0.5, 0, 0.1)
# (2500, 0.1, 8, 0.5, 0, 1)
# (2500, 0.1, 8, 0.5, 1, 0)
# (2500, 0.1, 8, 0.5, 1, 0.1)
# (2500, 0.1, 8, 0.5, 1, 1)
# (2500, 0.1, 8, 0.8, 0, 0)
# (2500, 0.1, 8, 0.8, 0, 0.1)
# (2500, 0.1, 8, 0.8, 0, 1)
# (2500, 0.1, 8, 0.8, 1, 0)
# (2500, 0.1, 8, 0.8, 1, 0.1)
# (2500, 0.1, 8, 0.8, 1, 1)
# (2500, 0.5, 4, 0.1, 0, 0)
# (2500, 0.5, 4, 0.1, 0, 0.1)
# (2500, 0.5, 4, 0.1, 0, 1)
# (2500, 0.5, 4, 0.1, 1, 0)
# (2500, 0.5, 4, 0.1, 1, 0.1)
# (2500, 0.5, 4, 0.1, 1, 1)
# (2500, 0.5, 4, 0.5, 0, 0)
# (2500, 0.5, 4, 0.5, 0, 0.1)
# (2500, 0.5, 4, 0.5, 0, 1)
# (2500, 0.5, 4, 0.5, 1, 0)
# (2500, 0.5, 4, 0.5, 1, 0.1)
# (2500, 0.5, 4, 0.5, 1, 1)
# (2500, 0.5, 4, 0.8, 0, 0)
# (2500, 0.5, 4, 0.8, 0, 0.1)
# (2500, 0.5, 4, 0.8, 0, 1)
# (2500, 0.5, 4, 0.8, 1, 0)
# (2500, 0.5, 4, 0.8, 1, 0.1)
# (2500, 0.5, 4, 0.8, 1, 1)
# (2500, 0.5, 6, 0.1, 0, 0)
# (2500, 0.5, 6, 0.1, 0, 0.1)
# (2500, 0.5, 6, 0.1, 0, 1)
# (2500, 0.5, 6, 0.1, 1, 0)
# (2500, 0.5, 6, 0.1, 1, 0.1)
# (2500, 0.5, 6, 0.1, 1, 1)
# (2500, 0.5, 6, 0.5, 0, 0)
# (2500, 0.5, 6, 0.5, 0, 0.1)
# (2500, 0.5, 6, 0.5, 0, 1)
# (2500, 0.5, 6, 0.5, 1, 0)
# (2500, 0.5, 6, 0.5, 1, 0.1)
# (2500, 0.5, 6, 0.5, 1, 1)
# (2500, 0.5, 6, 0.8, 0, 0)
# (2500, 0.5, 6, 0.8, 0, 0.1)
# (2500, 0.5, 6, 0.8, 0, 1)
# (2500, 0.5, 6, 0.8, 1, 0)
# (2500, 0.5, 6, 0.8, 1, 0.1)
# (2500, 0.5, 6, 0.8, 1, 1)
# (2500, 0.5, 8, 0.1, 0, 0)
# (2500, 0.5, 8, 0.1, 0, 0.1)
# (2500, 0.5, 8, 0.1, 0, 1)
# (2500, 0.5, 8, 0.1, 1, 0)
# (2500, 0.5, 8, 0.1, 1, 0.1)
# (2500, 0.5, 8, 0.1, 1, 1)
# (2500, 0.5, 8, 0.5, 0, 0)
# (2500, 0.5, 8, 0.5, 0, 0.1)
# (2500, 0.5, 8, 0.5, 0, 1)
# (2500, 0.5, 8, 0.5, 1, 0)
# (2500, 0.5, 8, 0.5, 1, 0.1)
# (2500, 0.5, 8, 0.5, 1, 1)
# (2500, 0.5, 8, 0.8, 0, 0)
# (2500, 0.5, 8, 0.8, 0, 0.1)
# (2500, 0.5, 8, 0.8, 0, 1)
# (2500, 0.5, 8, 0.8, 1, 0)
# (2500, 0.5, 8, 0.8, 1, 0.1)
# (2500, 0.5, 8, 0.8, 1, 1)
# (5000, 0.001, 4, 0.1, 0, 0)
# (5000, 0.001, 4, 0.1, 0, 0.1)
# (5000, 0.001, 4, 0.1, 0, 1)
# (5000, 0.001, 4, 0.1, 1, 0)
# (5000, 0.001, 4, 0.1, 1, 0.1)
# (5000, 0.001, 4, 0.1, 1, 1)
# (5000, 0.001, 4, 0.5, 0, 0)
# (5000, 0.001, 4, 0.5, 0, 0.1)
# (5000, 0.001, 4, 0.5, 0, 1)
# (5000, 0.001, 4, 0.5, 1, 0)
# (5000, 0.001, 4, 0.5, 1, 0.1)
# (5000, 0.001, 4, 0.5, 1, 1)
# (5000, 0.001, 4, 0.8, 0, 0)
# (5000, 0.001, 4, 0.8, 0, 0.1)
# (5000, 0.001, 4, 0.8, 0, 1)
# (5000, 0.001, 4, 0.8, 1, 0)
# (5000, 0.001, 4, 0.8, 1, 0.1)
# (5000, 0.001, 4, 0.8, 1, 1)
# (5000, 0.001, 6, 0.1, 0, 0)
# (5000, 0.001, 6, 0.1, 0, 0.1)
# (5000, 0.001, 6, 0.1, 0, 1)
# (5000, 0.001, 6, 0.1, 1, 0)
# (5000, 0.001, 6, 0.1, 1, 0.1)
# (5000, 0.001, 6, 0.1, 1, 1)
# (5000, 0.001, 6, 0.5, 0, 0)
# (5000, 0.001, 6, 0.5, 0, 0.1)
# (5000, 0.001, 6, 0.5, 0, 1)
# (5000, 0.001, 6, 0.5, 1, 0)
# (5000, 0.001, 6, 0.5, 1, 0.1)
# (5000, 0.001, 6, 0.5, 1, 1)
# (5000, 0.001, 6, 0.8, 0, 0)
# (5000, 0.001, 6, 0.8, 0, 0.1)
# (5000, 0.001, 6, 0.8, 0, 1)
# (5000, 0.001, 6, 0.8, 1, 0)
# (5000, 0.001, 6, 0.8, 1, 0.1)
# (5000, 0.001, 6, 0.8, 1, 1)
# (5000, 0.001, 8, 0.1, 0, 0)
# (5000, 0.001, 8, 0.1, 0, 0.1)
# (5000, 0.001, 8, 0.1, 0, 1)
# (5000, 0.001, 8, 0.1, 1, 0)
# (5000, 0.001, 8, 0.1, 1, 0.1)
# (5000, 0.001, 8, 0.1, 1, 1)
# (5000, 0.001, 8, 0.5, 0, 0)
# (5000, 0.001, 8, 0.5, 0, 0.1)
# (5000, 0.001, 8, 0.5, 0, 1)
# (5000, 0.001, 8, 0.5, 1, 0)
# (5000, 0.001, 8, 0.5, 1, 0.1)
# (5000, 0.001, 8, 0.5, 1, 1)
# (5000, 0.001, 8, 0.8, 0, 0)
# (5000, 0.001, 8, 0.8, 0, 0.1)
# (5000, 0.001, 8, 0.8, 0, 1)
# (5000, 0.001, 8, 0.8, 1, 0)
# (5000, 0.001, 8, 0.8, 1, 0.1)
# (5000, 0.001, 8, 0.8, 1, 1)
# (5000, 0.1, 4, 0.1, 0, 0)
# (5000, 0.1, 4, 0.1, 0, 0.1)
# (5000, 0.1, 4, 0.1, 0, 1)
# (5000, 0.1, 4, 0.1, 1, 0)
# (5000, 0.1, 4, 0.1, 1, 0.1)
# (5000, 0.1, 4, 0.1, 1, 1)
# (5000, 0.1, 4, 0.5, 0, 0)
# (5000, 0.1, 4, 0.5, 0, 0.1)
# (5000, 0.1, 4, 0.5, 0, 1)
# (5000, 0.1, 4, 0.5, 1, 0)
# (5000, 0.1, 4, 0.5, 1, 0.1)
# (5000, 0.1, 4, 0.5, 1, 1)
# (5000, 0.1, 4, 0.8, 0, 0)
# (5000, 0.1, 4, 0.8, 0, 0.1)
# (5000, 0.1, 4, 0.8, 0, 1)
# (5000, 0.1, 4, 0.8, 1, 0)
# (5000, 0.1, 4, 0.8, 1, 0.1)
# (5000, 0.1, 4, 0.8, 1, 1)
# (5000, 0.1, 6, 0.1, 0, 0)
# (5000, 0.1, 6, 0.1, 0, 0.1)
# (5000, 0.1, 6, 0.1, 0, 1)
# (5000, 0.1, 6, 0.1, 1, 0)
# (5000, 0.1, 6, 0.1, 1, 0.1)
# (5000, 0.1, 6, 0.1, 1, 1)
# (5000, 0.1, 6, 0.5, 0, 0)
# (5000, 0.1, 6, 0.5, 0, 0.1)
# (5000, 0.1, 6, 0.5, 0, 1)
# (5000, 0.1, 6, 0.5, 1, 0)
# (5000, 0.1, 6, 0.5, 1, 0.1)
# (5000, 0.1, 6, 0.5, 1, 1)
# (5000, 0.1, 6, 0.8, 0, 0)
# (5000, 0.1, 6, 0.8, 0, 0.1)
# (5000, 0.1, 6, 0.8, 0, 1)
# (5000, 0.1, 6, 0.8, 1, 0)
# (5000, 0.1, 6, 0.8, 1, 0.1)
# (5000, 0.1, 6, 0.8, 1, 1)
# (5000, 0.1, 8, 0.1, 0, 0)
# (5000, 0.1, 8, 0.1, 0, 0.1)
# (5000, 0.1, 8, 0.1, 0, 1)
# (5000, 0.1, 8, 0.1, 1, 0)
# (5000, 0.1, 8, 0.1, 1, 0.1)
# (5000, 0.1, 8, 0.1, 1, 1)
# (5000, 0.1, 8, 0.5, 0, 0)
# (5000, 0.1, 8, 0.5, 0, 0.1)
# (5000, 0.1, 8, 0.5, 0, 1)
# (5000, 0.1, 8, 0.5, 1, 0)
# (5000, 0.1, 8, 0.5, 1, 0.1)
# (5000, 0.1, 8, 0.5, 1, 1)
# (5000, 0.1, 8, 0.8, 0, 0)
# (5000, 0.1, 8, 0.8, 0, 0.1)
# (5000, 0.1, 8, 0.8, 0, 1)
# (5000, 0.1, 8, 0.8, 1, 0)
# (5000, 0.1, 8, 0.8, 1, 0.1)
# (5000, 0.1, 8, 0.8, 1, 1)
# (5000, 0.5, 4, 0.1, 0, 0)
# (5000, 0.5, 4, 0.1, 0, 0.1)
# (5000, 0.5, 4, 0.1, 0, 1)
# (5000, 0.5, 4, 0.1, 1, 0)
# (5000, 0.5, 4, 0.1, 1, 0.1)
# (5000, 0.5, 4, 0.1, 1, 1)
# (5000, 0.5, 4, 0.5, 0, 0)
# (5000, 0.5, 4, 0.5, 0, 0.1)
# (5000, 0.5, 4, 0.5, 0, 1)
# (5000, 0.5, 4, 0.5, 1, 0)
# (5000, 0.5, 4, 0.5, 1, 0.1)
# (5000, 0.5, 4, 0.5, 1, 1)
# (5000, 0.5, 4, 0.8, 0, 0)
# (5000, 0.5, 4, 0.8, 0, 0.1)
# (5000, 0.5, 4, 0.8, 0, 1)
# (5000, 0.5, 4, 0.8, 1, 0)
# (5000, 0.5, 4, 0.8, 1, 0.1)
# (5000, 0.5, 4, 0.8, 1, 1)
# (5000, 0.5, 6, 0.1, 0, 0)
# (5000, 0.5, 6, 0.1, 0, 0.1)
# (5000, 0.5, 6, 0.1, 0, 1)
# (5000, 0.5, 6, 0.1, 1, 0)
# (5000, 0.5, 6, 0.1, 1, 0.1)
# (5000, 0.5, 6, 0.1, 1, 1)
# (5000, 0.5, 6, 0.5, 0, 0)
# (5000, 0.5, 6, 0.5, 0, 0.1)
# (5000, 0.5, 6, 0.5, 0, 1)
# (5000, 0.5, 6, 0.5, 1, 0)
# (5000, 0.5, 6, 0.5, 1, 0.1)
# (5000, 0.5, 6, 0.5, 1, 1)
# (5000, 0.5, 6, 0.8, 0, 0)
# (5000, 0.5, 6, 0.8, 0, 0.1)
# (5000, 0.5, 6, 0.8, 0, 1)
# (5000, 0.5, 6, 0.8, 1, 0)
# (5000, 0.5, 6, 0.8, 1, 0.1)
# (5000, 0.5, 6, 0.8, 1, 1)
# (5000, 0.5, 8, 0.1, 0, 0)
# (5000, 0.5, 8, 0.1, 0, 0.1)
# (5000, 0.5, 8, 0.1, 0, 1)
# (5000, 0.5, 8, 0.1, 1, 0)
# (5000, 0.5, 8, 0.1, 1, 0.1)
# (5000, 0.5, 8, 0.1, 1, 1)
# (5000, 0.5, 8, 0.5, 0, 0)
# (5000, 0.5, 8, 0.5, 0, 0.1)
# (5000, 0.5, 8, 0.5, 0, 1)
# (5000, 0.5, 8, 0.5, 1, 0)
# (5000, 0.5, 8, 0.5, 1, 0.1)
# (5000, 0.5, 8, 0.5, 1, 1)
# (5000, 0.5, 8, 0.8, 0, 0)
# (5000, 0.5, 8, 0.8, 0, 0.1)
# (5000, 0.5, 8, 0.8, 0, 1)
# (5000, 0.5, 8, 0.8, 1, 0)
# (5000, 0.5, 8, 0.8, 1, 0.1)
# (5000, 0.5, 8, 0.8, 1, 1)
# (7500, 0.001, 4, 0.1, 0, 0)
# (7500, 0.001, 4, 0.1, 0, 0.1)
# (7500, 0.001, 4, 0.1, 0, 1)
# (7500, 0.001, 4, 0.1, 1, 0)
# (7500, 0.001, 4, 0.1, 1, 0.1)
# (7500, 0.001, 4, 0.1, 1, 1)
# (7500, 0.001, 4, 0.5, 0, 0)
# (7500, 0.001, 4, 0.5, 0, 0.1)
# (7500, 0.001, 4, 0.5, 0, 1)
# (7500, 0.001, 4, 0.5, 1, 0)
# (7500, 0.001, 4, 0.5, 1, 0.1)
# (7500, 0.001, 4, 0.5, 1, 1)
# (7500, 0.001, 4, 0.8, 0, 0)
# (7500, 0.001, 4, 0.8, 0, 0.1)
# (7500, 0.001, 4, 0.8, 0, 1)
# (7500, 0.001, 4, 0.8, 1, 0)
# (7500, 0.001, 4, 0.8, 1, 0.1)
# (7500, 0.001, 4, 0.8, 1, 1)
# (7500, 0.001, 6, 0.1, 0, 0)
# (7500, 0.001, 6, 0.1, 0, 0.1)
# (7500, 0.001, 6, 0.1, 0, 1)
# (7500, 0.001, 6, 0.1, 1, 0)
# (7500, 0.001, 6, 0.1, 1, 0.1)
# (7500, 0.001, 6, 0.1, 1, 1)
# (7500, 0.001, 6, 0.5, 0, 0)
# (7500, 0.001, 6, 0.5, 0, 0.1)
# (7500, 0.001, 6, 0.5, 0, 1)
# (7500, 0.001, 6, 0.5, 1, 0)
# (7500, 0.001, 6, 0.5, 1, 0.1)
# (7500, 0.001, 6, 0.5, 1, 1)
# (7500, 0.001, 6, 0.8, 0, 0)
# (7500, 0.001, 6, 0.8, 0, 0.1)
# (7500, 0.001, 6, 0.8, 0, 1)
# (7500, 0.001, 6, 0.8, 1, 0)
# (7500, 0.001, 6, 0.8, 1, 0.1)
# (7500, 0.001, 6, 0.8, 1, 1)
# (7500, 0.001, 8, 0.1, 0, 0)
# (7500, 0.001, 8, 0.1, 0, 0.1)
# (7500, 0.001, 8, 0.1, 0, 1)
# (7500, 0.001, 8, 0.1, 1, 0)
# (7500, 0.001, 8, 0.1, 1, 0.1)
# (7500, 0.001, 8, 0.1, 1, 1)
# (7500, 0.001, 8, 0.5, 0, 0)
# (7500, 0.001, 8, 0.5, 0, 0.1)
# (7500, 0.001, 8, 0.5, 0, 1)
# (7500, 0.001, 8, 0.5, 1, 0)
# (7500, 0.001, 8, 0.5, 1, 0.1)
# (7500, 0.001, 8, 0.5, 1, 1)
# (7500, 0.001, 8, 0.8, 0, 0)
# (7500, 0.001, 8, 0.8, 0, 0.1)
# (7500, 0.001, 8, 0.8, 0, 1)
# (7500, 0.001, 8, 0.8, 1, 0)
# (7500, 0.001, 8, 0.8, 1, 0.1)
# (7500, 0.001, 8, 0.8, 1, 1)
# (7500, 0.1, 4, 0.1, 0, 0)
# (7500, 0.1, 4, 0.1, 0, 0.1)
# (7500, 0.1, 4, 0.1, 0, 1)
# (7500, 0.1, 4, 0.1, 1, 0)
# (7500, 0.1, 4, 0.1, 1, 0.1)
# (7500, 0.1, 4, 0.1, 1, 1)
# (7500, 0.1, 4, 0.5, 0, 0)
# (7500, 0.1, 4, 0.5, 0, 0.1)
# (7500, 0.1, 4, 0.5, 0, 1)
# (7500, 0.1, 4, 0.5, 1, 0)
# (7500, 0.1, 4, 0.5, 1, 0.1)
# (7500, 0.1, 4, 0.5, 1, 1)
# (7500, 0.1, 4, 0.8, 0, 0)
# (7500, 0.1, 4, 0.8, 0, 0.1)
# (7500, 0.1, 4, 0.8, 0, 1)
# (7500, 0.1, 4, 0.8, 1, 0)
# (7500, 0.1, 4, 0.8, 1, 0.1)
# (7500, 0.1, 4, 0.8, 1, 1)
# (7500, 0.1, 6, 0.1, 0, 0)
# (7500, 0.1, 6, 0.1, 0, 0.1)
# (7500, 0.1, 6, 0.1, 0, 1)
# (7500, 0.1, 6, 0.1, 1, 0)
# (7500, 0.1, 6, 0.1, 1, 0.1)
# (7500, 0.1, 6, 0.1, 1, 1)
# (7500, 0.1, 6, 0.5, 0, 0)
# (7500, 0.1, 6, 0.5, 0, 0.1)
# (7500, 0.1, 6, 0.5, 0, 1)
# (7500, 0.1, 6, 0.5, 1, 0)
# (7500, 0.1, 6, 0.5, 1, 0.1)
# (7500, 0.1, 6, 0.5, 1, 1)
# (7500, 0.1, 6, 0.8, 0, 0)
# (7500, 0.1, 6, 0.8, 0, 0.1)
# (7500, 0.1, 6, 0.8, 0, 1)
# (7500, 0.1, 6, 0.8, 1, 0)
# (7500, 0.1, 6, 0.8, 1, 0.1)
# (7500, 0.1, 6, 0.8, 1, 1)
# (7500, 0.1, 8, 0.1, 0, 0)
# (7500, 0.1, 8, 0.1, 0, 0.1)
# (7500, 0.1, 8, 0.1, 0, 1)
# (7500, 0.1, 8, 0.1, 1, 0)
# (7500, 0.1, 8, 0.1, 1, 0.1)
# (7500, 0.1, 8, 0.1, 1, 1)
# (7500, 0.1, 8, 0.5, 0, 0)
# (7500, 0.1, 8, 0.5, 0, 0.1)
# (7500, 0.1, 8, 0.5, 0, 1)
# (7500, 0.1, 8, 0.5, 1, 0)
# (7500, 0.1, 8, 0.5, 1, 0.1)
# (7500, 0.1, 8, 0.5, 1, 1)
# (7500, 0.1, 8, 0.8, 0, 0)
# (7500, 0.1, 8, 0.8, 0, 0.1)
# (7500, 0.1, 8, 0.8, 0, 1)
# (7500, 0.1, 8, 0.8, 1, 0)
# (7500, 0.1, 8, 0.8, 1, 0.1)
# (7500, 0.1, 8, 0.8, 1, 1)
# (7500, 0.5, 4, 0.1, 0, 0)
# (7500, 0.5, 4, 0.1, 0, 0.1)
# (7500, 0.5, 4, 0.1, 0, 1)
# (7500, 0.5, 4, 0.1, 1, 0)
# (7500, 0.5, 4, 0.1, 1, 0.1)
# (7500, 0.5, 4, 0.1, 1, 1)
# (7500, 0.5, 4, 0.5, 0, 0)
# (7500, 0.5, 4, 0.5, 0, 0.1)
# (7500, 0.5, 4, 0.5, 0, 1)
# (7500, 0.5, 4, 0.5, 1, 0)
# (7500, 0.5, 4, 0.5, 1, 0.1)
# (7500, 0.5, 4, 0.5, 1, 1)
# (7500, 0.5, 4, 0.8, 0, 0)
# (7500, 0.5, 4, 0.8, 0, 0.1)
# (7500, 0.5, 4, 0.8, 0, 1)
# (7500, 0.5, 4, 0.8, 1, 0)
# (7500, 0.5, 4, 0.8, 1, 0.1)
# (7500, 0.5, 4, 0.8, 1, 1)
# (7500, 0.5, 6, 0.1, 0, 0)
# (7500, 0.5, 6, 0.1, 0, 0.1)
# (7500, 0.5, 6, 0.1, 0, 1)
# (7500, 0.5, 6, 0.1, 1, 0)
# (7500, 0.5, 6, 0.1, 1, 0.1)
# (7500, 0.5, 6, 0.1, 1, 1)
# (7500, 0.5, 6, 0.5, 0, 0)
# (7500, 0.5, 6, 0.5, 0, 0.1)
# (7500, 0.5, 6, 0.5, 0, 1)
# (7500, 0.5, 6, 0.5, 1, 0)
# (7500, 0.5, 6, 0.5, 1, 0.1)
# (7500, 0.5, 6, 0.5, 1, 1)
# (7500, 0.5, 6, 0.8, 0, 0)
# (7500, 0.5, 6, 0.8, 0, 0.1)
# (7500, 0.5, 6, 0.8, 0, 1)
# (7500, 0.5, 6, 0.8, 1, 0)
# (7500, 0.5, 6, 0.8, 1, 0.1)
# (7500, 0.5, 6, 0.8, 1, 1)
# (7500, 0.5, 8, 0.1, 0, 0)
# (7500, 0.5, 8, 0.1, 0, 0.1)
# (7500, 0.5, 8, 0.1, 0, 1)
# (7500, 0.5, 8, 0.1, 1, 0)
# (7500, 0.5, 8, 0.1, 1, 0.1)
# (7500, 0.5, 8, 0.1, 1, 1)
# (7500, 0.5, 8, 0.5, 0, 0)
# (7500, 0.5, 8, 0.5, 0, 0.1)
# (7500, 0.5, 8, 0.5, 0, 1)
# (7500, 0.5, 8, 0.5, 1, 0)
# (7500, 0.5, 8, 0.5, 1, 0.1)
# (7500, 0.5, 8, 0.5, 1, 1)
# (7500, 0.5, 8, 0.8, 0, 0)
# (7500, 0.5, 8, 0.8, 0, 0.1)
# (7500, 0.5, 8, 0.8, 0, 1)
# (7500, 0.5, 8, 0.8, 1, 0)
# (7500, 0.5, 8, 0.8, 1, 0.1)
# (7500, 0.5, 8, 0.8, 1, 1)

# %%
print(best_score, best_cfg)
# Out:
# 705893.565324325 (2500, 0.001, 4, 0.1, 1, 0)

# %%
nEst = [2500]
lr = [0.001]
md = [2,3,4]
ss = [0.1,0.5,0.3]
rl = [0.5,1]
gam = [0.01,0,0.001]
best_score, best_cfg = float("inf"), None
for n in nEst:
    for l in lr:
        for m in md:
            for s in ss:
                for r in rl:
                    for g in gam:
                        eval = (n,l,m,s,r,g)
                        avg = 0
                        print(eval)
                        for train_index, val_index in tscv.split(finalXTrain):
                            train_data, val_data = finalXTrain.loc[train_index], finalXTrain.loc[val_index]
                            yFit = yTrain.loc[train_index]
                            yVal = yTrain.loc[val_index]
                            model = xgb.XGBRegressor(n_estimators=n, learning_rate=l, max_depth=m, subsample=s, reg_lambda=r, gamma=g)
                            model.fit(train_data, yFit)
                            forecast = model.predict(val_data)
                            mse = mean_squared_error(yVal, forecast)
                            avg += mse
                        if avg < best_score:
                            best_score, best_cfg = avg, eval
# Out:
# (2500, 0.001, 2, 0.1, 0.5, 0.01)
# (2500, 0.001, 2, 0.1, 0.5, 0)
# (2500, 0.001, 2, 0.1, 0.5, 0.001)
# (2500, 0.001, 2, 0.1, 1, 0.01)
# (2500, 0.001, 2, 0.1, 1, 0)
# (2500, 0.001, 2, 0.1, 1, 0.001)
# (2500, 0.001, 2, 0.5, 0.5, 0.01)
# (2500, 0.001, 2, 0.5, 0.5, 0)
# (2500, 0.001, 2, 0.5, 0.5, 0.001)
# (2500, 0.001, 2, 0.5, 1, 0.01)
# (2500, 0.001, 2, 0.5, 1, 0)
# (2500, 0.001, 2, 0.5, 1, 0.001)
# (2500, 0.001, 2, 0.3, 0.5, 0.01)
# (2500, 0.001, 2, 0.3, 0.5, 0)
# (2500, 0.001, 2, 0.3, 0.5, 0.001)
# (2500, 0.001, 2, 0.3, 1, 0.01)
# (2500, 0.001, 2, 0.3, 1, 0)
# (2500, 0.001, 2, 0.3, 1, 0.001)
# (2500, 0.001, 3, 0.1, 0.5, 0.01)
# (2500, 0.001, 3, 0.1, 0.5, 0)
# (2500, 0.001, 3, 0.1, 0.5, 0.001)
# (2500, 0.001, 3, 0.1, 1, 0.01)
# (2500, 0.001, 3, 0.1, 1, 0)
# (2500, 0.001, 3, 0.1, 1, 0.001)
# (2500, 0.001, 3, 0.5, 0.5, 0.01)
# (2500, 0.001, 3, 0.5, 0.5, 0)
# (2500, 0.001, 3, 0.5, 0.5, 0.001)
# (2500, 0.001, 3, 0.5, 1, 0.01)
# (2500, 0.001, 3, 0.5, 1, 0)
# (2500, 0.001, 3, 0.5, 1, 0.001)
# (2500, 0.001, 3, 0.3, 0.5, 0.01)
# (2500, 0.001, 3, 0.3, 0.5, 0)
# (2500, 0.001, 3, 0.3, 0.5, 0.001)
# (2500, 0.001, 3, 0.3, 1, 0.01)
# (2500, 0.001, 3, 0.3, 1, 0)
# (2500, 0.001, 3, 0.3, 1, 0.001)
# (2500, 0.001, 4, 0.1, 0.5, 0.01)
# (2500, 0.001, 4, 0.1, 0.5, 0)
# (2500, 0.001, 4, 0.1, 0.5, 0.001)
# (2500, 0.001, 4, 0.1, 1, 0.01)
# (2500, 0.001, 4, 0.1, 1, 0)
# (2500, 0.001, 4, 0.1, 1, 0.001)
# (2500, 0.001, 4, 0.5, 0.5, 0.01)
# (2500, 0.001, 4, 0.5, 0.5, 0)
# (2500, 0.001, 4, 0.5, 0.5, 0.001)
# (2500, 0.001, 4, 0.5, 1, 0.01)
# (2500, 0.001, 4, 0.5, 1, 0)
# (2500, 0.001, 4, 0.5, 1, 0.001)
# (2500, 0.001, 4, 0.3, 0.5, 0.01)
# (2500, 0.001, 4, 0.3, 0.5, 0)
# (2500, 0.001, 4, 0.3, 0.5, 0.001)
# (2500, 0.001, 4, 0.3, 1, 0.01)
# (2500, 0.001, 4, 0.3, 1, 0)
# (2500, 0.001, 4, 0.3, 1, 0.001)

# %%
print(best_score, best_cfg)
# Out:
# 705893.565324325 (2500, 0.001, 4, 0.1, 1, 0.01)

# %%
model = xgb.XGBRegressor(n_estimators=2500, learning_rate=0.001, max_depth=4, subsample=0.1, reg_lambda=1, gamma=0.01)

model.fit(finalXTrain, yTrain)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=0.01, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.001, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=4, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=2500, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
yTest = test[['incremental_cases', 'entity', 'date']]
xTest = test.drop(labels=['incremental_cases', 'date'],axis=1)
xTest = pd.get_dummies(xTest)
xTest['stay_at_home_announced_no'] = False
xTest['stay_at_home_effective_no'] = False
xTest['precip_flag_A'] = False
xTest['precip_flag_I'] = False
xTest = xTest[finalXTrain.columns]

# %%
xTest
# Out:
#       total_population    area_sqmi  population_density_per_sqmi  \
# 2949        10057155.0  4058.183382                  2478.240645
# 2961        10057155.0  4058.183382                  2478.240645
# 2973        10057155.0  4058.183382                  2478.240645
# 2985        10057155.0  4058.183382                  2478.240645
# 2997        10057155.0  4058.183382                  2478.240645
# ...                ...          ...                          ...
# 3380         1947529.0   863.649681                  2254.998805
# 3392         1947529.0   863.649681                  2254.998805
# 3404         1947529.0   863.649681                  2254.998805
# 3416         1947529.0   863.649681                  2254.998805
# 3428         1947529.0   863.649681                  2254.998805
#
#       percent_fair_or_poor_health  \
# 2949                    16.418669
# 2961                    16.418669
# 2973                    16.418669
# 2985                    16.418669
# 2997                    16.418669
# ...                           ...
# 3380                    19.945542
# 3392                    19.945542
# 3404                    19.945542
# 3416                    19.945542
# 3428                    19.945542
#
#       average_number_of_physically_unhealthy_days  \
# 2949                                     3.550138
# 2961                                     3.550138
# 2973                                     3.550138
# 2985                                     3.550138
# 2997                                     3.550138
# ...                                           ...
# 3380                                     3.633687
# 3392                                     3.633687
# 3404                                     3.633687
# 3416                                     3.633687
# 3428                                     3.633687
#
#       average_number_of_mentally_unhealthy_days  percent_low_birthweight  \
# 2949                                   3.616494                 7.133827
# 2961                                   3.616494                 7.133827
# 2973                                   3.616494                 7.133827
# 2985                                   3.616494                 7.133827
# 2997                                   3.616494                 7.133827
# ...                                         ...                      ...
# 3380                                   3.878487                 8.344893
# 3392                                   3.878487                 8.344893
# 3404                                   3.878487                 8.344893
# 3416                                   3.878487                 8.344893
# 3428                                   3.878487                 8.344893
#
#       percent_smokers  percent_adults_with_obesity  food_environment_index  \
# 2949        10.847678                         21.7                     8.5
# 2961        10.847678                         21.7                     8.5
# 2973        10.847678                         21.7                     8.5
# 2985        10.847678                         21.7                     8.5
# 2997        10.847678                         21.7                     8.5
# ...               ...                          ...                     ...
# 3380        14.049000                         29.5                     7.0
# 3392        14.049000                         29.5                     7.0
# 3404        14.049000                         29.5                     7.0
# 3416        14.049000                         29.5                     7.0
# 3428        14.049000                         29.5                     7.0
#
#       ...  entity_California-San Diego  entity_Florida-Miami-Dade  \
# 2949  ...                        False                      False
# 2961  ...                        False                      False
# 2973  ...                        False                      False
# 2985  ...                        False                      False
# 2997  ...                        False                      False
# ...   ...                          ...                        ...
# 3380  ...                        False                      False
# 3392  ...                        False                      False
# 3404  ...                        False                      False
# 3416  ...                        False                      False
# 3428  ...                        False                      False
#
#       entity_Illinois-Cook  entity_Nevada-Clark  entity_New York-Nassau  \
# 2949                 False                False                   False
# 2961                 False                False                   False
# 2973                 False                False                   False
# 2985                 False                False                   False
# 2997                 False                False                   False
# ...                    ...                  ...                     ...
# 3380                 False                False                   False
# 3392                 False                False                   False
# 3404                 False                False                   False
# 3416                 False                False                   False
# 3428                 False                False                   False
#
#       entity_New York-New York City  entity_New York-Suffolk  \
# 2949                          False                    False
# 2961                          False                    False
# 2973                          False                    False
# 2985                          False                    False
# 2997                          False                    False
# ...                             ...                      ...
# 3380                          False                    False
# 3392                          False                    False
# 3404                          False                    False
# 3416                          False                    False
# 3428                          False                    False
#
#       entity_Pennsylvania-Philadelphia  entity_Texas-Harris  \
# 2949                             False                False
# 2961                             False                False
# 2973                             False                False
# 2985                             False                False
# 2997                             False                False
# ...                                ...                  ...
# 3380                             False                False
# 3392                             False                False
# 3404                             False                False
# 3416                             False                False
# 3428                             False                False
#
#       entity_Texas-Tarrant
# 2949                 False
# 2961                 False
# 2973                 False
# 2985                 False
# 2997                 False
# ...                    ...
# 3380                  True
# 3392                  True
# 3404                  True
# 3416                  True
# 3428                  True
#
# [480 rows x 183 columns]

# %%
preds = model.predict(xTest)

# %%
from sklearn.metrics import mean_absolute_percentage_error

mse = mean_absolute_percentage_error(preds, yTest.incremental_cases)
mse
# Out:
# 2.9850022924831747

# %%
yTest['preds'] = preds
# Out:
# C:\Users\Albert Song\AppData\Local\Temp\ipykernel_5900\4113693813.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   yTest['preds'] = preds

# %%
model = xgb.XGBRegressor()

model.fit(finalXTrain, yTrain)
preds = model.predict(xTest)
mse = mean_absolute_percentage_error(preds, yTest.incremental_cases)
mse
# Out:
# 2.3584006479609343

# %%
yTest
# Out:
#       incremental_cases         entity       date
# 2953             1879.0  Illinois-Cook 2020-10-26
# 2965             1367.0  Illinois-Cook 2020-10-27
# 2977             2276.0  Illinois-Cook 2020-10-28
# 2989             2541.0  Illinois-Cook 2020-10-29
# 3001             2756.0  Illinois-Cook 2020-10-30
# 3013                0.0  Illinois-Cook 2020-10-31
# 3025             6697.0  Illinois-Cook 2020-11-01
# 3037             2638.0  Illinois-Cook 2020-11-02
# 3049             2444.0  Illinois-Cook 2020-11-03
# 3061             2992.0  Illinois-Cook 2020-11-04
# 3073             3801.0  Illinois-Cook 2020-11-05
# 3085             5289.0  Illinois-Cook 2020-11-06
# 3097             4658.0  Illinois-Cook 2020-11-07
# 3109             3738.0  Illinois-Cook 2020-11-08
# 3121             4448.0  Illinois-Cook 2020-11-09
# 3133             4315.0  Illinois-Cook 2020-11-10
# 3145             4037.0  Illinois-Cook 2020-11-11
# 3157             5255.0  Illinois-Cook 2020-11-12
# 3169             5945.0  Illinois-Cook 2020-11-13
# 3181             3730.0  Illinois-Cook 2020-11-14
# 3193             4709.0  Illinois-Cook 2020-11-15
# 3205             4507.0  Illinois-Cook 2020-11-16
# 3217             4396.0  Illinois-Cook 2020-11-17
# 3229             2425.0  Illinois-Cook 2020-11-18
# 3241             5855.0  Illinois-Cook 2020-11-19
# 3253             4449.0  Illinois-Cook 2020-11-20
# 3265             4293.0  Illinois-Cook 2020-11-21
# 3277             3870.0  Illinois-Cook 2020-11-22
# 3289             3321.0  Illinois-Cook 2020-11-23
# 3301             2907.0  Illinois-Cook 2020-11-24
# 3313             4188.0  Illinois-Cook 2020-11-25
# 3325             4817.0  Illinois-Cook 2020-11-26
# 3337             2741.0  Illinois-Cook 2020-11-27
# 3349             2712.0  Illinois-Cook 2020-11-28
# 3361             2638.0  Illinois-Cook 2020-11-29
# 3373             2149.0  Illinois-Cook 2020-11-30
# 3385             4353.0  Illinois-Cook 2020-12-01
# 3397             3412.0  Illinois-Cook 2020-12-02
# 3409             4190.0  Illinois-Cook 2020-12-03
# 3421             3798.0  Illinois-Cook 2020-12-04

# %%
for x in yTest.entity.unique():
    dfPlot = yTest[yTest['entity'] == x].drop(labels=['entity'], axis=1)
    dfPlot.plot(x='date', title=str('XGBoost Predictions for ' + x + ' county'))
